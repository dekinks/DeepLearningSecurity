# %%
# !pip3 install pandas
# !pip3 install seaborn
# !pip3 install --upgrade tensorflow-gpu
# !pip3 install import-ipynb
# !pip3 install cuda-python

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 

from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import math
import pickle
import time
import sys

import import_ipynb
import AttackDetectionModel

import tensorflow as tf
tf.compat.v1.disable_eager_execution()
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras import optimizers

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.metrics import f1_score, confusion_matrix

from bayes_opt import BayesianOptimization

# %matplotlib inline
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/andressa.amaral/.local/lib/python3.8/site-packages (1.5.1)
# Requirement already satisfied: numpy>=1.20.3 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from pandas) (1.23.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from pandas) (2022.6)
# Requirement already satisfied: six>=1.5 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in /home/andressa.amaral/.local/lib/python3.8/site-packages (0.12.1)
# Requirement already satisfied: pandas>=0.25 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from seaborn) (1.5.1)
# Requirement already satisfied: numpy>=1.17 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from seaborn) (1.23.4)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from seaborn) (3.6.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.3.0)
# Requirement already satisfied: packaging>=20.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (21.3)
# Requirement already satisfied: cycler>=0.10 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.6)
# Requirement already satisfied: fonttools>=4.22.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from pandas>=0.25->seaborn) (2022.6)
# Requirement already satisfied: six>=1.5 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow-gpu in /home/andressa.amaral/.local/lib/python3.8/site-packages (2.11.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (0.27.0)
# Requirement already satisfied: six>=1.12.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (1.16.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (2.11.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (3.3.0)
# Requirement already satisfied: absl-py>=1.0.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (1.3.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (0.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (2.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (4.4.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (2.11.0)
# Requirement already satisfied: flatbuffers>=2.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (22.10.26)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (2.11.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (3.19.6)
# Requirement already satisfied: h5py>=2.9.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (3.7.0)
# Requirement already satisfied: numpy>=1.20 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (1.23.4)
# Requirement already satisfied: setuptools in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (65.5.1)
# Requirement already satisfied: wrapt>=1.11.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (1.14.1)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (0.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (1.6.3)
# Requirement already satisfied: libclang>=13.0.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (14.0.6)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (1.50.0)
# Requirement already satisfied: packaging in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (21.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/lib/python3/dist-packages (from astunparse>=1.6.0->tensorflow-gpu) (0.30.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorboard<2.12,>=2.11->tensorflow-gpu) (2.14.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorboard<2.12,>=2.11->tensorflow-gpu) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorboard<2.12,>=2.11->tensorflow-gpu) (2.2.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorboard<2.12,>=2.11->tensorflow-gpu) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorboard<2.12,>=2.11->tensorflow-gpu) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorboard<2.12,>=2.11->tensorflow-gpu) (2.28.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorboard<2.12,>=2.11->tensorflow-gpu) (0.4.6)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from packaging->tensorflow-gpu) (3.0.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-gpu) (5.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-gpu) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-gpu) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-gpu) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-gpu) (5.0.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-gpu) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-gpu) (1.22)
# Requirement already satisfied: idna<4,>=2.5 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-gpu) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-gpu) (2018.1.18)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow-gpu) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-gpu) (3.10.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-gpu) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-gpu) (3.2.2)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: import-ipynb in /home/andressa.amaral/.local/lib/python3.8/site-packages (0.1.4)
# Requirement already satisfied: IPython in /home/andressa.amaral/.local/lib/python3.8/site-packages (from import-ipynb) (8.6.0)
# Requirement already satisfied: nbformat in /home/andressa.amaral/.local/lib/python3.8/site-packages (from import-ipynb) (5.7.0)
# Requirement already satisfied: pexpect>4.3 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from IPython->import-ipynb) (4.8.0)
# Requirement already satisfied: stack-data in /home/andressa.amaral/.local/lib/python3.8/site-packages (from IPython->import-ipynb) (0.6.1)
# Requirement already satisfied: backcall in /home/andressa.amaral/.local/lib/python3.8/site-packages (from IPython->import-ipynb) (0.2.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from IPython->import-ipynb) (3.0.32)
# Requirement already satisfied: pickleshare in /home/andressa.amaral/.local/lib/python3.8/site-packages (from IPython->import-ipynb) (0.7.5)
# Requirement already satisfied: traitlets>=5 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from IPython->import-ipynb) (5.5.0)
# Requirement already satisfied: decorator in /usr/lib/python3/dist-packages (from IPython->import-ipynb) (4.1.2)
# Requirement already satisfied: pygments>=2.4.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from IPython->import-ipynb) (2.13.0)
# Requirement already satisfied: jedi>=0.16 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from IPython->import-ipynb) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /home/andressa.amaral/.local/lib/python3.8/site-packages (from IPython->import-ipynb) (0.1.6)
# Requirement already satisfied: jupyter-core in /home/andressa.amaral/.local/lib/python3.8/site-packages (from nbformat->import-ipynb) (5.0.0)
# Requirement already satisfied: jsonschema>=2.6 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from nbformat->import-ipynb) (4.17.0)
# Requirement already satisfied: fastjsonschema in /home/andressa.amaral/.local/lib/python3.8/site-packages (from nbformat->import-ipynb) (2.16.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from jedi>=0.16->IPython->import-ipynb) (0.8.3)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (1.3.10)
# Requirement already satisfied: attrs>=17.4.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (22.1.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (5.10.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (0.19.2)
# Requirement already satisfied: ptyprocess>=0.5 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from pexpect>4.3->IPython->import-ipynb) (0.7.0)
# Requirement already satisfied: wcwidth in /home/andressa.amaral/.local/lib/python3.8/site-packages (from prompt-toolkit<3.1.0,>3.0.1->IPython->import-ipynb) (0.2.5)
# Requirement already satisfied: platformdirs in /home/andressa.amaral/.local/lib/python3.8/site-packages (from jupyter-core->nbformat->import-ipynb) (2.5.4)
# Requirement already satisfied: asttokens>=2.1.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from stack-data->IPython->import-ipynb) (2.1.0)
# Requirement already satisfied: pure-eval in /home/andressa.amaral/.local/lib/python3.8/site-packages (from stack-data->IPython->import-ipynb) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from stack-data->IPython->import-ipynb) (1.2.0)
# Requirement already satisfied: six in /home/andressa.amaral/.local/lib/python3.8/site-packages (from asttokens>=2.1.0->stack-data->IPython->import-ipynb) (1.16.0)
# Requirement already satisfied: zipp>=3.1.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat->import-ipynb) (3.10.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: cuda-python in /home/andressa.amaral/.local/lib/python3.8/site-packages (11.8.1)
# Requirement already satisfied: cython in /home/andressa.amaral/.local/lib/python3.8/site-packages (from cuda-python) (0.29.32)
# importing Jupyter notebook from AttackDetectionModel.ipynb

# %%
gpu_options = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction = 0.333)
sess = tf.compat.v1.Session(config = tf.compat.v1.ConfigProto(gpu_options = gpu_options))

# %% [markdown]
# # Data Pre-Processing

# %%
#number_features = 115
#number_features = 92
#number_features = 69
#number_features = 46
number_features = 23

# %%
# Get benign traffic 
df_et_benign = AttackDetectionModel.get_files('../../nbaiot/Ecobee_Thermostat', number_features)

# Get Bashlite traffic
df_et_bashlite = AttackDetectionModel.get_files('../../nbaiot/Ecobee_Thermostat/gafgyt', number_features)

# Get Mirai traffic
df_et_mirai = AttackDetectionModel.get_files('../../nbaiot/Ecobee_Thermostat/mirai', number_features)

# %%
# Normalize with the min-max scaler
scaler = MinMaxScaler()
df_et_benign_norm = scaler.fit_transform(df_et_benign)
df_et_bashlite_norm = scaler.fit_transform(df_et_bashlite)
df_et_mirai_norm = scaler.fit_transform(df_et_mirai)

# %% [markdown]
# # Sets

# %%
# Train set
len_benign_train = int(0.7 * len(df_et_benign_norm))
X_train = df_et_benign_norm[:len_benign_train]

# %%
# Test set
X_test_benign = df_et_benign_norm[len_benign_train:]
X_test = np.concatenate([X_test_benign, df_et_bashlite_norm, df_et_mirai_norm])

Y_test = np.ones(len(X_test))
Y_test[:len(X_test_benign)] = 0

# %% [markdown]
# # Model

# %%
# Parameters
original_dim = X_train.shape[1]
input_shape = (original_dim,)
intermediate_dim = int(original_dim / 2)
latent_dim = int(original_dim / 3)

# Initial values
epochs = 5
learning_rate = 0.0001
batch_size = 20
anomaly_threshold = 0.05

# Dictionary
dict_params = { 'learning_rate': learning_rate, 'batch_size': round(batch_size), 'epochs': round(epochs)}
pbounds = { 'learning_rate': (0.000001, 0.001), 'batch_size': (10, 100), 'epochs': (50, 500)}

# %%
# KL Loss function
def vae_loss(x, x_decoded_mean):
    # Compute the average MSE error, then scale it up (sum on all axes)
    
    reconstruction_loss = K.sum(K.square(x - x_decoded_mean))
    
    # Compute the KL loss
    
    kl_loss = - 0.5 * K.sum(1 + z_var - K.square(z_mean) - K.square(K.exp(z_var)), axis=-1)
    
    # Return the average loss over all 
    
    total_loss = K.mean(reconstruction_loss + kl_loss) # Total_loss = reconstruction_loss + kl_loss 
    return total_loss

# (1) Reconstruction Loss - Forces the encoder to generate latent features that minimize the reconstruction error, or else is
# penalized
# (2) KL Loss - Forces the distribution generated by the encoder to be similar to the prior probability of the input vector, 
# pushing latent feature space to normality

# %%
# Encoder
inputs, encoder, z_var, z_mean = AttackDetectionModel.vae_encoder(input_shape, 
                                                                  intermediate_dim, 
                                                                  latent_dim, 
                                                                  AttackDetectionModel.reparametrization)
encoder.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  encoder_input (InputLayer)     [(None, 23)]         0           []
#
#  dense (Dense)                  (None, 11)           264         ['encoder_input[0][0]']
#
#  z_mean (Dense)                 (None, 7)            84          ['dense[0][0]']
#
#  z_var (Dense)                  (None, 7)            84          ['dense[0][0]']
#
#  z (Lambda)                     (None, 7)            0           ['z_mean[0][0]',
#                                                                   'z_var[0][0]']
#
# ==================================================================================================
# Total params: 432
# Trainable params: 432
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Decoder
decoder = AttackDetectionModel.vae_decoder(intermediate_dim, latent_dim, original_dim)
outputs = decoder(encoder(inputs))
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  z_sampling (InputLayer)     [(None, 7)]               0
#
#  dense_1 (Dense)             (None, 11)                88
#
#  dense_2 (Dense)             (None, 23)                276
#
# =================================================================
# Total params: 364
# Trainable params: 364
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Hyperparameter Optimization

# %%
def maximize_training(X_train = X_train, 
                      X_test = X_test, 
                      Y_test = Y_test, 
                      inputs = inputs, 
                      outputs = outputs, 
                      vae_loss = vae_loss,
                      learning_rate = learning_rate,
                      batch_size = batch_size,
                      epochs = epochs,
                      anomaly_threshold = anomaly_threshold):    
    
    # Create model
    opt_adam = optimizers.Adam(learning_rate = dict_params['learning_rate'], clipvalue = 0.5)
    model = Model(inputs, outputs, name = 'vae_mlp')
    model.compile(optimizer = opt_adam, loss = vae_loss)

    # Train
    history = model.fit(X_train, 
                        X_train, 
                        shuffle = True, 
                        verbose = 0,
                        epochs = dict_params['epochs'], 
                        batch_size = dict_params['batch_size'])
    
    # Maximize the f1-score
    X_pred_opt = model.predict(X_test)
    error_vector_opt = AttackDetectionModel.get_error_term(X_pred_opt, X_test, _rmse = False)
    Y_pred_opt = (error_vector_opt > anomaly_threshold)
    f1 = f1_score(Y_test, Y_pred_opt)
    
    return f1

# %%
'''
# Apply Bayesian optimization to choose the best hyperparameters

opt = BayesianOptimization(f = maximize_training,
                           pbounds = pbounds,
                           verbose = 2, 
                           random_state = 1)

opt_start = time.time()

opt.maximize(init_points = 5, n_iter = 5)

opt_end = time.time()
opt_time = opt_end - opt_start
print("Optimization time:", opt_time)

learning_rate = opt.max['params']['learning_rate']
epochs = round(opt.max['params']['epochs'])
batch_size = round(opt.max['params']['batch_size'])
'''
# Out:
# '\n# Apply Bayesian optimization to choose the best hyperparameters\n\nopt = BayesianOptimization(f = maximize_training,\n                           pbounds = pbounds,\n                           verbose = 2, \n                           random_state = 1)\n\nopt_start = time.time()\n\nopt.maximize(init_points = 5, n_iter = 5)\n\nopt_end = time.time()\nopt_time = opt_end - opt_start\nprint("Optimization time:", opt_time)\n\nlearning_rate = opt.max[\'params\'][\'learning_rate\']\nepochs = round(opt.max[\'params\'][\'epochs\'])\nbatch_size = round(opt.max[\'params\'][\'batch_size\'])\n'

# %% [markdown]
# # Predict Attacks

# %%
# Training step with the best hyperparameters
learning_rate = 0.00012123446827562964
epochs = 422
batch_size = 74
opt_time = 262.7667851448059
anomaly_threshold = 0.04

# %%
for i in range(1):
    print("Iteration " + str(i))
    
    # Train
    vae_model, train_time = AttackDetectionModel.train(X_train, inputs, outputs, vae_loss, learning_rate, epochs, batch_size)
    
    # Set the optimized anomaly threshold
    #anomaly_threshold = AttackDetectionModel.get_anomaly_threshold(X_train, vae_model)
    
    # Test
    X_pred, test_time = AttackDetectionModel.test(X_test, vae_model)
    Y_test, Y_pred = AttackDetectionModel.get_prediction(Y_test, X_pred, X_test, anomaly_threshold, vae_model)
    
    # Metrics
    acc, f1, pre, rec = AttackDetectionModel.get_scores(Y_test, Y_pred)
    
    # Print results
    AttackDetectionModel.print_results(number_features,
                                       learning_rate,
                                       epochs,
                                       batch_size,
                                       anomaly_threshold,
                                       X_train,
                                       X_test,
                                       opt_time,
                                       train_time,
                                       test_time,
                                       acc,
                                       f1,
                                       pre,
                                       rec,
                                       Y_test,
                                       Y_pred,
                                       "Results/ecobee_thermostat.txt")
    
    print("")
# Out:
# Iteration 0
# Train on 9179 samples
# Epoch 1/422
# 9179/9179 [==============================] - 1s 67us/sample - loss: 292.9022
# Epoch 2/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 266.3727
# Epoch 3/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 243.3265
# Epoch 4/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 219.5697
# Epoch 5/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 194.3837
# Epoch 6/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 168.8267
# Epoch 7/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 142.4027
# Epoch 8/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 115.6081
# Epoch 9/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 90.7285
# Epoch 10/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 70.3564
# Epoch 11/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 53.3841
# Epoch 12/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 41.0664
# Epoch 13/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 32.8899
# Epoch 14/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 27.9790
# Epoch 15/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 24.5787
# Epoch 16/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 22.1802
# Epoch 17/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 20.6074
# Epoch 18/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 19.3550
# Epoch 19/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 18.4865
# Epoch 20/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 17.7623
# Epoch 21/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 17.0915
# Epoch 22/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 16.6158
# Epoch 23/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 16.1801
# Epoch 24/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 15.6721
# Epoch 25/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 15.2360
# Epoch 26/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 14.8548
# Epoch 27/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 14.4244
# Epoch 28/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 14.1217
# Epoch 29/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 13.7003
# Epoch 30/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 13.2854
# Epoch 31/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 12.8615
# Epoch 32/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 12.5016
# Epoch 33/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 12.0860
# Epoch 34/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 11.7745
# Epoch 35/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 11.5177
# Epoch 36/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 11.1376
# Epoch 37/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 10.9231
# Epoch 38/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 10.6708
# Epoch 39/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 10.4377
# Epoch 40/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 10.2481
# Epoch 41/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 10.0465
# Epoch 42/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 9.7998
# Epoch 43/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 9.6735
# Epoch 44/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 9.5073
# Epoch 45/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 9.3433
# Epoch 46/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 9.2166
# Epoch 47/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 9.1280
# Epoch 48/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 9.0065
# Epoch 49/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 8.8697
# Epoch 50/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 8.8494
# Epoch 51/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 8.7027
# Epoch 52/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 8.6282
# Epoch 53/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 8.5717
# Epoch 54/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 8.4928
# Epoch 55/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 8.4605
# Epoch 56/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 8.4268
# Epoch 57/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 8.3768
# Epoch 58/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 8.2803
# Epoch 59/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 8.2662
# Epoch 60/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 8.2272
# Epoch 61/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 8.1414
# Epoch 62/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 8.1300
# Epoch 63/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 8.0611
# Epoch 64/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 8.0265
# Epoch 65/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 7.9626
# Epoch 66/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 7.9311
# Epoch 67/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 7.8891
# Epoch 68/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 7.9022
# Epoch 69/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 7.8044
# Epoch 70/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 7.8042
# Epoch 71/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 7.7496
# Epoch 72/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 7.7416
# Epoch 73/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 7.6985
# Epoch 74/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 7.6740
# Epoch 75/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 7.6492
# Epoch 76/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 7.6023
# Epoch 77/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 7.5941
# Epoch 78/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 7.5430
# Epoch 79/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 7.5260
# Epoch 80/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 7.4976
# Epoch 81/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 7.4982
# Epoch 82/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 7.4443
# Epoch 83/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 7.4010
# Epoch 84/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 7.3835
# Epoch 85/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 7.3755
# Epoch 86/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 7.3083
# Epoch 87/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 7.2731
# Epoch 88/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 7.2878
# Epoch 89/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 7.2480
# Epoch 90/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 7.2277
# Epoch 91/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 7.1946
# Epoch 92/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 7.1745
# Epoch 93/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 7.1343
# Epoch 94/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 7.0927
# Epoch 95/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 7.1142
# Epoch 96/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 7.0049
# Epoch 97/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.9996
# Epoch 98/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 6.9717
# Epoch 99/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 6.9519
# Epoch 100/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 6.9270
# Epoch 101/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.9154
# Epoch 102/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 6.9202
# Epoch 103/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 6.8389
# Epoch 104/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.8040
# Epoch 105/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.7703
# Epoch 106/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 6.7661
# Epoch 107/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.7668
# Epoch 108/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.6835
# Epoch 109/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.6582
# Epoch 110/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.6544
# Epoch 111/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 6.6421
# Epoch 112/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.6054
# Epoch 113/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 6.5676
# Epoch 114/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 6.5347
# Epoch 115/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 6.4995
# Epoch 116/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 6.4709
# Epoch 117/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 6.4651
# Epoch 118/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 6.4088
# Epoch 119/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 6.4271
# Epoch 120/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 6.3787
# Epoch 121/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 6.3244
# Epoch 122/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 6.2980
# Epoch 123/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 6.2810
# Epoch 124/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 6.2460
# Epoch 125/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 6.2168
# Epoch 126/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 6.1923
# Epoch 127/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 6.1777
# Epoch 128/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 6.1653
# Epoch 129/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 6.1880
# Epoch 130/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 6.0926
# Epoch 131/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 6.0461
# Epoch 132/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 6.0774
# Epoch 133/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 6.0321
# Epoch 134/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 6.0067
# Epoch 135/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 6.0111
# Epoch 136/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 5.9563
# Epoch 137/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 5.9619
# Epoch 138/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 5.9365
# Epoch 139/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 5.9008
# Epoch 140/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 5.8586
# Epoch 141/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 5.8503
# Epoch 142/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 5.8383
# Epoch 143/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 5.7719
# Epoch 144/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 5.8293
# Epoch 145/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 5.7578
# Epoch 146/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 5.7471
# Epoch 147/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 5.7182
# Epoch 148/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 5.6553
# Epoch 149/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 5.6363
# Epoch 150/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 5.6170
# Epoch 151/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 5.6441
# Epoch 152/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 5.5731
# Epoch 153/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 5.5988
# Epoch 154/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 5.5496
# Epoch 155/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 5.5231
# Epoch 156/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 5.4677
# Epoch 157/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 5.4528
# Epoch 158/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 5.4501
# Epoch 159/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 5.4032
# Epoch 160/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 5.4064
# Epoch 161/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 5.3817
# Epoch 162/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 5.3114
# Epoch 163/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 5.3383
# Epoch 164/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 5.3197
# Epoch 165/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 5.2701
# Epoch 166/422
# 9179/9179 [==============================] - 0s 24us/sample - loss: 5.2895
# Epoch 167/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 5.2514
# Epoch 168/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 5.2012
# Epoch 169/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 5.2111
# Epoch 170/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 5.2061
# Epoch 171/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 5.1945
# Epoch 172/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 5.1849
# Epoch 173/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 5.1172
# Epoch 174/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 5.1337
# Epoch 175/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 5.1214
# Epoch 176/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 5.1019
# Epoch 177/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 5.0968
# Epoch 178/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 5.0965
# Epoch 179/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 5.0609
# Epoch 180/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 5.0562
# Epoch 181/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 5.0532
# Epoch 182/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 5.0551
# Epoch 183/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 5.0313
# Epoch 184/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 5.0004
# Epoch 185/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 4.9900
# Epoch 186/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 4.9914
# Epoch 187/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 4.9760
# Epoch 188/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 4.9569
# Epoch 189/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.9300
# Epoch 190/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 4.9713
# Epoch 191/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 4.9297
# Epoch 192/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 4.9410
# Epoch 193/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 4.9232
# Epoch 194/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 4.8950
# Epoch 195/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 4.9256
# Epoch 196/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.8707
# Epoch 197/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 4.8981
# Epoch 198/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 4.8914
# Epoch 199/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 4.9041
# Epoch 200/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.8903
# Epoch 201/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.8681
# Epoch 202/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.8617
# Epoch 203/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 4.8569
# Epoch 204/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.8715
# Epoch 205/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.8661
# Epoch 206/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.8492
# Epoch 207/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.8368
# Epoch 208/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 4.8305
# Epoch 209/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 4.8302
# Epoch 210/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 4.8573
# Epoch 211/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.7907
# Epoch 212/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 4.8186
# Epoch 213/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.8106
# Epoch 214/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 4.7909
# Epoch 215/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 4.8020
# Epoch 216/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.7697
# Epoch 217/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.7592
# Epoch 218/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.8109
# Epoch 219/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 4.7767
# Epoch 220/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.7735
# Epoch 221/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.7719
# Epoch 222/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 4.7423
# Epoch 223/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 4.7665
# Epoch 224/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.7085
# Epoch 225/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 4.7366
# Epoch 226/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.7226
# Epoch 227/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.7204
# Epoch 228/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.7133
# Epoch 229/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 4.7011
# Epoch 230/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.7082
# Epoch 231/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 4.7050
# Epoch 232/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 4.6836
# Epoch 233/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.7136
# Epoch 234/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.6425
# Epoch 235/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 4.6836
# Epoch 236/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.6832
# Epoch 237/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.7090
# Epoch 238/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.6572
# Epoch 239/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.7020
# Epoch 240/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.6436
# Epoch 241/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 4.6476
# Epoch 242/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 4.6130
# Epoch 243/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 4.6825
# Epoch 244/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 4.6551
# Epoch 245/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.6577
# Epoch 246/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.6661
# Epoch 247/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.6471
# Epoch 248/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.6599
# Epoch 249/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.6464
# Epoch 250/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.6117
# Epoch 251/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.6287
# Epoch 252/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 4.6236
# Epoch 253/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.6234
# Epoch 254/422
# 9179/9179 [==============================] - 0s 24us/sample - loss: 4.6039
# Epoch 255/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.6343
# Epoch 256/422
# 9179/9179 [==============================] - 0s 24us/sample - loss: 4.5976
# Epoch 257/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 4.5838
# Epoch 258/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 4.5963
# Epoch 259/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.5595
# Epoch 260/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.5990
# Epoch 261/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 4.5890
# Epoch 262/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 4.5755
# Epoch 263/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.5877
# Epoch 264/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.5718
# Epoch 265/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.5582
# Epoch 266/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 4.5443
# Epoch 267/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.5661
# Epoch 268/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.5719
# Epoch 269/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.5484
# Epoch 270/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.5648
# Epoch 271/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.5778
# Epoch 272/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.5498
# Epoch 273/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.5275
# Epoch 274/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.5324
# Epoch 275/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.5348
# Epoch 276/422
# 9179/9179 [==============================] - 0s 24us/sample - loss: 4.5090
# Epoch 277/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.5324
# Epoch 278/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.5399
# Epoch 279/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.4957
# Epoch 280/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 4.4989
# Epoch 281/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 4.5017
# Epoch 282/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 4.4983
# Epoch 283/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.5106
# Epoch 284/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.5202
# Epoch 285/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.5131
# Epoch 286/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.5136
# Epoch 287/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.4738
# Epoch 288/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.5082
# Epoch 289/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.4663
# Epoch 290/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.4858
# Epoch 291/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.4921
# Epoch 292/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 4.4550
# Epoch 293/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.4730
# Epoch 294/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.4816
# Epoch 295/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.5065
# Epoch 296/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.4862
# Epoch 297/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.4359
# Epoch 298/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.4853
# Epoch 299/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.4989
# Epoch 300/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 4.4613
# Epoch 301/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.4647
# Epoch 302/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.4578
# Epoch 303/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.4345
# Epoch 304/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 4.4448
# Epoch 305/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.4423
# Epoch 306/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.4749
# Epoch 307/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.4475
# Epoch 308/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.4363
# Epoch 309/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 4.4487
# Epoch 310/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.4281
# Epoch 311/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.4630
# Epoch 312/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.4406
# Epoch 313/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.4350
# Epoch 314/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.4345
# Epoch 315/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.4451
# Epoch 316/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.4342
# Epoch 317/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.4372
# Epoch 318/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.4254
# Epoch 319/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 4.4334
# Epoch 320/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.4214
# Epoch 321/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.4622
# Epoch 322/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.4115
# Epoch 323/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.4201
# Epoch 324/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.4234
# Epoch 325/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.4273
# Epoch 326/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.4342
# Epoch 327/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 4.4252
# Epoch 328/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.4151
# Epoch 329/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.4142
# Epoch 330/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.3614
# Epoch 331/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.3759
# Epoch 332/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 4.3762
# Epoch 333/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.4242
# Epoch 334/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.4080
# Epoch 335/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.4156
# Epoch 336/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.3838
# Epoch 337/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.3802
# Epoch 338/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.3883
# Epoch 339/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.3839
# Epoch 340/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.3823
# Epoch 341/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 4.3763
# Epoch 342/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.4060
# Epoch 343/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.3765
# Epoch 344/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.3934
# Epoch 345/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.3951
# Epoch 346/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.3774
# Epoch 347/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.3746
# Epoch 348/422
# 9179/9179 [==============================] - 0s 24us/sample - loss: 4.3990
# Epoch 349/422
# 9179/9179 [==============================] - 0s 24us/sample - loss: 4.3865
# Epoch 350/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.3720
# Epoch 351/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.3622
# Epoch 352/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.3433
# Epoch 353/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.3854
# Epoch 354/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 4.3819
# Epoch 355/422
# 9179/9179 [==============================] - 0s 25us/sample - loss: 4.3699
# Epoch 356/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.3680
# Epoch 357/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.4153
# Epoch 358/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.3779
# Epoch 359/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.3881
# Epoch 360/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.3924
# Epoch 361/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 4.3507
# Epoch 362/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.3554
# Epoch 363/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.3673
# Epoch 364/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.3467
# Epoch 365/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 4.3606
# Epoch 366/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.3640
# Epoch 367/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 4.3528
# Epoch 368/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.3676
# Epoch 369/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.3682
# Epoch 370/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.3270
# Epoch 371/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.3025
# Epoch 372/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.3702
# Epoch 373/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 4.3516
# Epoch 374/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.3436
# Epoch 375/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.3568
# Epoch 376/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.3532
# Epoch 377/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.3355
# Epoch 378/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.3268
# Epoch 379/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.3712
# Epoch 380/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.3238
# Epoch 381/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.3584
# Epoch 382/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.3525
# Epoch 383/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 4.3579
# Epoch 384/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.3401
# Epoch 385/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.2850
# Epoch 386/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.3027
# Epoch 387/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.3055
# Epoch 388/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 4.3903
# Epoch 389/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.3158
# Epoch 390/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 4.2998
# Epoch 391/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.3435
# Epoch 392/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.3344
# Epoch 393/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 4.3261
# Epoch 394/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.3155
# Epoch 395/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.3403
# Epoch 396/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.3154
# Epoch 397/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.3218
# Epoch 398/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.2968
# Epoch 399/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.3017
# Epoch 400/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 4.3245
# Epoch 401/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.3147
# Epoch 402/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.3105
# Epoch 403/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.2997
# Epoch 404/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.3410
# Epoch 405/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.3364
# Epoch 406/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.3439
# Epoch 407/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.3124
# Epoch 408/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.3077
# Epoch 409/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.3032
# Epoch 410/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.3011
# Epoch 411/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.2947
# Epoch 412/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.3110
# Epoch 413/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.3045
# Epoch 414/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.3716
# Epoch 415/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.2815
# Epoch 416/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.3180
# Epoch 417/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.3382
# Epoch 418/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.3388
# Epoch 419/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 4.2914
# Epoch 420/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.2957
# Epoch 421/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.3082
# Epoch 422/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 4.3218
# Training time: 82.0908591747284
# /home/andressa.amaral/.local/lib/python3.8/site-packages/keras/engine/training_v1.py:2357: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# Testing time: 13.671406269073486

# %% [markdown]
# # Metrics

# %%
# Examinig the latent space generated by the encoder
X_encoded = encoder.predict(X_test)

pca = PCA(n_components=2)
X_analysis = pca.fit_transform(X_encoded)
# Out:
# /home/andressa.amaral/.local/lib/python3.8/site-packages/keras/engine/training_v1.py:2357: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,

# %%
plt.figure(figsize=(8, 8))
sns.scatterplot(x = X_analysis[:, 0], y = X_analysis[:, 1], s = 20, hue = Y_pred)
plt.grid()
plt.savefig("Results/PCA/ET_" + str(number_features))
plt.show()

# Orange ones are anomalies

# %%
plt.figure(figsize = (8, 8))
sns.scatterplot(x = X_analysis[:, 0], y = X_analysis[:, 1], s = 20, hue = Y_test)
plt.grid()
plt.savefig("Results/PCA Groundtruth/ET_" + str(number_features))
plt.show()

# Ground truth

# %%
conf_matrix = confusion_matrix(Y_test, Y_pred)

fig, ax = plt.subplots(figsize = (5, 5))
ax.matshow(conf_matrix, cmap = plt.cm.Blues, alpha = 0.3)
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        ax.text(x = j, y = i,s = conf_matrix[i, j], va = 'center', ha = 'center', size = 'large')
 
plt.xlabel('Predictions', fontsize=12)
plt.ylabel('Actuals', fontsize=12)
plt.title('Confusion Matrix', fontsize=14)
plt.savefig("Results/Confusion Matrix/ET_" + str(number_features))
plt.show()
