# %%
# !pip3 install pandas
# !pip3 install seaborn
# !pip3 install --upgrade tensorflow-gpu
# !pip3 install import-ipynb
# !pip3 install cuda-python

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 

from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import math
import pickle
import time
import sys

import import_ipynb
import AttackDetectionModel

import tensorflow as tf
tf.compat.v1.disable_eager_execution()
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras import optimizers

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.metrics import f1_score, confusion_matrix

from bayes_opt import BayesianOptimization

# %matplotlib inline
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/andressa.amaral/.local/lib/python3.8/site-packages (1.5.1)
# Requirement already satisfied: pytz>=2020.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from pandas) (2022.6)
# Requirement already satisfied: numpy>=1.20.3 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from pandas) (1.23.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in /home/andressa.amaral/.local/lib/python3.8/site-packages (0.12.1)
# Requirement already satisfied: numpy>=1.17 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from seaborn) (1.23.4)
# Requirement already satisfied: pandas>=0.25 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from seaborn) (1.5.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from seaborn) (3.6.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.6)
# Requirement already satisfied: python-dateutil>=2.7 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.3.0)
# Requirement already satisfied: pytz>=2020.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from pandas>=0.25->seaborn) (2022.6)
# Requirement already satisfied: six>=1.5 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow-gpu in /home/andressa.amaral/.local/lib/python3.8/site-packages (2.11.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (2.11.0)
# Requirement already satisfied: numpy>=1.20 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (1.23.4)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (1.50.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (0.4.0)
# Requirement already satisfied: absl-py>=1.0.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (1.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (4.4.0)
# Requirement already satisfied: six>=1.12.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (1.16.0)
# Requirement already satisfied: packaging in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (21.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (3.3.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (14.0.6)
# Requirement already satisfied: setuptools in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (65.5.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (3.19.6)
# Requirement already satisfied: termcolor>=1.1.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (2.1.0)
# Requirement already satisfied: h5py>=2.9.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (3.7.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (1.14.1)
# Requirement already satisfied: astunparse>=1.6.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (1.6.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (0.27.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (0.2.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (2.11.0)
# Requirement already satisfied: flatbuffers>=2.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (22.10.26)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (2.11.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/lib/python3/dist-packages (from astunparse>=1.6.0->tensorflow-gpu) (0.30.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorboard<2.12,>=2.11->tensorflow-gpu) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorboard<2.12,>=2.11->tensorflow-gpu) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorboard<2.12,>=2.11->tensorflow-gpu) (0.4.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorboard<2.12,>=2.11->tensorflow-gpu) (2.28.1)
# Requirement already satisfied: markdown>=2.6.8 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorboard<2.12,>=2.11->tensorflow-gpu) (3.4.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorboard<2.12,>=2.11->tensorflow-gpu) (2.2.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorboard<2.12,>=2.11->tensorflow-gpu) (2.14.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from packaging->tensorflow-gpu) (3.0.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-gpu) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-gpu) (5.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-gpu) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-gpu) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-gpu) (5.0.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-gpu) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-gpu) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-gpu) (2018.1.18)
# Requirement already satisfied: idna<4,>=2.5 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-gpu) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow-gpu) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-gpu) (3.10.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-gpu) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-gpu) (3.2.2)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: import-ipynb in /home/andressa.amaral/.local/lib/python3.8/site-packages (0.1.4)
# Requirement already satisfied: IPython in /home/andressa.amaral/.local/lib/python3.8/site-packages (from import-ipynb) (8.6.0)
# Requirement already satisfied: nbformat in /home/andressa.amaral/.local/lib/python3.8/site-packages (from import-ipynb) (5.7.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from IPython->import-ipynb) (3.0.32)
# Requirement already satisfied: matplotlib-inline in /home/andressa.amaral/.local/lib/python3.8/site-packages (from IPython->import-ipynb) (0.1.6)
# Requirement already satisfied: traitlets>=5 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from IPython->import-ipynb) (5.5.0)
# Requirement already satisfied: pexpect>4.3 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from IPython->import-ipynb) (4.8.0)
# Requirement already satisfied: pickleshare in /home/andressa.amaral/.local/lib/python3.8/site-packages (from IPython->import-ipynb) (0.7.5)
# Requirement already satisfied: backcall in /home/andressa.amaral/.local/lib/python3.8/site-packages (from IPython->import-ipynb) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from IPython->import-ipynb) (0.18.1)
# Requirement already satisfied: pygments>=2.4.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from IPython->import-ipynb) (2.13.0)
# Requirement already satisfied: decorator in /usr/lib/python3/dist-packages (from IPython->import-ipynb) (4.1.2)
# Requirement already satisfied: stack-data in /home/andressa.amaral/.local/lib/python3.8/site-packages (from IPython->import-ipynb) (0.6.1)
# Requirement already satisfied: jsonschema>=2.6 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from nbformat->import-ipynb) (4.17.0)
# Requirement already satisfied: fastjsonschema in /home/andressa.amaral/.local/lib/python3.8/site-packages (from nbformat->import-ipynb) (2.16.2)
# Requirement already satisfied: jupyter-core in /home/andressa.amaral/.local/lib/python3.8/site-packages (from nbformat->import-ipynb) (5.0.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from jedi>=0.16->IPython->import-ipynb) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (0.19.2)
# Requirement already satisfied: attrs>=17.4.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (22.1.0)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (1.3.10)
# Requirement already satisfied: importlib-resources>=1.4.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (5.10.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from pexpect>4.3->IPython->import-ipynb) (0.7.0)
# Requirement already satisfied: wcwidth in /home/andressa.amaral/.local/lib/python3.8/site-packages (from prompt-toolkit<3.1.0,>3.0.1->IPython->import-ipynb) (0.2.5)
# Requirement already satisfied: platformdirs in /home/andressa.amaral/.local/lib/python3.8/site-packages (from jupyter-core->nbformat->import-ipynb) (2.5.4)
# Requirement already satisfied: asttokens>=2.1.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from stack-data->IPython->import-ipynb) (2.1.0)
# Requirement already satisfied: executing>=1.2.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from stack-data->IPython->import-ipynb) (1.2.0)
# Requirement already satisfied: pure-eval in /home/andressa.amaral/.local/lib/python3.8/site-packages (from stack-data->IPython->import-ipynb) (0.2.2)
# Requirement already satisfied: six in /home/andressa.amaral/.local/lib/python3.8/site-packages (from asttokens>=2.1.0->stack-data->IPython->import-ipynb) (1.16.0)
# Requirement already satisfied: zipp>=3.1.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat->import-ipynb) (3.10.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: cuda-python in /home/andressa.amaral/.local/lib/python3.8/site-packages (11.8.1)
# Requirement already satisfied: cython in /home/andressa.amaral/.local/lib/python3.8/site-packages (from cuda-python) (0.29.32)
# importing Jupyter notebook from AttackDetectionModel.ipynb

# %%
gpu_options = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction = 0.333)
sess = tf.compat.v1.Session(config = tf.compat.v1.ConfigProto(gpu_options = gpu_options))

# %% [markdown]
# # Data Pre-Processing

# %%
#number_features = 115
#number_features = 92
#number_features = 69
#number_features = 46
number_features = 23

# %%
# Get benign traffic 
df_p7_benign = AttackDetectionModel.get_files('../../nbaiot/Provision_PT_737E_Security_Camera', number_features)

# Get Bashlite traffic
df_p7_bashlite = AttackDetectionModel.get_files('../../nbaiot/Provision_PT_737E_Security_Camera/gafgyt', number_features)

# Get Mirai traffic
df_p7_mirai = AttackDetectionModel.get_files('../../nbaiot/Provision_PT_737E_Security_Camera/mirai', number_features)

# %%
# Normalize with the min-max scaler
scaler = MinMaxScaler()
df_p7_benign_norm = scaler.fit_transform(df_p7_benign)
df_p7_bashlite_norm = scaler.fit_transform(df_p7_bashlite)
df_p7_mirai_norm = scaler.fit_transform(df_p7_mirai)

# %% [markdown]
# # Sets

# %%
# Train set
len_benign_train = int(0.7 * len(df_p7_benign_norm))
X_train = df_p7_benign_norm[:len_benign_train]

# %%
# Test set
X_test_benign = df_p7_benign_norm[len_benign_train:]
X_test = np.concatenate([X_test_benign, df_p7_bashlite_norm, df_p7_mirai_norm])

Y_test = np.ones(len(X_test))
Y_test[:len(X_test_benign)] = 0

# %% [markdown]
# # Model

# %%
# Parameters
original_dim = X_train.shape[1]
input_shape = (original_dim,)
intermediate_dim = int(original_dim / 2)
latent_dim = int(original_dim / 3)

# Initial values
epochs = 5
learning_rate = 0.0001
batch_size = 32
anomaly_threshold = 0.035

# Dictionary
dict_params = { 'learning_rate': learning_rate, 'batch_size': round(batch_size), 'epochs': round(epochs)}
pbounds = { 'learning_rate': (0.000001, 0.001), 'batch_size': (10, 100), 'epochs': (50, 500)}

# %%
# KL Loss function
def vae_loss(x, x_decoded_mean):
    # Compute the average MSE error, then scale it up (sum on all axes)
    
    reconstruction_loss = K.sum(K.square(x - x_decoded_mean))
    
    # Compute the KL loss
    
    kl_loss = - 0.5 * K.sum(1 + z_var - K.square(z_mean) - K.square(K.exp(z_var)), axis=-1)
    
    # Return the average loss over all 
    
    total_loss = K.mean(reconstruction_loss + kl_loss) # Total_loss = reconstruction_loss + kl_loss 
    return total_loss

# (1) Reconstruction Loss - Forces the encoder to generate latent features that minimize the reconstruction error, or else is
# penalized
# (2) KL Loss - Forces the distribution generated by the encoder to be similar to the prior probability of the input vector, 
# pushing latent feature space to normality

# %%
# Encoder
inputs, encoder, z_var, z_mean = AttackDetectionModel.vae_encoder(input_shape, 
                                                                  intermediate_dim, 
                                                                  latent_dim, 
                                                                  AttackDetectionModel.reparametrization)
encoder.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  encoder_input (InputLayer)     [(None, 23)]         0           []
#
#  dense (Dense)                  (None, 11)           264         ['encoder_input[0][0]']
#
#  z_mean (Dense)                 (None, 7)            84          ['dense[0][0]']
#
#  z_var (Dense)                  (None, 7)            84          ['dense[0][0]']
#
#  z (Lambda)                     (None, 7)            0           ['z_mean[0][0]',
#                                                                   'z_var[0][0]']
#
# ==================================================================================================
# Total params: 432
# Trainable params: 432
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Decoder
decoder = AttackDetectionModel.vae_decoder(intermediate_dim, latent_dim, original_dim)
outputs = decoder(encoder(inputs))
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  z_sampling (InputLayer)     [(None, 7)]               0
#
#  dense_1 (Dense)             (None, 11)                88
#
#  dense_2 (Dense)             (None, 23)                276
#
# =================================================================
# Total params: 364
# Trainable params: 364
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Hyperparemet Optimization

# %%
def maximize_training(X_train = X_train, 
                      X_test = X_test, 
                      Y_test = Y_test, 
                      inputs = inputs, 
                      outputs = outputs, 
                      vae_loss = vae_loss,
                      learning_rate = learning_rate,
                      batch_size = batch_size,
                      epochs = epochs,
                      anomaly_threshold = anomaly_threshold):    
    
    # Create model
    opt_adam = optimizers.Adam(learning_rate = dict_params['learning_rate'], clipvalue = 0.5)
    model = Model(inputs, outputs, name = 'vae_mlp')
    model.compile(optimizer = opt_adam, loss = vae_loss)

    # Train
    history = model.fit(X_train, 
                        X_train, 
                        shuffle = True, 
                        verbose = 0,
                        epochs = dict_params['epochs'], 
                        batch_size = dict_params['batch_size'])
    
    # Maximize the f1-score
    X_pred_opt = model.predict(X_test)
    error_vector_opt = AttackDetectionModel.get_error_term(X_pred_opt, X_test, _rmse = False)
    Y_pred_opt = (error_vector_opt > anomaly_threshold)
    f1 = f1_score(Y_test, Y_pred_opt)
    
    return f1

# %%
'''
# Apply Bayesian optimization to choose the best hyperparameters

opt = BayesianOptimization(f = maximize_training,
                           pbounds = pbounds,
                           verbose = 2, 
                           random_state = 1)

opt_start = time.time()

opt.maximize(init_points = 5, n_iter = 5)

opt_end = time.time()
opt_time = opt_end - opt_start
print("Optimization time:", opt_time)

learning_rate = opt.max['params']['learning_rate']
epochs = round(opt.max['params']['epochs'])
batch_size = round(opt.max['params']['batch_size'])
'''
# Out:
# '\n# Apply Bayesian optimization to choose the best hyperparameters\n\nopt = BayesianOptimization(f = maximize_training,\n                           pbounds = pbounds,\n                           verbose = 2, \n                           random_state = 1)\n\nopt_start = time.time()\n\nopt.maximize(init_points = 5, n_iter = 5)\n\nopt_end = time.time()\nopt_time = opt_end - opt_start\nprint("Optimization time:", opt_time)\n\nlearning_rate = opt.max[\'params\'][\'learning_rate\']\nepochs = round(opt.max[\'params\'][\'epochs\'])\nbatch_size = round(opt.max[\'params\'][\'batch_size\'])\n'

# %% [markdown]
# # Predict Attacks

# %%
# Training step with the best hyperparameters
learning_rate = 0.0002573457473330052
epochs = 464
batch_size = 78
opt_time = 543.0240316390991
anomaly_threshold = 0.05

# %%
for i in range(1):
    print("Iteration " + str(i))
    
    # Train
    vae_model, train_time = AttackDetectionModel.train(X_train, inputs, outputs, vae_loss, learning_rate, epochs, batch_size)
    
    # Set the optimized anomaly threshold
    #anomaly_threshold = AttackDetectionModel.get_anomaly_threshold(X_train, vae_model)
    
    # Test
    X_pred, test_time = AttackDetectionModel.test(X_test, vae_model)
    Y_test, Y_pred = AttackDetectionModel.get_prediction(Y_test, X_pred, X_test, anomaly_threshold, vae_model)
    
    # Metrics
    acc, f1, pre, rec = AttackDetectionModel.get_scores(Y_test, Y_pred)
    
    # Print results
    AttackDetectionModel.print_results(number_features,
                                       learning_rate,
                                       epochs,
                                       batch_size,
                                       anomaly_threshold,
                                       X_train,
                                       X_test,
                                       opt_time,
                                       train_time,
                                       test_time,
                                       acc,
                                       f1,
                                       pre,
                                       rec,
                                       Y_test,
                                       Y_pred,
                                       "Results/P737_camera.txt")
    
    print("")
# Out:
# Iteration 0
# Train on 43507 samples
# Epoch 1/464
# 43507/43507 [==============================] - 1s 28us/sample - loss: 257.5517
# Epoch 2/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 67.3781
# Epoch 3/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 19.0956
# Epoch 4/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 16.1079
# Epoch 5/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 14.4599
# Epoch 6/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 12.6236
# Epoch 7/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 11.0469
# Epoch 8/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 10.0195
# Epoch 9/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 9.2983
# Epoch 10/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 8.6395
# Epoch 11/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 8.0282
# Epoch 12/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 7.4312
# Epoch 13/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 6.8936
# Epoch 14/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 6.4191
# Epoch 15/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 6.0282
# Epoch 16/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 5.7010
# Epoch 17/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 5.5122
# Epoch 18/464
# 43507/43507 [==============================] - 1s 21us/sample - loss: 5.3366
# Epoch 19/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 5.1570
# Epoch 20/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 5.0477
# Epoch 21/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 4.8770
# Epoch 22/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 4.7481
# Epoch 23/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 4.6607
# Epoch 24/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 4.5333
# Epoch 25/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 4.4425
# Epoch 26/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 4.3606
# Epoch 27/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 4.2913
# Epoch 28/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 4.2377
# Epoch 29/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 4.1432
# Epoch 30/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 4.0934
# Epoch 31/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 4.0539
# Epoch 32/464
# 43507/43507 [==============================] - 1s 21us/sample - loss: 4.0098
# Epoch 33/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 3.9878
# Epoch 34/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.9388
# Epoch 35/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 3.9277
# Epoch 36/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.8940
# Epoch 37/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 3.8846
# Epoch 38/464
# 43507/43507 [==============================] - 1s 21us/sample - loss: 3.8676
# Epoch 39/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.8259
# Epoch 40/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 3.8243
# Epoch 41/464
# 43507/43507 [==============================] - 1s 21us/sample - loss: 3.8174
# Epoch 42/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 3.7840
# Epoch 43/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.7905
# Epoch 44/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.7620
# Epoch 45/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.7591
# Epoch 46/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.7354
# Epoch 47/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.7246
# Epoch 48/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 3.7253
# Epoch 49/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.7145
# Epoch 50/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 3.6883
# Epoch 51/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.6991
# Epoch 52/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 3.6892
# Epoch 53/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.6778
# Epoch 54/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 3.6450
# Epoch 55/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 3.6412
# Epoch 56/464
# 43507/43507 [==============================] - 1s 21us/sample - loss: 3.6489
# Epoch 57/464
# 43507/43507 [==============================] - 1s 27us/sample - loss: 3.6484
# Epoch 58/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 3.6135
# Epoch 59/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 3.6317
# Epoch 60/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.6054
# Epoch 61/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.6110
# Epoch 62/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.5661
# Epoch 63/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 3.6096
# Epoch 64/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.5655
# Epoch 65/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.5719
# Epoch 66/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 3.5624
# Epoch 67/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.5745
# Epoch 68/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.5561
# Epoch 69/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.5623
# Epoch 70/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.5215
# Epoch 71/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.5371
# Epoch 72/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 3.5207
# Epoch 73/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.5310
# Epoch 74/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.5118
# Epoch 75/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.5389
# Epoch 76/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.5031
# Epoch 77/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.5082
# Epoch 78/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 3.4941
# Epoch 79/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 3.5006
# Epoch 80/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 3.5224
# Epoch 81/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 3.4906
# Epoch 82/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 3.5144
# Epoch 83/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 3.4921
# Epoch 84/464
# 43507/43507 [==============================] - 1s 21us/sample - loss: 3.4922
# Epoch 85/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.5037
# Epoch 86/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.4817
# Epoch 87/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.4692
# Epoch 88/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.4959
# Epoch 89/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 3.4645
# Epoch 90/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.4767
# Epoch 91/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.4639
# Epoch 92/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.4545
# Epoch 93/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.4661
# Epoch 94/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.4539
# Epoch 95/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.4653
# Epoch 96/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.4539
# Epoch 97/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.4565
# Epoch 98/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.4431
# Epoch 99/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.4338
# Epoch 100/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.4567
# Epoch 101/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.4561
# Epoch 102/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.4290
# Epoch 103/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.4465
# Epoch 104/464
# 43507/43507 [==============================] - 1s 21us/sample - loss: 3.4370
# Epoch 105/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.4462
# Epoch 106/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.4008
# Epoch 107/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.4286
# Epoch 108/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.4215
# Epoch 109/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.4293
# Epoch 110/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3862
# Epoch 111/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.4186
# Epoch 112/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3845
# Epoch 113/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3823
# Epoch 114/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.4220
# Epoch 115/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3943
# Epoch 116/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.4089
# Epoch 117/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3978
# Epoch 118/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3670
# Epoch 119/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3770
# Epoch 120/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3661
# Epoch 121/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3860
# Epoch 122/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.4043
# Epoch 123/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.4122
# Epoch 124/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3893
# Epoch 125/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3963
# Epoch 126/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3513
# Epoch 127/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3881
# Epoch 128/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3692
# Epoch 129/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3745
# Epoch 130/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3220
# Epoch 131/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3376
# Epoch 132/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3239
# Epoch 133/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3475
# Epoch 134/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3547
# Epoch 135/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3660
# Epoch 136/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 3.3541
# Epoch 137/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3435
# Epoch 138/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 3.3306
# Epoch 139/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3309
# Epoch 140/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3304
# Epoch 141/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3314
# Epoch 142/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3449
# Epoch 143/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3472
# Epoch 144/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 3.3218
# Epoch 145/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3326
# Epoch 146/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 3.3334
# Epoch 147/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3447
# Epoch 148/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3494
# Epoch 149/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3190
# Epoch 150/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.2892
# Epoch 151/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3160
# Epoch 152/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3562
# Epoch 153/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3422
# Epoch 154/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3476
# Epoch 155/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3071
# Epoch 156/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3244
# Epoch 157/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3305
# Epoch 158/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3579
# Epoch 159/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3281
# Epoch 160/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3138
# Epoch 161/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3415
# Epoch 162/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3648
# Epoch 163/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3276
# Epoch 164/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3499
# Epoch 165/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3272
# Epoch 166/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3548
# Epoch 167/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3633
# Epoch 168/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3567
# Epoch 169/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3277
# Epoch 170/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3700
# Epoch 171/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3452
# Epoch 172/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3572
# Epoch 173/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3616
# Epoch 174/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3311
# Epoch 175/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3445
# Epoch 176/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3390
# Epoch 177/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3706
# Epoch 178/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3424
# Epoch 179/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3681
# Epoch 180/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3249
# Epoch 181/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3400
# Epoch 182/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3720
# Epoch 183/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3608
# Epoch 184/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3326
# Epoch 185/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3524
# Epoch 186/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3412
# Epoch 187/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3271
# Epoch 188/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3578
# Epoch 189/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3664
# Epoch 190/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3448
# Epoch 191/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3303
# Epoch 192/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3557
# Epoch 193/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3697
# Epoch 194/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3325
# Epoch 195/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 3.3552
# Epoch 196/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3783
# Epoch 197/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 3.3281
# Epoch 198/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3597
# Epoch 199/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 3.3793
# Epoch 200/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 3.3560
# Epoch 201/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3818
# Epoch 202/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 3.3292
# Epoch 203/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 3.3576
# Epoch 204/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 3.3763
# Epoch 205/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3492
# Epoch 206/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3501
# Epoch 207/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3846
# Epoch 208/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3580
# Epoch 209/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3766
# Epoch 210/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3480
# Epoch 211/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3549
# Epoch 212/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3672
# Epoch 213/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 3.3930
# Epoch 214/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3450
# Epoch 215/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3447
# Epoch 216/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3526
# Epoch 217/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3908
# Epoch 218/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3470
# Epoch 219/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3770
# Epoch 220/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3721
# Epoch 221/464
# 43507/43507 [==============================] - 1s 21us/sample - loss: 3.3368
# Epoch 222/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3309
# Epoch 223/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3477
# Epoch 224/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3515
# Epoch 225/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3554
# Epoch 226/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3543
# Epoch 227/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3553
# Epoch 228/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3510
# Epoch 229/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3488
# Epoch 230/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3270
# Epoch 231/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3211
# Epoch 232/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3355
# Epoch 233/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3396
# Epoch 234/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3064
# Epoch 235/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3245
# Epoch 236/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3234
# Epoch 237/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.2989
# Epoch 238/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.2920
# Epoch 239/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3007
# Epoch 240/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.2874
# Epoch 241/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.2763
# Epoch 242/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.2837
# Epoch 243/464
# 43507/43507 [==============================] - 1s 16us/sample - loss: 3.2798
# Epoch 244/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3536
# Epoch 245/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.2944
# Epoch 246/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.2785
# Epoch 247/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.2616
# Epoch 248/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.2919
# Epoch 249/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3137
# Epoch 250/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.2859
# Epoch 251/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.2748
# Epoch 252/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.2692
# Epoch 253/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.2761
# Epoch 254/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.2759
# Epoch 255/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.2889
# Epoch 256/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.2746
# Epoch 257/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.2659
# Epoch 258/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.2505
# Epoch 259/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.2895
# Epoch 260/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.2915
# Epoch 261/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.2944
# Epoch 262/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.2868
# Epoch 263/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.2726
# Epoch 264/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.2753
# Epoch 265/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.2811
# Epoch 266/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.2976
# Epoch 267/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.2828
# Epoch 268/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.2844
# Epoch 269/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.2703
# Epoch 270/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.2744
# Epoch 271/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3083
# Epoch 272/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3474
# Epoch 273/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3231
# Epoch 274/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3388
# Epoch 275/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3067
# Epoch 276/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.2995
# Epoch 277/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3348
# Epoch 278/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3413
# Epoch 279/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3337
# Epoch 280/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3249
# Epoch 281/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3479
# Epoch 282/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3254
# Epoch 283/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3446
# Epoch 284/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3064
# Epoch 285/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3568
# Epoch 286/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3454
# Epoch 287/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3388
# Epoch 288/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3110
# Epoch 289/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3386
# Epoch 290/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3423
# Epoch 291/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3421
# Epoch 292/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3750
# Epoch 293/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3424
# Epoch 294/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3610
# Epoch 295/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3156
# Epoch 296/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3504
# Epoch 297/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3767
# Epoch 298/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3377
# Epoch 299/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3536
# Epoch 300/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3544
# Epoch 301/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3339
# Epoch 302/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3997
# Epoch 303/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3292
# Epoch 304/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3780
# Epoch 305/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3499
# Epoch 306/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3689
# Epoch 307/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3707
# Epoch 308/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3884
# Epoch 309/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3424
# Epoch 310/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.4034
# Epoch 311/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3692
# Epoch 312/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3763
# Epoch 313/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3351
# Epoch 314/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3687
# Epoch 315/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3534
# Epoch 316/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3703
# Epoch 317/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3760
# Epoch 318/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3923
# Epoch 319/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3660
# Epoch 320/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3973
# Epoch 321/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3591
# Epoch 322/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3944
# Epoch 323/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3882
# Epoch 324/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3930
# Epoch 325/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3693
# Epoch 326/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3637
# Epoch 327/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3751
# Epoch 328/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3843
# Epoch 329/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3496
# Epoch 330/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3530
# Epoch 331/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3638
# Epoch 332/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3477
# Epoch 333/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3755
# Epoch 334/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3776
# Epoch 335/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3933
# Epoch 336/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3688
# Epoch 337/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3785
# Epoch 338/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3779
# Epoch 339/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3393
# Epoch 340/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.4072
# Epoch 341/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3728
# Epoch 342/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3839
# Epoch 343/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3733
# Epoch 344/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3442
# Epoch 345/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3725
# Epoch 346/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3600
# Epoch 347/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3841
# Epoch 348/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3582
# Epoch 349/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3390
# Epoch 350/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3516
# Epoch 351/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3589
# Epoch 352/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3652
# Epoch 353/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3533
# Epoch 354/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3809
# Epoch 355/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3709
# Epoch 356/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3707
# Epoch 357/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3866
# Epoch 358/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3564
# Epoch 359/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3809
# Epoch 360/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3630
# Epoch 361/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3675
# Epoch 362/464
# 43507/43507 [==============================] - 1s 16us/sample - loss: 3.3797
# Epoch 363/464
# 43507/43507 [==============================] - 1s 16us/sample - loss: 3.3857
# Epoch 364/464
# 43507/43507 [==============================] - 1s 16us/sample - loss: 3.3511
# Epoch 365/464
# 43507/43507 [==============================] - 1s 16us/sample - loss: 3.3574
# Epoch 366/464
# 43507/43507 [==============================] - 1s 16us/sample - loss: 3.3704
# Epoch 367/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3828
# Epoch 368/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3614
# Epoch 369/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3810
# Epoch 370/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3648
# Epoch 371/464
# 43507/43507 [==============================] - 1s 16us/sample - loss: 3.3642
# Epoch 372/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3399
# Epoch 373/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3304
# Epoch 374/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3364
# Epoch 375/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3611
# Epoch 376/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3687
# Epoch 377/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3522
# Epoch 378/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.4041
# Epoch 379/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3634
# Epoch 380/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3822
# Epoch 381/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3900
# Epoch 382/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.4016
# Epoch 383/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3728
# Epoch 384/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3773
# Epoch 385/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.3619
# Epoch 386/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.4156
# Epoch 387/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.3796
# Epoch 388/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 3.4214
# Epoch 389/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.4076
# Epoch 390/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 3.4131
# Epoch 391/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.4466
# Epoch 392/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.4422
# Epoch 393/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3809
# Epoch 394/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.4447
# Epoch 395/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.4381
# Epoch 396/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.4113
# Epoch 397/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.4035
# Epoch 398/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.4117
# Epoch 399/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.3808
# Epoch 400/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.4321
# Epoch 401/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.4316
# Epoch 402/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.4231
# Epoch 403/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.4062
# Epoch 404/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.4355
# Epoch 405/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.4132
# Epoch 406/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.4193
# Epoch 407/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.4483
# Epoch 408/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.4570
# Epoch 409/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.4747
# Epoch 410/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.4485
# Epoch 411/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.4604
# Epoch 412/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.4134
# Epoch 413/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.4751
# Epoch 414/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.4656
# Epoch 415/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.4307
# Epoch 416/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.4361
# Epoch 417/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.4360
# Epoch 418/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.4644
# Epoch 419/464
# 43507/43507 [==============================] - 1s 16us/sample - loss: 3.4547
# Epoch 420/464
# 43507/43507 [==============================] - 1s 16us/sample - loss: 3.4338
# Epoch 421/464
# 43507/43507 [==============================] - 1s 16us/sample - loss: 3.4824
# Epoch 422/464
# 43507/43507 [==============================] - 1s 16us/sample - loss: 3.4458
# Epoch 423/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.4821
# Epoch 424/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.4807
# Epoch 425/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.4873
# Epoch 426/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.5053
# Epoch 427/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.4632
# Epoch 428/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.4844
# Epoch 429/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.4618
# Epoch 430/464
# 43507/43507 [==============================] - 1s 17us/sample - loss: 3.5097
# Epoch 431/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.4877
# Epoch 432/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.5059
# Epoch 433/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.4509
# Epoch 434/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.5083
# Epoch 435/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.5130
# Epoch 436/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 3.4747
# Epoch 437/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.4786
# Epoch 438/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.5141
# Epoch 439/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 3.4827
# Epoch 440/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.5261
# Epoch 441/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.5346
# Epoch 442/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.4987
# Epoch 443/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 3.5403
# Epoch 444/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 3.5345
# Epoch 445/464
# 43507/43507 [==============================] - 1s 21us/sample - loss: 3.5260
# Epoch 446/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 3.5524
# Epoch 447/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 3.5157
# Epoch 448/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 3.5226
# Epoch 449/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.5036
# Epoch 450/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.5524
# Epoch 451/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 3.5603
# Epoch 452/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 3.5423
# Epoch 453/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.6109
# Epoch 454/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 3.5282
# Epoch 455/464
# 43507/43507 [==============================] - 1s 21us/sample - loss: 3.5741
# Epoch 456/464
# 43507/43507 [==============================] - 1s 21us/sample - loss: 3.5656
# Epoch 457/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.5417
# Epoch 458/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.6110
# Epoch 459/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.5621
# Epoch 460/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.5880
# Epoch 461/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.5449
# Epoch 462/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.5666
# Epoch 463/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 3.5304
# Epoch 464/464
# 43507/43507 [==============================] - 1s 20us/sample - loss: 3.6388
# Training time: 374.94600343704224
# /home/andressa.amaral/.local/lib/python3.8/site-packages/keras/engine/training_v1.py:2357: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# Testing time: 12.515878915786743

# %% [markdown]
# # Metrics

# %%
# Examinig the latent space generated by the encoder
X_encoded = encoder.predict(X_test)

pca = PCA(n_components=2)
X_analysis = pca.fit_transform(X_encoded)
# Out:
# /home/andressa.amaral/.local/lib/python3.8/site-packages/keras/engine/training_v1.py:2357: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,

# %%
plt.figure(figsize=(8, 8))
sns.scatterplot(x = X_analysis[:, 0], y = X_analysis[:, 1], s = 20, hue = Y_pred)
plt.grid()
plt.savefig("Results/PCA/P7_" + str(number_features))
plt.show()

# Orange ones are anomalies

# %%
plt.figure(figsize = (8, 8))
sns.scatterplot(x = X_analysis[:, 0], y = X_analysis[:, 1], s = 20, hue = Y_test)
plt.grid()
plt.savefig("Results/PCA Groundtruth/P7_" + str(number_features))
plt.show()

# Ground truth

# %%
conf_matrix = confusion_matrix(Y_test, Y_pred)

fig, ax = plt.subplots(figsize = (5, 5))
ax.matshow(conf_matrix, cmap = plt.cm.Blues, alpha = 0.3)
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        ax.text(x = j, y = i,s = conf_matrix[i, j], va = 'center', ha = 'center', size = 'large')
 
plt.xlabel('Predictions', fontsize=12)
plt.ylabel('Actuals', fontsize=12)
plt.title('Confusion Matrix', fontsize=14)
plt.savefig("Results/Confusion Matrix/P7_" + str(number_features))
plt.show()
