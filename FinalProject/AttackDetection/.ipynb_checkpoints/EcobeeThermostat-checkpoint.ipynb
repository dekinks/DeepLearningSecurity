# %%
# !pip3 install pandas
# !pip3 install seaborn
# !pip3 install --upgrade tensorflow-gpu
# !pip3 install import-ipynb
# !pip3 install cuda-python

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 

from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import math
import pickle
import time
import sys

import import_ipynb
import AttackDetectionModel

import tensorflow as tf
tf.compat.v1.disable_eager_execution()
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras import optimizers

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.metrics import f1_score, confusion_matrix

from bayes_opt import BayesianOptimization

# %matplotlib inline
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/andressa.amaral/.local/lib/python3.7/site-packages (1.3.5)
# Requirement already satisfied: numpy>=1.17.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from pandas) (1.21.5)
# Requirement already satisfied: pytz>=2017.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from pandas) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# WARNING: You are using pip version 22.0.4; however, version 22.3 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in /home/andressa.amaral/.local/lib/python3.7/site-packages (0.11.2)
# Requirement already satisfied: numpy>=1.15 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from seaborn) (1.21.5)
# Requirement already satisfied: pandas>=0.23 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from seaborn) (1.3.5)
# Requirement already satisfied: matplotlib>=2.2 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from seaborn) (3.5.1)
# Requirement already satisfied: scipy>=1.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from seaborn) (1.7.3)
# Requirement already satisfied: packaging>=20.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (3.0.7)
# Requirement already satisfied: cycler>=0.10 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (1.4.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (9.0.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (4.31.1)
# Requirement already satisfied: pytz>=2017.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from pandas>=0.23->seaborn) (2022.1)
# Requirement already satisfied: typing-extensions in /home/andressa.amaral/.local/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib>=2.2->seaborn) (4.1.1)
# Requirement already satisfied: six>=1.5 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# WARNING: You are using pip version 22.0.4; however, version 22.3 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow-gpu in /home/andressa.amaral/.local/lib/python3.7/site-packages (2.10.0)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (2.10.0)
# Requirement already satisfied: absl-py>=1.0.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.0.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (4.1.1)
# Requirement already satisfied: wrapt>=1.11.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.14.0)
# Requirement already satisfied: six>=1.12.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.16.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (0.4.0)
# Requirement already satisfied: flatbuffers>=2.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (2.0.7)
# Requirement already satisfied: keras<2.11,>=2.10.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (2.10.0)
# Requirement already satisfied: numpy>=1.20 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.21.5)
# Requirement already satisfied: packaging in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (21.3)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (0.2.0)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (2.10.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (0.24.0)
# Requirement already satisfied: h5py>=2.9.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (3.6.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.1.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.44.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (3.19.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (3.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.6.3)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.1.2)
# Requirement already satisfied: setuptools in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (60.10.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (13.0.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/lib/python3/dist-packages (from astunparse>=1.6.0->tensorflow-gpu) (0.30.0)
# Requirement already satisfied: cached-property in /home/andressa.amaral/.local/lib/python3.7/site-packages (from h5py>=2.9.0->tensorflow-gpu) (1.5.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (2.6.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (2.0.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (3.3.6)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (0.4.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (2.27.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from packaging->tensorflow-gpu) (3.0.7)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow-gpu) (4.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow-gpu) (5.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow-gpu) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow-gpu) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow-gpu) (4.11.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow-gpu) (2018.1.18)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow-gpu) (2.6)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow-gpu) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow-gpu) (1.22)
# Requirement already satisfied: zipp>=0.5 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow-gpu) (3.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow-gpu) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow-gpu) (3.2.0)
# WARNING: You are using pip version 22.0.4; however, version 22.3 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: import-ipynb in /home/andressa.amaral/.local/lib/python3.7/site-packages (0.1.3)
# WARNING: You are using pip version 22.0.4; however, version 22.3 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: cuda-python in /home/andressa.amaral/.local/lib/python3.7/site-packages (11.8.0)
# Requirement already satisfied: cython in /home/andressa.amaral/.local/lib/python3.7/site-packages (from cuda-python) (0.29.32)
# WARNING: You are using pip version 22.0.4; however, version 22.3 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# importing Jupyter notebook from AttackDetectionModel.ipynb
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/andressa.amaral/.local/lib/python3.7/site-packages (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from pandas) (1.21.5)
# Requirement already satisfied: pytz>=2017.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from pandas) (2022.1)
# Requirement already satisfied: six>=1.5 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# WARNING: You are using pip version 22.0.4; however, version 22.3 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow-gpu in /home/andressa.amaral/.local/lib/python3.7/site-packages (2.10.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.44.0)
# Requirement already satisfied: setuptools in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (60.10.0)
# Requirement already satisfied: flatbuffers>=2.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (2.0.7)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (2.10.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (0.2.0)
# Requirement already satisfied: six>=1.12.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.16.0)
# Requirement already satisfied: h5py>=2.9.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (3.6.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.1.0)
# Requirement already satisfied: absl-py>=1.0.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.0.0)
# Requirement already satisfied: numpy>=1.20 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.21.5)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (2.10.0)
# Requirement already satisfied: packaging in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (21.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (0.24.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (0.4.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.1.2)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (3.19.4)
# Requirement already satisfied: keras<2.11,>=2.10.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (2.10.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (3.3.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (13.0.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.14.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (4.1.1)
# Requirement already satisfied: astunparse>=1.6.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.6.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/lib/python3/dist-packages (from astunparse>=1.6.0->tensorflow-gpu) (0.30.0)
# Requirement already satisfied: cached-property in /home/andressa.amaral/.local/lib/python3.7/site-packages (from h5py>=2.9.0->tensorflow-gpu) (1.5.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (2.6.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (2.0.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (2.27.1)
# Requirement already satisfied: markdown>=2.6.8 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (3.3.6)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from packaging->tensorflow-gpu) (3.0.7)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow-gpu) (5.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow-gpu) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow-gpu) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow-gpu) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow-gpu) (4.11.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow-gpu) (1.22)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow-gpu) (2.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow-gpu) (2018.1.18)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow-gpu) (2.0.12)
# Requirement already satisfied: zipp>=0.5 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow-gpu) (3.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow-gpu) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow-gpu) (3.2.0)
# WARNING: You are using pip version 22.0.4; however, version 22.3 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
gpu_options = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction = 0.333)
sess = tf.compat.v1.Session(config = tf.compat.v1.ConfigProto(gpu_options = gpu_options))

# %% [markdown]
# # Data Pre-Processing

# %%
#number_features = 115
#number_features = 92
number_features = 69
#number_features = 46
#number_features = 23

# %%
# Get benign traffic 
df_et_benign = AttackDetectionModel.get_files('../../nbaiot/Ecobee_Thermostat', number_features)

# Get Bashlite traffic
df_et_bashlite = AttackDetectionModel.get_files('../../nbaiot/Ecobee_Thermostat/gafgyt', number_features)

# Get Mirai traffic
df_et_mirai = AttackDetectionModel.get_files('../../nbaiot/Ecobee_Thermostat/mirai', number_features)

# %%
# Normalize with the min-max scaler
scaler = MinMaxScaler()
df_et_benign_norm = scaler.fit_transform(df_et_benign)
df_et_bashlite_norm = scaler.fit_transform(df_et_bashlite)
df_et_mirai_norm = scaler.fit_transform(df_et_mirai)

# %% [markdown]
# # Sets

# %%
# Train set
len_benign_train = int(0.7 * len(df_et_benign_norm))
X_train = df_et_benign_norm[:len_benign_train]

# %%
# Test set
X_test_benign = df_et_benign_norm[len_benign_train:]
X_test = np.concatenate([X_test_benign, df_et_bashlite_norm, df_et_mirai_norm])

Y_test = np.ones(len(X_test))
Y_test[:len(X_test_benign)] = 0

# %% [markdown]
# # Model

# %%
# Parameters
original_dim = X_train.shape[1]
input_shape = (original_dim,)
intermediate_dim = int(original_dim / 2)
latent_dim = int(original_dim / 3)

# Initial values
epochs = 5
learning_rate = 0.0001
batch_size = 20
anomaly_threshold = 0.05

# Dictionary
dict_params = { 'learning_rate': learning_rate, 'batch_size': round(batch_size), 'epochs': round(epochs)}
pbounds = { 'learning_rate': (0.000001, 0.001), 'batch_size': (10, 100), 'epochs': (50, 500)}

# %%
# KL Loss function
def vae_loss(x, x_decoded_mean):
    # Compute the average MSE error, then scale it up (sum on all axes)
    
    reconstruction_loss = K.sum(K.square(x - x_decoded_mean))
    
    # Compute the KL loss
    
    kl_loss = - 0.5 * K.sum(1 + z_var - K.square(z_mean) - K.square(K.exp(z_var)), axis=-1)
    
    # Return the average loss over all 
    
    total_loss = K.mean(reconstruction_loss + kl_loss) # Total_loss = reconstruction_loss + kl_loss 
    return total_loss

# (1) Reconstruction Loss - Forces the encoder to generate latent features that minimize the reconstruction error, or else is
# penalized
# (2) KL Loss - Forces the distribution generated by the encoder to be similar to the prior probability of the input vector, 
# pushing latent feature space to normality

# %%
# Encoder
inputs, encoder, z_var, z_mean = AttackDetectionModel.vae_encoder(input_shape, 
                                                                  intermediate_dim, 
                                                                  latent_dim, 
                                                                  AttackDetectionModel.reparametrization)
encoder.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  encoder_input (InputLayer)     [(None, 69)]         0           []
#
#  dense (Dense)                  (None, 34)           2380        ['encoder_input[0][0]']
#
#  z_mean (Dense)                 (None, 23)           805         ['dense[0][0]']
#
#  z_var (Dense)                  (None, 23)           805         ['dense[0][0]']
#
#  z (Lambda)                     (None, 23)           0           ['z_mean[0][0]',
#                                                                   'z_var[0][0]']
#
# ==================================================================================================
# Total params: 3,990
# Trainable params: 3,990
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Decoder
decoder = AttackDetectionModel.vae_decoder(intermediate_dim, latent_dim, original_dim)
outputs = decoder(encoder(inputs))
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  z_sampling (InputLayer)     [(None, 23)]              0
#
#  dense_1 (Dense)             (None, 34)                816
#
#  dense_2 (Dense)             (None, 69)                2415
#
# =================================================================
# Total params: 3,231
# Trainable params: 3,231
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Hyperparameter Optimization

# %%
def maximize_training(X_train = X_train, 
                      X_test = X_test, 
                      Y_test = Y_test, 
                      inputs = inputs, 
                      outputs = outputs, 
                      vae_loss = vae_loss,
                      learning_rate = learning_rate,
                      batch_size = batch_size,
                      epochs = epochs,
                      anomaly_threshold = anomaly_threshold):    
    
    # Create model
    opt_adam = optimizers.Adam(learning_rate = dict_params['learning_rate'], clipvalue = 0.5)
    model = Model(inputs, outputs, name = 'vae_mlp')
    model.compile(optimizer = opt_adam, loss = vae_loss)

    # Train
    history = model.fit(X_train, 
                        X_train, 
                        shuffle = True, 
                        verbose = 0,
                        epochs = dict_params['epochs'], 
                        batch_size = dict_params['batch_size'])
    
    # Maximize the f1-score
    X_pred_opt = model.predict(X_test)
    error_vector_opt = AttackDetectionModel.get_error_term(X_pred_opt, X_test, _rmse = False)
    Y_pred_opt = (error_vector_opt > anomaly_threshold)
    f1 = f1_score(Y_test, Y_pred_opt)
    
    return f1

# %%
'''
# Apply Bayesian optimization to choose the best hyperparameters

opt = BayesianOptimization(f = maximize_training,
                           pbounds = pbounds,
                           verbose = 2, 
                           random_state = 1)

opt_start = time.time()

opt.maximize(init_points = 5, n_iter = 5)

opt_end = time.time()
opt_time = opt_end - opt_start
print("Optimization time:", opt_time)

learning_rate = opt.max['params']['learning_rate']
epochs = round(opt.max['params']['epochs'])
batch_size = round(opt.max['params']['batch_size'])
'''
# Out:
# '\n# Apply Bayesian optimization to choose the best hyperparameters\n\nopt = BayesianOptimization(f = maximize_training,\n                           pbounds = pbounds,\n                           verbose = 2, \n                           random_state = 1)\n\nopt_start = time.time()\n\nopt.maximize(init_points = 5, n_iter = 5)\n\nopt_end = time.time()\nopt_time = opt_end - opt_start\nprint("Optimization time:", opt_time)\n\nlearning_rate = opt.max[\'params\'][\'learning_rate\']\nepochs = round(opt.max[\'params\'][\'epochs\'])\nbatch_size = round(opt.max[\'params\'][\'batch_size\'])\n'

# %% [markdown]
# # Predict Attacks

# %%
# Training step with the best hyperparameters
learning_rate = 0.00012123446827562964
epochs = 422
batch_size = 74
opt_time = 262.7667851448059
#anomaly_threshold = 0.15

# %%
for i in range(1):
    print("Iteration " + str(i))
    
    # Train
    vae_model, train_time = AttackDetectionModel.train(X_train, inputs, outputs, vae_loss, learning_rate, epochs, batch_size)
    
    # Set the optimized anomaly threshold
    anomaly_threshold = AttackDetectionModel.get_anomaly_threshold(X_train, vae_model)
    
    # Test
    X_pred, test_time = AttackDetectionModel.test(X_test, vae_model)
    Y_test, Y_pred = AttackDetectionModel.get_prediction(Y_test, X_pred, X_test, anomaly_threshold, vae_model)
    
    # Metrics
    acc, f1, pre, rec = AttackDetectionModel.get_scores(Y_test, Y_pred)
    
    # Print results
    AttackDetectionModel.print_results(number_features,
                                       learning_rate,
                                       epochs,
                                       batch_size,
                                       anomaly_threshold,
                                       X_train,
                                       X_test,
                                       opt_time,
                                       train_time,
                                       test_time,
                                       acc,
                                       f1,
                                       pre,
                                       rec,
                                       Y_test,
                                       Y_pred,
                                       "Results/ecobee_thermostat.txt")
    
    print("")
# Out:
# Iteration 0
# Train on 9179 samples
# Epoch 1/422
# 9179/9179 [==============================] - 1s 58us/sample - loss: 801.3790
# Epoch 2/422
# 9179/9179 [==============================] - 0s 35us/sample - loss: 610.2465
# Epoch 3/422
# 9179/9179 [==============================] - 0s 32us/sample - loss: 399.8119
# Epoch 4/422
# 9179/9179 [==============================] - 0s 38us/sample - loss: 215.2598
# Epoch 5/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 118.7838
# Epoch 6/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 77.7395
# Epoch 7/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 61.2484
# Epoch 8/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 53.4707
# Epoch 9/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 48.0251
# Epoch 10/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 43.0209
# Epoch 11/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 39.1225
# Epoch 12/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 35.8372
# Epoch 13/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 33.5512
# Epoch 14/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 32.0954
# Epoch 15/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 30.8809
# Epoch 16/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 30.0627
# Epoch 17/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 28.9372
# Epoch 18/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 28.3150
# Epoch 19/422
# 9179/9179 [==============================] - 0s 40us/sample - loss: 27.3321
# Epoch 20/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 26.7995
# Epoch 21/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 25.9466
# Epoch 22/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 25.2941
# Epoch 23/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 24.7298
# Epoch 24/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 24.0545
# Epoch 25/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 23.6569
# Epoch 26/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 22.9649
# Epoch 27/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 22.3193
# Epoch 28/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 21.7582
# Epoch 29/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 21.3278
# Epoch 30/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 20.8613
# Epoch 31/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 20.4585
# Epoch 32/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 20.0291
# Epoch 33/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 19.7078
# Epoch 34/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 19.1695
# Epoch 35/422
# 9179/9179 [==============================] - 0s 40us/sample - loss: 18.9016
# Epoch 36/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 18.5260
# Epoch 37/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 18.1536
# Epoch 38/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 17.9656
# Epoch 39/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 17.6602
# Epoch 40/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 17.4069
# Epoch 41/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 17.1198
# Epoch 42/422
# 9179/9179 [==============================] - 0s 43us/sample - loss: 16.7470
# Epoch 43/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 16.5421
# Epoch 44/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 16.3321
# Epoch 45/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 16.0936
# Epoch 46/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 15.8370
# Epoch 47/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 15.6356
# Epoch 48/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 15.3494
# Epoch 49/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 15.1934
# Epoch 50/422
# 9179/9179 [==============================] - 0s 40us/sample - loss: 14.8697
# Epoch 51/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 14.6839
# Epoch 52/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 14.5846
# Epoch 53/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 14.3786
# Epoch 54/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 14.2665
# Epoch 55/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 14.0164
# Epoch 56/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 13.8227
# Epoch 57/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 13.5305
# Epoch 58/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 13.5843
# Epoch 59/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 13.2767
# Epoch 60/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 13.1264
# Epoch 61/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 13.0260
# Epoch 62/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 12.8592
# Epoch 63/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 12.6391
# Epoch 64/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 12.5563
# Epoch 65/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 12.4360
# Epoch 66/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 12.3820
# Epoch 67/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 12.1436
# Epoch 68/422
# 9179/9179 [==============================] - 0s 40us/sample - loss: 12.1315
# Epoch 69/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 12.0416
# Epoch 70/422
# 9179/9179 [==============================] - 0s 40us/sample - loss: 11.9171
# Epoch 71/422
# 9179/9179 [==============================] - 0s 37us/sample - loss: 11.7712
# Epoch 72/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 11.6436
# Epoch 73/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 11.5197
# Epoch 74/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 11.3575
# Epoch 75/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 11.3619
# Epoch 76/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 11.2277
# Epoch 77/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 11.1099
# Epoch 78/422
# 9179/9179 [==============================] - 0s 43us/sample - loss: 10.9680
# Epoch 79/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 10.9658
# Epoch 80/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 10.9297
# Epoch 81/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 10.7253
# Epoch 82/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 10.7604
# Epoch 83/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 10.5281
# Epoch 84/422
# 9179/9179 [==============================] - 0s 40us/sample - loss: 10.5411
# Epoch 85/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 10.4173
# Epoch 86/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 10.3070
# Epoch 87/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 10.2294
# Epoch 88/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 10.2818
# Epoch 89/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 10.1349
# Epoch 90/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 9.9683
# Epoch 91/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 9.9919
# Epoch 92/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 9.8628
# Epoch 93/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 9.8192
# Epoch 94/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 9.7318
# Epoch 95/422
# 9179/9179 [==============================] - 0s 43us/sample - loss: 9.7134
# Epoch 96/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 9.6293
# Epoch 97/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 9.5309
# Epoch 98/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 9.4178
# Epoch 99/422
# 9179/9179 [==============================] - 0s 43us/sample - loss: 9.4814
# Epoch 100/422
# 9179/9179 [==============================] - 0s 43us/sample - loss: 9.3533
# Epoch 101/422
# 9179/9179 [==============================] - 0s 43us/sample - loss: 9.2413
# Epoch 102/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 9.1981
# Epoch 103/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 9.1399
# Epoch 104/422
# 9179/9179 [==============================] - 0s 43us/sample - loss: 9.0539
# Epoch 105/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 9.0781
# Epoch 106/422
# 9179/9179 [==============================] - 0s 40us/sample - loss: 9.0055
# Epoch 107/422
# 9179/9179 [==============================] - 0s 40us/sample - loss: 8.9704
# Epoch 108/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 8.9579
# Epoch 109/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 8.8177
# Epoch 110/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 8.8105
# Epoch 111/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 8.8107
# Epoch 112/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 8.6669
# Epoch 113/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 8.6710
# Epoch 114/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 8.7072
# Epoch 115/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 8.6458
# Epoch 116/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 8.5456
# Epoch 117/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 8.4997
# Epoch 118/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 8.4233
# Epoch 119/422
# 9179/9179 [==============================] - 0s 43us/sample - loss: 8.3344
# Epoch 120/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 8.3854
# Epoch 121/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 8.3041
# Epoch 122/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 8.3038
# Epoch 123/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 8.2463
# Epoch 124/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 8.1659
# Epoch 125/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 8.1760
# Epoch 126/422
# 9179/9179 [==============================] - 0s 40us/sample - loss: 8.0731
# Epoch 127/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 8.0934
# Epoch 128/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 7.9871
# Epoch 129/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 8.0525
# Epoch 130/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 7.9228
# Epoch 131/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 7.9269
# Epoch 132/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 7.8062
# Epoch 133/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 7.9049
# Epoch 134/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 7.8706
# Epoch 135/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 7.8272
# Epoch 136/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 7.8166
# Epoch 137/422
# 9179/9179 [==============================] - 0s 39us/sample - loss: 7.7969
# Epoch 138/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 7.7153
# Epoch 139/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 7.5852
# Epoch 140/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 7.6145
# Epoch 141/422
# 9179/9179 [==============================] - 0s 40us/sample - loss: 7.6422
# Epoch 142/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 7.6032
# Epoch 143/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 7.5269
# Epoch 144/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 7.5480
# Epoch 145/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 7.4791
# Epoch 146/422
# 9179/9179 [==============================] - 0s 43us/sample - loss: 7.5426
# Epoch 147/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 7.5233
# Epoch 148/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 7.4218
# Epoch 149/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 7.3815
# Epoch 150/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 7.3840
# Epoch 151/422
# 9179/9179 [==============================] - 0s 40us/sample - loss: 7.3901
# Epoch 152/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 7.2651
# Epoch 153/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 7.2777
# Epoch 154/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 7.2544
# Epoch 155/422
# 9179/9179 [==============================] - 0s 43us/sample - loss: 7.2084
# Epoch 156/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 7.2161
# Epoch 157/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 7.1864
# Epoch 158/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 7.1768
# Epoch 159/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 7.1224
# Epoch 160/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 7.0862
# Epoch 161/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 7.0846
# Epoch 162/422
# 9179/9179 [==============================] - 0s 43us/sample - loss: 7.0774
# Epoch 163/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 7.0632
# Epoch 164/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 7.0348
# Epoch 165/422
# 9179/9179 [==============================] - 0s 43us/sample - loss: 6.9880
# Epoch 166/422
# 9179/9179 [==============================] - 0s 43us/sample - loss: 6.9471
# Epoch 167/422
# 9179/9179 [==============================] - 0s 43us/sample - loss: 6.9762
# Epoch 168/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 6.9254
# Epoch 169/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 6.9057
# Epoch 170/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 6.8973
# Epoch 171/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 6.8642
# Epoch 172/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 6.8606
# Epoch 173/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 6.8257
# Epoch 174/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 6.7935
# Epoch 175/422
# 9179/9179 [==============================] - 0s 43us/sample - loss: 6.8089
# Epoch 176/422
# 9179/9179 [==============================] - 0s 43us/sample - loss: 6.7642
# Epoch 177/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 6.7928
# Epoch 178/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 6.7267
# Epoch 179/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 6.7542
# Epoch 180/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 6.6754
# Epoch 181/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 6.6906
# Epoch 182/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 6.7017
# Epoch 183/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 6.6501
# Epoch 184/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 6.6803
# Epoch 185/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 6.5957
# Epoch 186/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 6.6017
# Epoch 187/422
# 9179/9179 [==============================] - 0s 40us/sample - loss: 6.5191
# Epoch 188/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 6.5613
# Epoch 189/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 6.5673
# Epoch 190/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 6.5446
# Epoch 191/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 6.5686
# Epoch 192/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 6.5068
# Epoch 193/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 6.4740
# Epoch 194/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 6.4751
# Epoch 195/422
# 9179/9179 [==============================] - 0s 43us/sample - loss: 6.4215
# Epoch 196/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 6.4172
# Epoch 197/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 6.4436
# Epoch 198/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 6.4327
# Epoch 199/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 6.4117
# Epoch 200/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 6.3927
# Epoch 201/422
# 9179/9179 [==============================] - 0s 40us/sample - loss: 6.3601
# Epoch 202/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 6.3675
# Epoch 203/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 6.3733
# Epoch 204/422
# 9179/9179 [==============================] - 0s 43us/sample - loss: 6.3891
# Epoch 205/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 6.3031
# Epoch 206/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 6.3329
# Epoch 207/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 6.2675
# Epoch 208/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 6.3079
# Epoch 209/422
# 9179/9179 [==============================] - 0s 40us/sample - loss: 6.2446
# Epoch 210/422
# 9179/9179 [==============================] - 0s 43us/sample - loss: 6.2892
# Epoch 211/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 6.2520
# Epoch 212/422
# 9179/9179 [==============================] - 0s 40us/sample - loss: 6.2569
# Epoch 213/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 6.2614
# Epoch 214/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 6.2054
# Epoch 215/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 6.1808
# Epoch 216/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 6.1931
# Epoch 217/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 6.1766
# Epoch 218/422
# 9179/9179 [==============================] - 0s 40us/sample - loss: 6.1417
# Epoch 219/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 6.1464
# Epoch 220/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 6.1410
# Epoch 221/422
# 9179/9179 [==============================] - 0s 43us/sample - loss: 6.1723
# Epoch 222/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 6.1742
# Epoch 223/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 6.1063
# Epoch 224/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 6.1275
# Epoch 225/422
# 9179/9179 [==============================] - 0s 40us/sample - loss: 6.0488
# Epoch 226/422
# 9179/9179 [==============================] - 0s 40us/sample - loss: 6.1143
# Epoch 227/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 6.1174
# Epoch 228/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 6.1272
# Epoch 229/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 6.0475
# Epoch 230/422
# 9179/9179 [==============================] - 0s 40us/sample - loss: 6.0734
# Epoch 231/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 6.0678
# Epoch 232/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 6.0213
# Epoch 233/422
# 9179/9179 [==============================] - 0s 39us/sample - loss: 6.0726
# Epoch 234/422
# 9179/9179 [==============================] - 0s 36us/sample - loss: 6.0276
# Epoch 235/422
# 9179/9179 [==============================] - 0s 34us/sample - loss: 5.9993
# Epoch 236/422
# 9179/9179 [==============================] - 0s 34us/sample - loss: 6.0559
# Epoch 237/422
# 9179/9179 [==============================] - 0s 35us/sample - loss: 5.9578
# Epoch 238/422
# 9179/9179 [==============================] - 0s 35us/sample - loss: 5.9964
# Epoch 239/422
# 9179/9179 [==============================] - 0s 35us/sample - loss: 5.9969
# Epoch 240/422
# 9179/9179 [==============================] - 0s 35us/sample - loss: 5.9775
# Epoch 241/422
# 9179/9179 [==============================] - 0s 29us/sample - loss: 5.9451
# Epoch 242/422
# 9179/9179 [==============================] - 0s 28us/sample - loss: 5.9630
# Epoch 243/422
# 9179/9179 [==============================] - 0s 26us/sample - loss: 5.9349
# Epoch 244/422
# 9179/9179 [==============================] - 0s 24us/sample - loss: 5.9670
# Epoch 245/422
# 9179/9179 [==============================] - 0s 26us/sample - loss: 5.9199
# Epoch 246/422
# 9179/9179 [==============================] - 0s 25us/sample - loss: 5.9290
# Epoch 247/422
# 9179/9179 [==============================] - 0s 36us/sample - loss: 5.9337
# Epoch 248/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.9286
# Epoch 249/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.8942
# Epoch 250/422
# 9179/9179 [==============================] - 0s 40us/sample - loss: 5.8724
# Epoch 251/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.8598
# Epoch 252/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.8726
# Epoch 253/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.8934
# Epoch 254/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.8684
# Epoch 255/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.8941
# Epoch 256/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.8910
# Epoch 257/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.8593
# Epoch 258/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.8261
# Epoch 259/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.8485
# Epoch 260/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.8395
# Epoch 261/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.8014
# Epoch 262/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.8347
# Epoch 263/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.8272
# Epoch 264/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.8182
# Epoch 265/422
# 9179/9179 [==============================] - 0s 43us/sample - loss: 5.7571
# Epoch 266/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.8023
# Epoch 267/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.7744
# Epoch 268/422
# 9179/9179 [==============================] - 0s 40us/sample - loss: 5.8260
# Epoch 269/422
# 9179/9179 [==============================] - 0s 40us/sample - loss: 5.7847
# Epoch 270/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.7261
# Epoch 271/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.7348
# Epoch 272/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.8228
# Epoch 273/422
# 9179/9179 [==============================] - 0s 43us/sample - loss: 5.7475
# Epoch 274/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.7703
# Epoch 275/422
# 9179/9179 [==============================] - 0s 39us/sample - loss: 5.7451
# Epoch 276/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.7395
# Epoch 277/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.6810
# Epoch 278/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.7147
# Epoch 279/422
# 9179/9179 [==============================] - 0s 40us/sample - loss: 5.7317
# Epoch 280/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.7363
# Epoch 281/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.7192
# Epoch 282/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.7076
# Epoch 283/422
# 9179/9179 [==============================] - 0s 40us/sample - loss: 5.7128
# Epoch 284/422
# 9179/9179 [==============================] - 0s 39us/sample - loss: 5.6915
# Epoch 285/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.6789
# Epoch 286/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.6524
# Epoch 287/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.6851
# Epoch 288/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.6711
# Epoch 289/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.6699
# Epoch 290/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.6692
# Epoch 291/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.6579
# Epoch 292/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.6457
# Epoch 293/422
# 9179/9179 [==============================] - 0s 43us/sample - loss: 5.6634
# Epoch 294/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.7229
# Epoch 295/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.6373
# Epoch 296/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.6415
# Epoch 297/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.6109
# Epoch 298/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.6351
# Epoch 299/422
# 9179/9179 [==============================] - 0s 40us/sample - loss: 5.5926
# Epoch 300/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.5971
# Epoch 301/422
# 9179/9179 [==============================] - 0s 39us/sample - loss: 5.6517
# Epoch 302/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.6343
# Epoch 303/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.6244
# Epoch 304/422
# 9179/9179 [==============================] - 0s 40us/sample - loss: 5.6117
# Epoch 305/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.5949
# Epoch 306/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.6551
# Epoch 307/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.6390
# Epoch 308/422
# 9179/9179 [==============================] - 0s 43us/sample - loss: 5.6088
# Epoch 309/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.5967
# Epoch 310/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.5620
# Epoch 311/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.5561
# Epoch 312/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.6114
# Epoch 313/422
# 9179/9179 [==============================] - 0s 40us/sample - loss: 5.5663
# Epoch 314/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.5590
# Epoch 315/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.5852
# Epoch 316/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.5872
# Epoch 317/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.5820
# Epoch 318/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.6112
# Epoch 319/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.5168
# Epoch 320/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.5780
# Epoch 321/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.5734
# Epoch 322/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.5588
# Epoch 323/422
# 9179/9179 [==============================] - 0s 40us/sample - loss: 5.5448
# Epoch 324/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.5417
# Epoch 325/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.5106
# Epoch 326/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.4802
# Epoch 327/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.4881
# Epoch 328/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.5573
# Epoch 329/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.5113
# Epoch 330/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.5428
# Epoch 331/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.5241
# Epoch 332/422
# 9179/9179 [==============================] - 0s 43us/sample - loss: 5.5105
# Epoch 333/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.5248
# Epoch 334/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.4998
# Epoch 335/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.5176
# Epoch 336/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.4845
# Epoch 337/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.5236
# Epoch 338/422
# 9179/9179 [==============================] - 0s 40us/sample - loss: 5.5045
# Epoch 339/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.5102
# Epoch 340/422
# 9179/9179 [==============================] - 0s 43us/sample - loss: 5.5210
# Epoch 341/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.4938
# Epoch 342/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.5004
# Epoch 343/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.5294
# Epoch 344/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.5409
# Epoch 345/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.5017
# Epoch 346/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.4867
# Epoch 347/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.4943
# Epoch 348/422
# 9179/9179 [==============================] - 0s 40us/sample - loss: 5.5029
# Epoch 349/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.4675
# Epoch 350/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.4911
# Epoch 351/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.4498
# Epoch 352/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.4511
# Epoch 353/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.4858
# Epoch 354/422
# 9179/9179 [==============================] - 0s 40us/sample - loss: 5.4701
# Epoch 355/422
# 9179/9179 [==============================] - 0s 43us/sample - loss: 5.4299
# Epoch 356/422
# 9179/9179 [==============================] - 0s 40us/sample - loss: 5.4434
# Epoch 357/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.4337
# Epoch 358/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.4401
# Epoch 359/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.4269
# Epoch 360/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.4722
# Epoch 361/422
# 9179/9179 [==============================] - 0s 40us/sample - loss: 5.4416
# Epoch 362/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.4037
# Epoch 363/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.4681
# Epoch 364/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.3688
# Epoch 365/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.4589
# Epoch 366/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.4279
# Epoch 367/422
# 9179/9179 [==============================] - 0s 39us/sample - loss: 5.4001
# Epoch 368/422
# 9179/9179 [==============================] - 0s 43us/sample - loss: 5.4080
# Epoch 369/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.3894
# Epoch 370/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.3940
# Epoch 371/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.4292
# Epoch 372/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.4054
# Epoch 373/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.4311
# Epoch 374/422
# 9179/9179 [==============================] - 0s 40us/sample - loss: 5.4480
# Epoch 375/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.3980
# Epoch 376/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.3984
# Epoch 377/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.4245
# Epoch 378/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.4269
# Epoch 379/422
# 9179/9179 [==============================] - 0s 43us/sample - loss: 5.4436
# Epoch 380/422
# 9179/9179 [==============================] - 0s 43us/sample - loss: 5.3754
# Epoch 381/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.4124
# Epoch 382/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.4110
# Epoch 383/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.3628
# Epoch 384/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.3968
# Epoch 385/422
# 9179/9179 [==============================] - 0s 40us/sample - loss: 5.3736
# Epoch 386/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.4535
# Epoch 387/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.3763
# Epoch 388/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.4141
# Epoch 389/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.3936
# Epoch 390/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.3792
# Epoch 391/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.3660
# Epoch 392/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.4049
# Epoch 393/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.3671
# Epoch 394/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.3402
# Epoch 395/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.3613
# Epoch 396/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.3426
# Epoch 397/422
# 9179/9179 [==============================] - 0s 43us/sample - loss: 5.3457
# Epoch 398/422
# 9179/9179 [==============================] - 0s 39us/sample - loss: 5.3810
# Epoch 399/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.3243
# Epoch 400/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.3544
# Epoch 401/422
# 9179/9179 [==============================] - 0s 40us/sample - loss: 5.3467
# Epoch 402/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.3659
# Epoch 403/422
# 9179/9179 [==============================] - 0s 40us/sample - loss: 5.3202
# Epoch 404/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.3399
# Epoch 405/422
# 9179/9179 [==============================] - 0s 43us/sample - loss: 5.3867
# Epoch 406/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.3269
# Epoch 407/422
# 9179/9179 [==============================] - 0s 40us/sample - loss: 5.3672
# Epoch 408/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.3191
# Epoch 409/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.3652
# Epoch 410/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.3476
# Epoch 411/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.2902
# Epoch 412/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.3434
# Epoch 413/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.3222
# Epoch 414/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.3473
# Epoch 415/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.3369
# Epoch 416/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.3413
# Epoch 417/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.3137
# Epoch 418/422
# 9179/9179 [==============================] - 0s 41us/sample - loss: 5.3186
# Epoch 419/422
# 9179/9179 [==============================] - 0s 39us/sample - loss: 5.3985
# Epoch 420/422
# 9179/9179 [==============================] - 0s 42us/sample - loss: 5.3054
# Epoch 421/422
# 9179/9179 [==============================] - 0s 43us/sample - loss: 5.3263
# Epoch 422/422
# 9179/9179 [==============================] - 0s 40us/sample - loss: 5.3316
# Training time: 160.16580533981323
# /home/andressa.amaral/.local/lib/python3.7/site-packages/keras/engine/training_v1.py:2356: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# Testing time: 34.60032534599304

# %% [markdown]
# # Metrics

# %%
# Examinig the latent space generated by the encoder
X_encoded = encoder.predict(X_test)

pca = PCA(n_components=2)
X_analysis = pca.fit_transform(X_encoded)
# Out:
# /home/andressa.amaral/.local/lib/python3.7/site-packages/keras/engine/training_v1.py:2356: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,

# %%
plt.figure(figsize=(8, 8))
sns.scatterplot(x = X_analysis[:, 0], y = X_analysis[:, 1], s = 20, hue = Y_pred)
plt.grid()
plt.savefig("Results/PCA/ET_" + str(number_features))
plt.show()

# Orange ones are anomalies

# %%
plt.figure(figsize = (8, 8))
sns.scatterplot(x = X_analysis[:, 0], y = X_analysis[:, 1], s = 20, hue = Y_test)
plt.grid()
plt.savefig("Results/PCA Groundtruth/ET_" + str(number_features))
plt.show()

# Ground truth

# %%
conf_matrix = confusion_matrix(Y_test, Y_pred)

fig, ax = plt.subplots(figsize = (5, 5))
ax.matshow(conf_matrix, cmap = plt.cm.Blues, alpha = 0.3)
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        ax.text(x = j, y = i,s = conf_matrix[i, j], va = 'center', ha = 'center', size = 'large')
 
plt.xlabel('Predictions', fontsize=12)
plt.ylabel('Actuals', fontsize=12)
plt.title('Confusion Matrix', fontsize=14)
plt.savefig("Results/Confusion Matrix/ET_" + str(number_features))
plt.show()
