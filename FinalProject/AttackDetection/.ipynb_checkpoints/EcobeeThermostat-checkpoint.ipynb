# %%
# !pip3 install pandas
# !pip3 install seaborn
# !pip3 install --upgrade tensorflow-gpu
# !pip3 install import-ipynb
# !pip3 install cuda-python

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 

from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import math
import pickle
import time
import sys

import import_ipynb
import AttackDetectionModel

import tensorflow as tf
tf.compat.v1.disable_eager_execution()
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras import optimizers

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.metrics import f1_score, confusion_matrix

from bayes_opt import BayesianOptimization

# %matplotlib inline
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/andressa.amaral/.local/lib/python3.7/site-packages (1.3.5)
# Requirement already satisfied: numpy>=1.17.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from pandas) (1.21.5)
# Requirement already satisfied: pytz>=2017.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from pandas) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# WARNING: You are using pip version 22.0.4; however, version 22.3 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in /home/andressa.amaral/.local/lib/python3.7/site-packages (0.11.2)
# Requirement already satisfied: matplotlib>=2.2 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from seaborn) (3.5.1)
# Requirement already satisfied: pandas>=0.23 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from seaborn) (1.3.5)
# Requirement already satisfied: scipy>=1.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from seaborn) (1.7.3)
# Requirement already satisfied: numpy>=1.15 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from seaborn) (1.21.5)
# Requirement already satisfied: packaging>=20.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (9.0.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (3.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (1.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (4.31.1)
# Requirement already satisfied: cycler>=0.10 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: pytz>=2017.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from pandas>=0.23->seaborn) (2022.1)
# Requirement already satisfied: typing-extensions in /home/andressa.amaral/.local/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib>=2.2->seaborn) (4.1.1)
# Requirement already satisfied: six>=1.5 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# WARNING: You are using pip version 22.0.4; however, version 22.3 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow-gpu in /home/andressa.amaral/.local/lib/python3.7/site-packages (2.10.0)
# Requirement already satisfied: six>=1.12.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.16.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (3.3.0)
# Requirement already satisfied: setuptools in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (60.10.0)
# Requirement already satisfied: numpy>=1.20 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.21.5)
# Requirement already satisfied: libclang>=13.0.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (13.0.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.44.0)
# Requirement already satisfied: packaging in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (21.3)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (2.10.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.1.0)
# Requirement already satisfied: flatbuffers>=2.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (2.0.7)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.1.2)
# Requirement already satisfied: wrapt>=1.11.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.14.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (0.4.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (0.24.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (3.19.4)
# Requirement already satisfied: h5py>=2.9.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (4.1.1)
# Requirement already satisfied: keras<2.11,>=2.10.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (2.10.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.6.3)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (2.10.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (0.2.0)
# Requirement already satisfied: absl-py>=1.0.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.0.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/lib/python3/dist-packages (from astunparse>=1.6.0->tensorflow-gpu) (0.30.0)
# Requirement already satisfied: cached-property in /home/andressa.amaral/.local/lib/python3.7/site-packages (from h5py>=2.9.0->tensorflow-gpu) (1.5.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (2.27.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (2.6.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (2.0.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (3.3.6)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from packaging->tensorflow-gpu) (3.0.7)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow-gpu) (5.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow-gpu) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow-gpu) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow-gpu) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow-gpu) (4.11.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow-gpu) (2.6)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow-gpu) (1.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow-gpu) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow-gpu) (2018.1.18)
# Requirement already satisfied: zipp>=0.5 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow-gpu) (3.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow-gpu) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow-gpu) (3.2.0)
# WARNING: You are using pip version 22.0.4; however, version 22.3 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: import-ipynb in /home/andressa.amaral/.local/lib/python3.7/site-packages (0.1.3)
# WARNING: You are using pip version 22.0.4; however, version 22.3 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: cuda-python in /home/andressa.amaral/.local/lib/python3.7/site-packages (11.8.0)
# Requirement already satisfied: cython in /home/andressa.amaral/.local/lib/python3.7/site-packages (from cuda-python) (0.29.32)
# WARNING: You are using pip version 22.0.4; however, version 22.3 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# importing Jupyter notebook from AttackDetectionModel.ipynb
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/andressa.amaral/.local/lib/python3.7/site-packages (1.3.5)
# Requirement already satisfied: pytz>=2017.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from pandas) (2022.1)
# Requirement already satisfied: numpy>=1.17.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from pandas) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# WARNING: You are using pip version 22.0.4; however, version 22.3 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow-gpu in /home/andressa.amaral/.local/lib/python3.7/site-packages (2.10.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (0.24.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.44.0)
# Requirement already satisfied: flatbuffers>=2.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (2.0.7)
# Requirement already satisfied: wrapt>=1.11.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.14.0)
# Requirement already satisfied: keras<2.11,>=2.10.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (2.10.0)
# Requirement already satisfied: packaging in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (21.3)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (2.10.0)
# Requirement already satisfied: six>=1.12.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.16.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (3.6.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (0.4.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (13.0.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (3.3.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.1.2)
# Requirement already satisfied: absl-py>=1.0.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.0.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (3.19.4)
# Requirement already satisfied: numpy>=1.20 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.21.5)
# Requirement already satisfied: termcolor>=1.1.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.1.0)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (2.10.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.6.3)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (4.1.1)
# Requirement already satisfied: setuptools in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (60.10.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/lib/python3/dist-packages (from astunparse>=1.6.0->tensorflow-gpu) (0.30.0)
# Requirement already satisfied: cached-property in /home/andressa.amaral/.local/lib/python3.7/site-packages (from h5py>=2.9.0->tensorflow-gpu) (1.5.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (2.0.3)
# Requirement already satisfied: markdown>=2.6.8 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (3.3.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (2.27.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (2.6.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (0.4.6)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from packaging->tensorflow-gpu) (3.0.7)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow-gpu) (5.0.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow-gpu) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow-gpu) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow-gpu) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow-gpu) (4.11.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow-gpu) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow-gpu) (2018.1.18)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow-gpu) (1.22)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow-gpu) (2.6)
# Requirement already satisfied: zipp>=0.5 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow-gpu) (3.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow-gpu) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow-gpu) (3.2.0)
# WARNING: You are using pip version 22.0.4; however, version 22.3 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
gpu_options = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction = 0.333)
sess = tf.compat.v1.Session(config = tf.compat.v1.ConfigProto(gpu_options = gpu_options))

# %% [markdown]
# # Data Pre-Processing

# %%
#number_features = 115
number_features = 92
#number_features = 69
#number_features = 46
#number_features = 23

# %%
# Get benign traffic 
df_et_benign = AttackDetectionModel.get_files('../../nbaiot/Ecobee_Thermostat', number_features)

# Get Bashlite traffic
df_et_bashlite = AttackDetectionModel.get_files('../../nbaiot/Ecobee_Thermostat/gafgyt', number_features)

# Get Mirai traffic
df_et_mirai = AttackDetectionModel.get_files('../../nbaiot/Ecobee_Thermostat/mirai', number_features)

# %%
# Normalize with the min-max scaler
scaler = MinMaxScaler()
df_et_benign_norm = scaler.fit_transform(df_et_benign)
df_et_bashlite_norm = scaler.fit_transform(df_et_bashlite)
df_et_mirai_norm = scaler.fit_transform(df_et_mirai)

# %% [markdown]
# # Sets

# %%
# Train set
len_benign_train = int(0.7 * len(df_et_benign_norm))
X_train = df_et_benign_norm[:len_benign_train]

# %%
# Test set
X_test_benign = df_et_benign_norm[len_benign_train:]
X_test = np.concatenate([X_test_benign, df_et_bashlite_norm, df_et_mirai_norm])

Y_test = np.ones(len(X_test))
Y_test[:len(X_test_benign)] = 0

# %% [markdown]
# # Model

# %%
# Parameters
original_dim = X_train.shape[1]
input_shape = (original_dim,)
intermediate_dim = int(original_dim / 2)
latent_dim = int(original_dim / 3)

# Initial values
epochs = 5
learning_rate = 0.0001
batch_size = 20
anomaly_threshold = 0.05

# Dictionary
dict_params = { 'learning_rate': learning_rate, 'batch_size': round(batch_size), 'epochs': round(epochs)}
pbounds = { 'learning_rate': (0.000001, 0.001), 'batch_size': (10, 100), 'epochs': (50, 500)}

# %%
# KL Loss function
def vae_loss(x, x_decoded_mean):
    # Compute the average MSE error, then scale it up (sum on all axes)
    
    reconstruction_loss = K.sum(K.square(x - x_decoded_mean))
    
    # Compute the KL loss
    
    kl_loss = - 0.5 * K.sum(1 + z_var - K.square(z_mean) - K.square(K.exp(z_var)), axis=-1)
    
    # Return the average loss over all 
    
    total_loss = K.mean(reconstruction_loss + kl_loss) # Total_loss = reconstruction_loss + kl_loss 
    return total_loss

# (1) Reconstruction Loss - Forces the encoder to generate latent features that minimize the reconstruction error, or else is
# penalized
# (2) KL Loss - Forces the distribution generated by the encoder to be similar to the prior probability of the input vector, 
# pushing latent feature space to normality

# %%
# Encoder
inputs, encoder, z_var, z_mean = AttackDetectionModel.vae_encoder(input_shape, 
                                                                  intermediate_dim, 
                                                                  latent_dim, 
                                                                  AttackDetectionModel.reparametrization)
encoder.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  encoder_input (InputLayer)     [(None, 69)]         0           []
#
#  dense (Dense)                  (None, 34)           2380        ['encoder_input[0][0]']
#
#  z_mean (Dense)                 (None, 23)           805         ['dense[0][0]']
#
#  z_var (Dense)                  (None, 23)           805         ['dense[0][0]']
#
#  z (Lambda)                     (None, 23)           0           ['z_mean[0][0]',
#                                                                   'z_var[0][0]']
#
# ==================================================================================================
# Total params: 3,990
# Trainable params: 3,990
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Decoder
decoder = AttackDetectionModel.vae_decoder(intermediate_dim, latent_dim, original_dim)
outputs = decoder(encoder(inputs))
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  z_sampling (InputLayer)     [(None, 23)]              0
#
#  dense_1 (Dense)             (None, 34)                816
#
#  dense_2 (Dense)             (None, 69)                2415
#
# =================================================================
# Total params: 3,231
# Trainable params: 3,231
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Hyperparameter Optimization

# %%
def maximize_training(X_train = X_train, 
                      X_test = X_test, 
                      Y_test = Y_test, 
                      inputs = inputs, 
                      outputs = outputs, 
                      vae_loss = vae_loss,
                      learning_rate = learning_rate,
                      batch_size = batch_size,
                      epochs = epochs,
                      anomaly_threshold = anomaly_threshold):    
    
    # Create model
    opt_adam = optimizers.Adam(learning_rate = dict_params['learning_rate'], clipvalue = 0.5)
    model = Model(inputs, outputs, name = 'vae_mlp')
    model.compile(optimizer = opt_adam, loss = vae_loss)

    # Train
    history = model.fit(X_train, 
                        X_train, 
                        shuffle = True, 
                        verbose = 0,
                        epochs = dict_params['epochs'], 
                        batch_size = dict_params['batch_size'])
    
    # Maximize the f1-score
    X_pred_opt = model.predict(X_test)
    error_vector_opt = AttackDetectionModel.get_error_term(X_pred_opt, X_test, _rmse = False)
    Y_pred_opt = (error_vector_opt > anomaly_threshold)
    f1 = f1_score(Y_test, Y_pred_opt)
    
    return f1

# %%
'''
# Apply Bayesian optimization to choose the best hyperparameters

opt = BayesianOptimization(f = maximize_training,
                           pbounds = pbounds,
                           verbose = 2, 
                           random_state = 1)

opt_start = time.time()

opt.maximize(init_points = 5, n_iter = 5)

opt_end = time.time()
opt_time = opt_end - opt_start
print("Optimization time:", opt_time)

learning_rate = opt.max['params']['learning_rate']
epochs = round(opt.max['params']['epochs'])
batch_size = round(opt.max['params']['batch_size'])
'''
# Out:
# '\n# Apply Bayesian optimization to choose the best hyperparameters\n\nopt = BayesianOptimization(f = maximize_training,\n                           pbounds = pbounds,\n                           verbose = 2, \n                           random_state = 1)\n\nopt_start = time.time()\n\nopt.maximize(init_points = 5, n_iter = 5)\n\nopt_end = time.time()\nopt_time = opt_end - opt_start\nprint("Optimization time:", opt_time)\n\nlearning_rate = opt.max[\'params\'][\'learning_rate\']\nepochs = round(opt.max[\'params\'][\'epochs\'])\nbatch_size = round(opt.max[\'params\'][\'batch_size\'])\n'

# %% [markdown]
# # Predict Attacks

# %%
# Training step with the best hyperparameters
learning_rate = 0.00012123446827562964
epochs = 422
batch_size = 74
opt_time = 262.7667851448059
anomaly_threshold = 0.04

# %%
for i in range(1):
    print("Iteration " + str(i))
    
    # Train
    vae_model, train_time = AttackDetectionModel.train(X_train, inputs, outputs, vae_loss, learning_rate, epochs, batch_size)
    
    # Set the optimized anomaly threshold
    #anomaly_threshold = AttackDetectionModel.get_anomaly_threshold(X_train, vae_model)
    
    # Test
    X_pred, test_time = AttackDetectionModel.test(X_test, vae_model)
    Y_test, Y_pred = AttackDetectionModel.get_prediction(Y_test, X_pred, X_test, anomaly_threshold, vae_model)
    
    # Metrics
    acc, f1, pre, rec = AttackDetectionModel.get_scores(Y_test, Y_pred)
    
    # Print results
    AttackDetectionModel.print_results(number_features,
                                       learning_rate,
                                       epochs,
                                       batch_size,
                                       anomaly_threshold,
                                       X_train,
                                       X_test,
                                       opt_time,
                                       train_time,
                                       test_time,
                                       acc,
                                       f1,
                                       pre,
                                       rec,
                                       Y_test,
                                       Y_pred,
                                       "Results/ecobee_thermostat.txt")
    
    print("")
# Out:
# Iteration 0
# Train on 9179 samples
# Epoch 1/422
# 9179/9179 [==============================] - 0s 52us/sample - loss: 730.7460
# Epoch 2/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 511.7721
# Epoch 3/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 294.2540
# Epoch 4/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 146.8762
# Epoch 5/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 91.4526
# Epoch 6/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 67.8615
# Epoch 7/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 56.4325
# Epoch 8/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 49.7046
# Epoch 9/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 44.5877
# Epoch 10/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 40.0844
# Epoch 11/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 36.5444
# Epoch 12/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 34.3664
# Epoch 13/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 32.6310
# Epoch 14/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 31.4932
# Epoch 15/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 30.3874
# Epoch 16/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 29.8310
# Epoch 17/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 28.8487
# Epoch 18/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 28.1840
# Epoch 19/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 27.3440
# Epoch 20/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 26.8370
# Epoch 21/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 26.0071
# Epoch 22/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 25.1557
# Epoch 23/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 24.6856
# Epoch 24/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 23.9522
# Epoch 25/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 23.1606
# Epoch 26/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 22.8515
# Epoch 27/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 22.3729
# Epoch 28/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 21.5863
# Epoch 29/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 20.9735
# Epoch 30/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 20.5642
# Epoch 31/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 20.0231
# Epoch 32/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 19.5314
# Epoch 33/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 19.1078
# Epoch 34/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 18.6720
# Epoch 35/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 18.1569
# Epoch 36/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 17.7814
# Epoch 37/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 17.3611
# Epoch 38/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 16.9151
# Epoch 39/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 16.5992
# Epoch 40/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 16.3433
# Epoch 41/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 15.9270
# Epoch 42/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 15.6853
# Epoch 43/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 15.3835
# Epoch 44/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 15.1134
# Epoch 45/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 14.9089
# Epoch 46/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 14.5231
# Epoch 47/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 14.3148
# Epoch 48/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 14.0430
# Epoch 49/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 13.7891
# Epoch 50/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 13.5342
# Epoch 51/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 13.4159
# Epoch 52/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 13.1363
# Epoch 53/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 12.9934
# Epoch 54/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 12.6937
# Epoch 55/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 12.5661
# Epoch 56/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 12.4315
# Epoch 57/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 12.2863
# Epoch 58/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 12.1642
# Epoch 59/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 11.9263
# Epoch 60/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 11.7666
# Epoch 61/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 11.6980
# Epoch 62/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 11.5099
# Epoch 63/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 11.3277
# Epoch 64/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 11.3125
# Epoch 65/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 11.1302
# Epoch 66/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 10.9313
# Epoch 67/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 10.8763
# Epoch 68/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 10.7726
# Epoch 69/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 10.6493
# Epoch 70/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 10.5464
# Epoch 71/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 10.4336
# Epoch 72/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 10.3739
# Epoch 73/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 10.2531
# Epoch 74/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 10.1328
# Epoch 75/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 10.0705
# Epoch 76/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 9.9158
# Epoch 77/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 9.8241
# Epoch 78/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 9.7783
# Epoch 79/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 9.7001
# Epoch 80/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 9.6154
# Epoch 81/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 9.5851
# Epoch 82/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 9.4888
# Epoch 83/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 9.4294
# Epoch 84/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 9.3582
# Epoch 85/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 9.2214
# Epoch 86/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 9.1778
# Epoch 87/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 9.0507
# Epoch 88/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 8.9667
# Epoch 89/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 8.9637
# Epoch 90/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 8.9735
# Epoch 91/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 8.8314
# Epoch 92/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 8.7557
# Epoch 93/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 8.7478
# Epoch 94/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 8.6123
# Epoch 95/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 8.5606
# Epoch 96/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 8.5916
# Epoch 97/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 8.5202
# Epoch 98/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 8.3790
# Epoch 99/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 8.3293
# Epoch 100/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 8.3202
# Epoch 101/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 8.2696
# Epoch 102/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 8.2609
# Epoch 103/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 8.2088
# Epoch 104/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 8.1423
# Epoch 105/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 8.0598
# Epoch 106/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 8.0236
# Epoch 107/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 7.9851
# Epoch 108/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 7.9060
# Epoch 109/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 7.8901
# Epoch 110/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 7.8965
# Epoch 111/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 7.8695
# Epoch 112/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 7.8027
# Epoch 113/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 7.7122
# Epoch 114/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 7.7689
# Epoch 115/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 7.6830
# Epoch 116/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 7.6289
# Epoch 117/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 7.6200
# Epoch 118/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 7.5965
# Epoch 119/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 7.5824
# Epoch 120/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 7.5462
# Epoch 121/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 7.4808
# Epoch 122/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 7.4996
# Epoch 123/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 7.4462
# Epoch 124/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 7.4631
# Epoch 125/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 7.3973
# Epoch 126/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 7.3635
# Epoch 127/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 7.3391
# Epoch 128/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 7.3697
# Epoch 129/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 7.2530
# Epoch 130/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 7.2622
# Epoch 131/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 7.2451
# Epoch 132/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 7.2189
# Epoch 133/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 7.2058
# Epoch 134/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 7.1690
# Epoch 135/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 7.1795
# Epoch 136/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 7.1647
# Epoch 137/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 7.1248
# Epoch 138/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 7.1130
# Epoch 139/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 7.0559
# Epoch 140/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 7.1213
# Epoch 141/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 7.0359
# Epoch 142/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 7.0268
# Epoch 143/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 7.0052
# Epoch 144/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 7.0028
# Epoch 145/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.9366
# Epoch 146/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.9508
# Epoch 147/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.9154
# Epoch 148/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 6.8802
# Epoch 149/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 6.9182
# Epoch 150/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 6.8572
# Epoch 151/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 6.8981
# Epoch 152/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 6.8436
# Epoch 153/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.8425
# Epoch 154/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 6.8520
# Epoch 155/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 6.7710
# Epoch 156/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.7760
# Epoch 157/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.7552
# Epoch 158/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.7586
# Epoch 159/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.6810
# Epoch 160/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.6971
# Epoch 161/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.7130
# Epoch 162/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.7354
# Epoch 163/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 6.6932
# Epoch 164/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.6899
# Epoch 165/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.6364
# Epoch 166/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.6412
# Epoch 167/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.6402
# Epoch 168/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 6.6496
# Epoch 169/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 6.6596
# Epoch 170/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.5959
# Epoch 171/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 6.5864
# Epoch 172/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.5853
# Epoch 173/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 6.5837
# Epoch 174/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.5869
# Epoch 175/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 6.5105
# Epoch 176/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 6.5243
# Epoch 177/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.5138
# Epoch 178/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 6.5387
# Epoch 179/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.4730
# Epoch 180/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 6.5135
# Epoch 181/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 6.4329
# Epoch 182/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 6.5060
# Epoch 183/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 6.5218
# Epoch 184/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 6.3960
# Epoch 185/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.4732
# Epoch 186/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.4530
# Epoch 187/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 6.4384
# Epoch 188/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 6.3984
# Epoch 189/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.4286
# Epoch 190/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 6.3960
# Epoch 191/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.3515
# Epoch 192/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.3351
# Epoch 193/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.3394
# Epoch 194/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 6.3599
# Epoch 195/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.3476
# Epoch 196/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.3359
# Epoch 197/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.3453
# Epoch 198/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.3535
# Epoch 199/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.3084
# Epoch 200/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 6.2829
# Epoch 201/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 6.3299
# Epoch 202/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 6.2652
# Epoch 203/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.2985
# Epoch 204/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.3003
# Epoch 205/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.2452
# Epoch 206/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.2650
# Epoch 207/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.2499
# Epoch 208/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.2407
# Epoch 209/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.2632
# Epoch 210/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 6.2359
# Epoch 211/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.1957
# Epoch 212/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 6.1745
# Epoch 213/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 6.1929
# Epoch 214/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.2140
# Epoch 215/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.2279
# Epoch 216/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.1412
# Epoch 217/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.1712
# Epoch 218/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.2025
# Epoch 219/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 6.1917
# Epoch 220/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.1971
# Epoch 221/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.1469
# Epoch 222/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.1166
# Epoch 223/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.1521
# Epoch 224/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 6.1461
# Epoch 225/422
# 9179/9179 [==============================] - 0s 24us/sample - loss: 6.1677
# Epoch 226/422
# 9179/9179 [==============================] - 0s 33us/sample - loss: 6.0848
# Epoch 227/422
# 9179/9179 [==============================] - 0s 33us/sample - loss: 6.1367
# Epoch 228/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 6.1159
# Epoch 229/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 6.1567
# Epoch 230/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 6.0749
# Epoch 231/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 6.1385
# Epoch 232/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 6.0860
# Epoch 233/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 6.0583
# Epoch 234/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 6.0855
# Epoch 235/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 6.0461
# Epoch 236/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 6.0611
# Epoch 237/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 6.1048
# Epoch 238/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 6.0306
# Epoch 239/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 6.0651
# Epoch 240/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 6.0519
# Epoch 241/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 6.0504
# Epoch 242/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 6.0005
# Epoch 243/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 5.9951
# Epoch 244/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 6.0276
# Epoch 245/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 6.0473
# Epoch 246/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 6.0181
# Epoch 247/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 5.9565
# Epoch 248/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 6.0340
# Epoch 249/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.9852
# Epoch 250/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 6.0005
# Epoch 251/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 5.9320
# Epoch 252/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.9607
# Epoch 253/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 5.9844
# Epoch 254/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 5.9640
# Epoch 255/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 5.9045
# Epoch 256/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.9115
# Epoch 257/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 5.9504
# Epoch 258/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.9475
# Epoch 259/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.9371
# Epoch 260/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.8734
# Epoch 261/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 5.8895
# Epoch 262/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 5.8872
# Epoch 263/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.9183
# Epoch 264/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.9264
# Epoch 265/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 5.8524
# Epoch 266/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 5.9574
# Epoch 267/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 5.8903
# Epoch 268/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 5.9072
# Epoch 269/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 5.9261
# Epoch 270/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 5.9058
# Epoch 271/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 5.8901
# Epoch 272/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 5.9000
# Epoch 273/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 5.8952
# Epoch 274/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 5.8318
# Epoch 275/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 5.8720
# Epoch 276/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 5.8680
# Epoch 277/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.8539
# Epoch 278/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.8539
# Epoch 279/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.8511
# Epoch 280/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.8192
# Epoch 281/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.8484
# Epoch 282/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 5.8448
# Epoch 283/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.8454
# Epoch 284/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 5.8264
# Epoch 285/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 5.8080
# Epoch 286/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.7983
# Epoch 287/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 5.7847
# Epoch 288/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.8780
# Epoch 289/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 5.7949
# Epoch 290/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.7928
# Epoch 291/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.8177
# Epoch 292/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.7830
# Epoch 293/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.8185
# Epoch 294/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.7762
# Epoch 295/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 5.7307
# Epoch 296/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.7602
# Epoch 297/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 5.7318
# Epoch 298/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 5.7312
# Epoch 299/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 5.7834
# Epoch 300/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.7832
# Epoch 301/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.7859
# Epoch 302/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 5.7273
# Epoch 303/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 5.7101
# Epoch 304/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.7361
# Epoch 305/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.7176
# Epoch 306/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.7413
# Epoch 307/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.7396
# Epoch 308/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 5.7458
# Epoch 309/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 5.7231
# Epoch 310/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.6783
# Epoch 311/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 5.7089
# Epoch 312/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.7122
# Epoch 313/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 5.7403
# Epoch 314/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.6977
# Epoch 315/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.6933
# Epoch 316/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.6806
# Epoch 317/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.6281
# Epoch 318/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.6749
# Epoch 319/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.6889
# Epoch 320/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.7051
# Epoch 321/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.6686
# Epoch 322/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.6516
# Epoch 323/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.6477
# Epoch 324/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 5.6796
# Epoch 325/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 5.6833
# Epoch 326/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.6512
# Epoch 327/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.6575
# Epoch 328/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.6663
# Epoch 329/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.6501
# Epoch 330/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.6385
# Epoch 331/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.6794
# Epoch 332/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.6474
# Epoch 333/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 5.6544
# Epoch 334/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.5860
# Epoch 335/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.7118
# Epoch 336/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 5.6150
# Epoch 337/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 5.6452
# Epoch 338/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.6404
# Epoch 339/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.5839
# Epoch 340/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.6420
# Epoch 341/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.5963
# Epoch 342/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.6123
# Epoch 343/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.6230
# Epoch 344/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.6404
# Epoch 345/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 5.5639
# Epoch 346/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 5.6084
# Epoch 347/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 5.6327
# Epoch 348/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 5.6441
# Epoch 349/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.6186
# Epoch 350/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.5787
# Epoch 351/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.5883
# Epoch 352/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 5.5792
# Epoch 353/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.6258
# Epoch 354/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.5678
# Epoch 355/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 5.5343
# Epoch 356/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 5.5710
# Epoch 357/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.5284
# Epoch 358/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.5547
# Epoch 359/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.5914
# Epoch 360/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.5284
# Epoch 361/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.5635
# Epoch 362/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.5525
# Epoch 363/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.5710
# Epoch 364/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.5644
# Epoch 365/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.5732
# Epoch 366/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 5.5720
# Epoch 367/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 5.5163
# Epoch 368/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.5272
# Epoch 369/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.5272
# Epoch 370/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.5570
# Epoch 371/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.5316
# Epoch 372/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.5043
# Epoch 373/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.5601
# Epoch 374/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 5.5324
# Epoch 375/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.5058
# Epoch 376/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.5644
# Epoch 377/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.5391
# Epoch 378/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 5.4650
# Epoch 379/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 5.4971
# Epoch 380/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.5519
# Epoch 381/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.5024
# Epoch 382/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 5.5165
# Epoch 383/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.4860
# Epoch 384/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.4453
# Epoch 385/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 5.5171
# Epoch 386/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 5.5306
# Epoch 387/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.5013
# Epoch 388/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.4790
# Epoch 389/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.4494
# Epoch 390/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.4637
# Epoch 391/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.4552
# Epoch 392/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.4574
# Epoch 393/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.4733
# Epoch 394/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.4648
# Epoch 395/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.4703
# Epoch 396/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.4936
# Epoch 397/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.4450
# Epoch 398/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.4415
# Epoch 399/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.4399
# Epoch 400/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 5.4958
# Epoch 401/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.4778
# Epoch 402/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 5.4734
# Epoch 403/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.5023
# Epoch 404/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 5.4455
# Epoch 405/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.4237
# Epoch 406/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.4455
# Epoch 407/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.4456
# Epoch 408/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.5048
# Epoch 409/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.4607
# Epoch 410/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.4326
# Epoch 411/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.4412
# Epoch 412/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 5.4034
# Epoch 413/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.4699
# Epoch 414/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.4368
# Epoch 415/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.4734
# Epoch 416/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.4529
# Epoch 417/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 5.4109
# Epoch 418/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 5.4189
# Epoch 419/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 5.4066
# Epoch 420/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 5.4563
# Epoch 421/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 5.4120
# Epoch 422/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 5.4550
# Training time: 74.08749651908875
# /home/andressa.amaral/.local/lib/python3.7/site-packages/keras/engine/training_v1.py:2356: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# Testing time: 13.332791805267334

# %% [markdown]
# # Metrics

# %%
# Examinig the latent space generated by the encoder
X_encoded = encoder.predict(X_test)

pca = PCA(n_components=2)
X_analysis = pca.fit_transform(X_encoded)
# Out:
# /home/andressa.amaral/.local/lib/python3.7/site-packages/keras/engine/training_v1.py:2356: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,

# %%
plt.figure(figsize=(8, 8))
sns.scatterplot(x = X_analysis[:, 0], y = X_analysis[:, 1], s = 20, hue = Y_pred)
plt.grid()
plt.savefig("Results/PCA/ET_" + str(number_features))
plt.show()

# Orange ones are anomalies

# %%
plt.figure(figsize = (8, 8))
sns.scatterplot(x = X_analysis[:, 0], y = X_analysis[:, 1], s = 20, hue = Y_test)
plt.grid()
plt.savefig("Results/PCA Groundtruth/ET_" + str(number_features))
plt.show()

# Ground truth

# %%
conf_matrix = confusion_matrix(Y_test, Y_pred)

fig, ax = plt.subplots(figsize = (5, 5))
ax.matshow(conf_matrix, cmap = plt.cm.Blues, alpha = 0.3)
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        ax.text(x = j, y = i,s = conf_matrix[i, j], va = 'center', ha = 'center', size = 'large')
 
plt.xlabel('Predictions', fontsize=12)
plt.ylabel('Actuals', fontsize=12)
plt.title('Confusion Matrix', fontsize=14)
plt.savefig("Results/Confusion Matrix/ET_" + str(number_features))
plt.show()
