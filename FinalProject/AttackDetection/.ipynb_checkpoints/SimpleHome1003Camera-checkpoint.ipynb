# %%
# !pip3 install pandas
# !pip3 install seaborn
# !pip3 install --upgrade tensorflow-gpu
# !pip3 install import-ipynb
# !pip3 install cuda-python

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 

from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import math
import pickle
import time
import sys

import import_ipynb
import AttackDetectionModel

import tensorflow as tf
tf.compat.v1.disable_eager_execution()
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras import optimizers

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.metrics import f1_score, confusion_matrix

from bayes_opt import BayesianOptimization

# %matplotlib inline
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/andressa.amaral/.local/lib/python3.7/site-packages (1.3.5)
# Requirement already satisfied: pytz>=2017.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from pandas) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from pandas) (1.21.5)
# Requirement already satisfied: six>=1.5 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# WARNING: You are using pip version 22.0.4; however, version 22.3 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in /home/andressa.amaral/.local/lib/python3.7/site-packages (0.11.2)
# Requirement already satisfied: scipy>=1.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from seaborn) (1.7.3)
# Requirement already satisfied: numpy>=1.15 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from seaborn) (1.21.5)
# Requirement already satisfied: pandas>=0.23 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from seaborn) (1.3.5)
# Requirement already satisfied: matplotlib>=2.2 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from seaborn) (3.5.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (3.0.7)
# Requirement already satisfied: pillow>=6.2.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (9.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (1.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (4.31.1)
# Requirement already satisfied: cycler>=0.10 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: pytz>=2017.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from pandas>=0.23->seaborn) (2022.1)
# Requirement already satisfied: typing-extensions in /home/andressa.amaral/.local/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib>=2.2->seaborn) (4.1.1)
# Requirement already satisfied: six>=1.5 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# WARNING: You are using pip version 22.0.4; however, version 22.3 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow-gpu in /home/andressa.amaral/.local/lib/python3.7/site-packages (2.10.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (3.3.0)
# Requirement already satisfied: keras<2.11,>=2.10.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (2.10.0)
# Requirement already satisfied: six>=1.12.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.16.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.1.2)
# Requirement already satisfied: h5py>=2.9.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (3.6.0)
# Requirement already satisfied: flatbuffers>=2.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (2.0.7)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (2.10.0)
# Requirement already satisfied: setuptools in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (60.10.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.14.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (13.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.6.3)
# Requirement already satisfied: termcolor>=1.1.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.1.0)
# Requirement already satisfied: numpy>=1.20 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.21.5)
# Requirement already satisfied: packaging in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (21.3)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (3.19.4)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (4.1.1)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (0.4.0)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (2.10.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.44.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (0.24.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (0.2.0)
# Requirement already satisfied: absl-py>=1.0.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.0.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/lib/python3/dist-packages (from astunparse>=1.6.0->tensorflow-gpu) (0.30.0)
# Requirement already satisfied: cached-property in /home/andressa.amaral/.local/lib/python3.7/site-packages (from h5py>=2.9.0->tensorflow-gpu) (1.5.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (2.6.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (2.27.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (2.0.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (3.3.6)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (1.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from packaging->tensorflow-gpu) (3.0.7)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow-gpu) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow-gpu) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow-gpu) (5.0.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow-gpu) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow-gpu) (4.11.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow-gpu) (2.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow-gpu) (2018.1.18)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow-gpu) (1.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow-gpu) (2.0.12)
# Requirement already satisfied: zipp>=0.5 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow-gpu) (3.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow-gpu) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow-gpu) (3.2.0)
# WARNING: You are using pip version 22.0.4; however, version 22.3 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: import-ipynb in /home/andressa.amaral/.local/lib/python3.7/site-packages (0.1.3)
# WARNING: You are using pip version 22.0.4; however, version 22.3 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: cuda-python in /home/andressa.amaral/.local/lib/python3.7/site-packages (11.8.0)
# Requirement already satisfied: cython in /home/andressa.amaral/.local/lib/python3.7/site-packages (from cuda-python) (0.29.32)
# WARNING: You are using pip version 22.0.4; however, version 22.3 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# importing Jupyter notebook from AttackDetectionModel.ipynb
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/andressa.amaral/.local/lib/python3.7/site-packages (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from pandas) (1.21.5)
# Requirement already satisfied: pytz>=2017.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from pandas) (2022.1)
# Requirement already satisfied: six>=1.5 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# WARNING: You are using pip version 22.0.4; however, version 22.3 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow-gpu in /home/andressa.amaral/.local/lib/python3.7/site-packages (2.10.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.1.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (13.0.0)
# Requirement already satisfied: six>=1.12.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.16.0)
# Requirement already satisfied: packaging in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (21.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (0.4.0)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (2.10.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (4.1.1)
# Requirement already satisfied: astunparse>=1.6.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.6.3)
# Requirement already satisfied: h5py>=2.9.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (3.6.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.44.0)
# Requirement already satisfied: numpy>=1.20 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.21.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (3.3.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.1.2)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (3.19.4)
# Requirement already satisfied: keras<2.11,>=2.10.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (2.10.0)
# Requirement already satisfied: setuptools in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (60.10.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.14.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (0.2.0)
# Requirement already satisfied: flatbuffers>=2.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (2.0.7)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (2.10.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (0.24.0)
# Requirement already satisfied: absl-py>=1.0.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.0.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/lib/python3/dist-packages (from astunparse>=1.6.0->tensorflow-gpu) (0.30.0)
# Requirement already satisfied: cached-property in /home/andressa.amaral/.local/lib/python3.7/site-packages (from h5py>=2.9.0->tensorflow-gpu) (1.5.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (2.6.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (1.8.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (2.27.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (0.4.6)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (2.0.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (3.3.6)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from packaging->tensorflow-gpu) (3.0.7)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow-gpu) (4.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow-gpu) (5.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow-gpu) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow-gpu) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow-gpu) (4.11.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow-gpu) (2018.1.18)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow-gpu) (1.22)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow-gpu) (2.6)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow-gpu) (2.0.12)
# Requirement already satisfied: zipp>=0.5 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow-gpu) (3.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow-gpu) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow-gpu) (3.2.0)
# WARNING: You are using pip version 22.0.4; however, version 22.3 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
gpu_options = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction = 0.333)
sess = tf.compat.v1.Session(config = tf.compat.v1.ConfigProto(gpu_options = gpu_options))

# %% [markdown]
# # Data Pre-Processing

# %%
#number_features = 115
#number_features = 92
#number_features = 69
#number_features = 46
number_features = 23

# %%
# Get benign traffic 
df_s3_benign = AttackDetectionModel.get_files('../../nbaiot/SimpleHome_XCS7_1003_WHT_Security_Camera', number_features)

# Get Bashlite traffic
df_s3_bashlite = AttackDetectionModel.get_files('../../nbaiot/SimpleHome_XCS7_1003_WHT_Security_Camera/gafgyt', number_features)

# Get Mirai traffic
df_s3_mirai = AttackDetectionModel.get_files('../../nbaiot/SimpleHome_XCS7_1003_WHT_Security_Camera/mirai', number_features)

# %%
# Normalize with the min-max scaler
scaler = MinMaxScaler()
df_s3_benign_norm = scaler.fit_transform(df_s3_benign)
df_s3_bashlite_norm = scaler.fit_transform(df_s3_bashlite)
df_s3_mirai_norm = scaler.fit_transform(df_s3_mirai)

# %% [markdown]
# # Sets

# %%
# Train set
len_benign_train = int(0.7 * len(df_s3_benign_norm))
X_train = df_s3_benign_norm[:len_benign_train]

# %%
# Test set
X_test_benign = df_s3_benign_norm[len_benign_train:]
X_test = np.concatenate([X_test_benign, df_s3_bashlite_norm, df_s3_mirai_norm])

Y_test = np.ones(len(X_test))
Y_test[:len(X_test_benign)] = 0

# %% [markdown]
# # Model

# %%
# Parameters
original_dim = X_train.shape[1]
input_shape = (original_dim,)
intermediate_dim = int(original_dim / 2)
latent_dim = int(original_dim / 3)

# Initial values
epochs = 5
learning_rate = 0.00008
batch_size = 25
anomaly_threshold = 0.01

# Dictionary
dict_params = { 'learning_rate': learning_rate, 'batch_size': round(batch_size), 'epochs': round(epochs)}
pbounds = { 'learning_rate': (0.000001, 0.001), 'batch_size': (10, 100), 'epochs': (50, 300)}

# %%
# KL Loss function
def vae_loss(x, x_decoded_mean):
    # Compute the average MSE error, then scale it up (sum on all axes)
    
    reconstruction_loss = K.sum(K.square(x - x_decoded_mean))
    
    # Compute the KL loss
    
    kl_loss = - 0.5 * K.sum(1 + z_var - K.square(z_mean) - K.square(K.exp(z_var)), axis=-1)
    
    # Return the average loss over all 
    
    total_loss = K.mean(reconstruction_loss + kl_loss) # Total_loss = reconstruction_loss + kl_loss 
    return total_loss

# (1) Reconstruction Loss - Forces the encoder to generate latent features that minimize the reconstruction error, or else is
# penalized
# (2) KL Loss - Forces the distribution generated by the encoder to be similar to the prior probability of the input vector, 
# pushing latent feature space to normality

# %%
# Encoder
inputs, encoder, z_var, z_mean = AttackDetectionModel.vae_encoder(input_shape, 
                                                                  intermediate_dim, 
                                                                  latent_dim, 
                                                                  AttackDetectionModel.reparametrization)
encoder.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  encoder_input (InputLayer)     [(None, 23)]         0           []
#
#  dense (Dense)                  (None, 11)           264         ['encoder_input[0][0]']
#
#  z_mean (Dense)                 (None, 7)            84          ['dense[0][0]']
#
#  z_var (Dense)                  (None, 7)            84          ['dense[0][0]']
#
#  z (Lambda)                     (None, 7)            0           ['z_mean[0][0]',
#                                                                   'z_var[0][0]']
#
# ==================================================================================================
# Total params: 432
# Trainable params: 432
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Decoder
decoder = AttackDetectionModel.vae_decoder(intermediate_dim, latent_dim, original_dim)
outputs = decoder(encoder(inputs))
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  z_sampling (InputLayer)     [(None, 7)]               0
#
#  dense_1 (Dense)             (None, 11)                88
#
#  dense_2 (Dense)             (None, 23)                276
#
# =================================================================
# Total params: 364
# Trainable params: 364
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Hyperparameter Optimization

# %%
def maximize_training(X_train = X_train, 
                      X_test = X_test, 
                      Y_test = Y_test, 
                      inputs = inputs, 
                      outputs = outputs, 
                      vae_loss = vae_loss,
                      learning_rate = learning_rate,
                      batch_size = batch_size,
                      epochs = epochs,
                      anomaly_threshold = anomaly_threshold):    
    
    # Create model
    opt_adam = optimizers.Adam(learning_rate = dict_params['learning_rate'], clipvalue = 0.5)
    model = Model(inputs, outputs, name = 'vae_mlp')
    model.compile(optimizer = opt_adam, loss = vae_loss)

    # Train
    history = model.fit(X_train, 
                        X_train, 
                        shuffle = True, 
                        verbose = 0,
                        epochs = dict_params['epochs'], 
                        batch_size = dict_params['batch_size'])
    
    # Maximize the f1-score
    X_pred_opt = model.predict(X_test)
    error_vector_opt = AttackDetectionModel.get_error_term(X_pred_opt, X_test, _rmse = False)
    Y_pred_opt = (error_vector_opt > anomaly_threshold)
    f1 = f1_score(Y_test, Y_pred_opt)
    
    return f1

# %%
'''
# Apply Bayesian optimization to choose the best hyperparameters

opt = BayesianOptimization(f = maximize_training,
                           pbounds = pbounds,
                           verbose = 2, 
                           random_state = 1)

opt_start = time.time()

opt.maximize(init_points = 5, n_iter = 5)

opt_end = time.time()
opt_time = opt_end - opt_start
print("Optimization time:", opt_time)

learning_rate = opt.max['params']['learning_rate']
epochs = round(opt.max['params']['epochs'])
batch_size = round(opt.max['params']['batch_size'])
'''
# Out:
# '\n# Apply Bayesian optimization to choose the best hyperparameters\n\nopt = BayesianOptimization(f = maximize_training,\n                           pbounds = pbounds,\n                           verbose = 2, \n                           random_state = 1)\n\nopt_start = time.time()\n\nopt.maximize(init_points = 5, n_iter = 5)\n\nopt_end = time.time()\nopt_time = opt_end - opt_start\nprint("Optimization time:", opt_time)\n\nlearning_rate = opt.max[\'params\'][\'learning_rate\']\nepochs = round(opt.max[\'params\'][\'epochs\'])\nbatch_size = round(opt.max[\'params\'][\'batch_size\'])\n'

# %% [markdown]
# # Predict Attacks

# %%
# Training step with the best hyperparameters
learning_rate = 0.00016249018479418736
epochs = 252
batch_size = 23
opt_time = 449.1416246891022
#anomaly_threshold = 0.1

# %%
for i in range(1):
    print("Iteration " + str(i))
    
    # Train
    vae_model, train_time = AttackDetectionModel.train(X_train, inputs, outputs, vae_loss, learning_rate, epochs, batch_size)
    
    # Set the optimized anomaly threshold
    anomaly_threshold = AttackDetectionModel.get_anomaly_threshold(X_train, vae_model)
    
    # Test
    X_pred, test_time = AttackDetectionModel.test(X_test, vae_model)
    Y_test, Y_pred = AttackDetectionModel.get_prediction(Y_test, X_pred, X_test, anomaly_threshold, vae_model)
    
    # Metrics
    acc, f1, pre, rec = AttackDetectionModel.get_scores(Y_test, Y_pred)
    
    # Print results
    AttackDetectionModel.print_results(number_features,
                                       learning_rate,
                                       epochs,
                                       batch_size,
                                       anomaly_threshold,
                                       X_train,
                                       X_test,
                                       opt_time,
                                       train_time,
                                       test_time,
                                       acc,
                                       f1,
                                       pre,
                                       rec,
                                       Y_test,
                                       Y_pred,
                                       "Results/S1003_camera.txt")
 
    print("")
# Out:
# Iteration 0
# Train on 13669 samples
# Epoch 1/252
# 13669/13669 [==============================] - 1s 84us/sample - loss: 79.0403
# Epoch 2/252
# 13669/13669 [==============================] - 1s 58us/sample - loss: 30.4776
# Epoch 3/252
# 13669/13669 [==============================] - 1s 54us/sample - loss: 11.6929
# Epoch 4/252
# 13669/13669 [==============================] - 1s 56us/sample - loss: 8.0772
# Epoch 5/252
# 13669/13669 [==============================] - 1s 56us/sample - loss: 6.4368
# Epoch 6/252
# 13669/13669 [==============================] - 1s 55us/sample - loss: 5.3921
# Epoch 7/252
# 13669/13669 [==============================] - 1s 57us/sample - loss: 4.7628
# Epoch 8/252
# 13669/13669 [==============================] - 1s 58us/sample - loss: 4.3943
# Epoch 9/252
# 13669/13669 [==============================] - 1s 61us/sample - loss: 3.9673
# Epoch 10/252
# 13669/13669 [==============================] - 1s 57us/sample - loss: 3.6801
# Epoch 11/252
# 13669/13669 [==============================] - 1s 53us/sample - loss: 3.4233
# Epoch 12/252
# 13669/13669 [==============================] - 1s 53us/sample - loss: 3.2143
# Epoch 13/252
# 13669/13669 [==============================] - 1s 56us/sample - loss: 2.9807
# Epoch 14/252
# 13669/13669 [==============================] - 1s 54us/sample - loss: 2.8341
# Epoch 15/252
# 13669/13669 [==============================] - 1s 53us/sample - loss: 2.7105
# Epoch 16/252
# 13669/13669 [==============================] - 1s 52us/sample - loss: 2.5980
# Epoch 17/252
# 13669/13669 [==============================] - 1s 54us/sample - loss: 2.5316
# Epoch 18/252
# 13669/13669 [==============================] - 1s 53us/sample - loss: 2.4701
# Epoch 19/252
# 13669/13669 [==============================] - 1s 53us/sample - loss: 2.4483
# Epoch 20/252
# 13669/13669 [==============================] - 1s 54us/sample - loss: 2.4096
# Epoch 21/252
# 13669/13669 [==============================] - 1s 54us/sample - loss: 2.3730
# Epoch 22/252
# 13669/13669 [==============================] - 1s 53us/sample - loss: 2.3397
# Epoch 23/252
# 13669/13669 [==============================] - 1s 54us/sample - loss: 2.3354
# Epoch 24/252
# 13669/13669 [==============================] - 1s 55us/sample - loss: 2.2997
# Epoch 25/252
# 13669/13669 [==============================] - 1s 54us/sample - loss: 2.2346
# Epoch 26/252
# 13669/13669 [==============================] - 1s 54us/sample - loss: 2.2697
# Epoch 27/252
# 13669/13669 [==============================] - 1s 53us/sample - loss: 2.2564
# Epoch 28/252
# 13669/13669 [==============================] - 1s 53us/sample - loss: 2.2364
# Epoch 29/252
# 13669/13669 [==============================] - 1s 54us/sample - loss: 2.2118
# Epoch 30/252
# 13669/13669 [==============================] - 1s 54us/sample - loss: 2.1604
# Epoch 31/252
# 13669/13669 [==============================] - 1s 53us/sample - loss: 2.1804
# Epoch 32/252
# 13669/13669 [==============================] - 1s 56us/sample - loss: 2.1251
# Epoch 33/252
# 13669/13669 [==============================] - 1s 53us/sample - loss: 2.1310
# Epoch 34/252
# 13669/13669 [==============================] - 1s 53us/sample - loss: 2.1191
# Epoch 35/252
# 13669/13669 [==============================] - 1s 54us/sample - loss: 2.0903
# Epoch 36/252
# 13669/13669 [==============================] - 1s 52us/sample - loss: 2.0752
# Epoch 37/252
# 13669/13669 [==============================] - 1s 55us/sample - loss: 2.0534
# Epoch 38/252
# 13669/13669 [==============================] - 1s 56us/sample - loss: 2.0470
# Epoch 39/252
# 13669/13669 [==============================] - 1s 56us/sample - loss: 2.0221
# Epoch 40/252
# 13669/13669 [==============================] - 1s 55us/sample - loss: 2.0009
# Epoch 41/252
# 13669/13669 [==============================] - 1s 54us/sample - loss: 1.9383
# Epoch 42/252
# 13669/13669 [==============================] - 1s 56us/sample - loss: 1.9603
# Epoch 43/252
# 13669/13669 [==============================] - 1s 55us/sample - loss: 1.9643
# Epoch 44/252
# 13669/13669 [==============================] - 1s 54us/sample - loss: 1.9249
# Epoch 45/252
# 13669/13669 [==============================] - 1s 53us/sample - loss: 1.9149
# Epoch 46/252
# 13669/13669 [==============================] - 1s 53us/sample - loss: 1.8636
# Epoch 47/252
# 13669/13669 [==============================] - 1s 54us/sample - loss: 1.8638
# Epoch 48/252
# 13669/13669 [==============================] - 1s 54us/sample - loss: 1.8480
# Epoch 49/252
# 13669/13669 [==============================] - 1s 52us/sample - loss: 1.8593
# Epoch 50/252
# 13669/13669 [==============================] - 1s 50us/sample - loss: 1.8421
# Epoch 51/252
# 13669/13669 [==============================] - 1s 50us/sample - loss: 1.8035
# Epoch 52/252
# 13669/13669 [==============================] - 1s 50us/sample - loss: 1.8055
# Epoch 53/252
# 13669/13669 [==============================] - 1s 50us/sample - loss: 1.7862
# Epoch 54/252
# 13669/13669 [==============================] - 1s 50us/sample - loss: 1.7482
# Epoch 55/252
# 13669/13669 [==============================] - 1s 52us/sample - loss: 1.7358
# Epoch 56/252
# 13669/13669 [==============================] - 1s 50us/sample - loss: 1.7139
# Epoch 57/252
# 13669/13669 [==============================] - 1s 51us/sample - loss: 1.7212
# Epoch 58/252
# 13669/13669 [==============================] - 1s 51us/sample - loss: 1.7131
# Epoch 59/252
# 13669/13669 [==============================] - 1s 49us/sample - loss: 1.7118
# Epoch 60/252
# 13669/13669 [==============================] - 1s 49us/sample - loss: 1.6877
# Epoch 61/252
# 13669/13669 [==============================] - 1s 53us/sample - loss: 1.6765
# Epoch 62/252
# 13669/13669 [==============================] - 1s 61us/sample - loss: 1.6762
# Epoch 63/252
# 13669/13669 [==============================] - 1s 50us/sample - loss: 1.6545
# Epoch 64/252
# 13669/13669 [==============================] - 1s 51us/sample - loss: 1.6230
# Epoch 65/252
# 13669/13669 [==============================] - 1s 50us/sample - loss: 1.6384
# Epoch 66/252
# 13669/13669 [==============================] - 1s 50us/sample - loss: 1.6244
# Epoch 67/252
# 13669/13669 [==============================] - 1s 50us/sample - loss: 1.6390
# Epoch 68/252
# 13669/13669 [==============================] - 1s 48us/sample - loss: 1.6275
# Epoch 69/252
# 13669/13669 [==============================] - 1s 50us/sample - loss: 1.6310
# Epoch 70/252
# 13669/13669 [==============================] - 1s 50us/sample - loss: 1.6269
# Epoch 71/252
# 13669/13669 [==============================] - 1s 48us/sample - loss: 1.6094
# Epoch 72/252
# 13669/13669 [==============================] - 1s 49us/sample - loss: 1.5992
# Epoch 73/252
# 13669/13669 [==============================] - 1s 50us/sample - loss: 1.6093
# Epoch 74/252
# 13669/13669 [==============================] - 1s 49us/sample - loss: 1.5928
# Epoch 75/252
# 13669/13669 [==============================] - 1s 49us/sample - loss: 1.5760
# Epoch 76/252
# 13669/13669 [==============================] - 1s 49us/sample - loss: 1.5837
# Epoch 77/252
# 13669/13669 [==============================] - 1s 49us/sample - loss: 1.5758
# Epoch 78/252
# 13669/13669 [==============================] - 1s 49us/sample - loss: 1.5881
# Epoch 79/252
# 13669/13669 [==============================] - 1s 50us/sample - loss: 1.5650
# Epoch 80/252
# 13669/13669 [==============================] - 1s 49us/sample - loss: 1.5739
# Epoch 81/252
# 13669/13669 [==============================] - 1s 49us/sample - loss: 1.5404
# Epoch 82/252
# 13669/13669 [==============================] - 1s 51us/sample - loss: 1.5745
# Epoch 83/252
# 13669/13669 [==============================] - 1s 50us/sample - loss: 1.5408
# Epoch 84/252
# 13669/13669 [==============================] - 1s 48us/sample - loss: 1.5562
# Epoch 85/252
# 13669/13669 [==============================] - 1s 49us/sample - loss: 1.5624
# Epoch 86/252
# 13669/13669 [==============================] - 1s 49us/sample - loss: 1.5545
# Epoch 87/252
# 13669/13669 [==============================] - 1s 50us/sample - loss: 1.5483
# Epoch 88/252
# 13669/13669 [==============================] - 1s 48us/sample - loss: 1.5570
# Epoch 89/252
# 13669/13669 [==============================] - 1s 49us/sample - loss: 1.5595
# Epoch 90/252
# 13669/13669 [==============================] - 1s 49us/sample - loss: 1.5794
# Epoch 91/252
# 13669/13669 [==============================] - 1s 50us/sample - loss: 1.5588
# Epoch 92/252
# 13669/13669 [==============================] - 1s 49us/sample - loss: 1.5738
# Epoch 93/252
# 13669/13669 [==============================] - 1s 50us/sample - loss: 1.5611
# Epoch 94/252
# 13669/13669 [==============================] - 1s 50us/sample - loss: 1.5616
# Epoch 95/252
# 13669/13669 [==============================] - 1s 50us/sample - loss: 1.5756
# Epoch 96/252
# 13669/13669 [==============================] - 1s 50us/sample - loss: 1.5220
# Epoch 97/252
# 13669/13669 [==============================] - 1s 48us/sample - loss: 1.5706
# Epoch 98/252
# 13669/13669 [==============================] - 1s 47us/sample - loss: 1.5809
# Epoch 99/252
# 13669/13669 [==============================] - 1s 46us/sample - loss: 1.5688
# Epoch 100/252
# 13669/13669 [==============================] - 1s 46us/sample - loss: 1.5603
# Epoch 101/252
# 13669/13669 [==============================] - 1s 47us/sample - loss: 1.5420
# Epoch 102/252
# 13669/13669 [==============================] - 1s 48us/sample - loss: 1.5656
# Epoch 103/252
# 13669/13669 [==============================] - 1s 48us/sample - loss: 1.5586
# Epoch 104/252
# 13669/13669 [==============================] - 1s 46us/sample - loss: 1.5821
# Epoch 105/252
# 13669/13669 [==============================] - 1s 47us/sample - loss: 1.5610
# Epoch 106/252
# 13669/13669 [==============================] - 1s 47us/sample - loss: 1.5304
# Epoch 107/252
# 13669/13669 [==============================] - 1s 48us/sample - loss: 1.5544
# Epoch 108/252
# 13669/13669 [==============================] - 1s 47us/sample - loss: 1.5532
# Epoch 109/252
# 13669/13669 [==============================] - 1s 47us/sample - loss: 1.6068
# Epoch 110/252
# 13669/13669 [==============================] - 1s 47us/sample - loss: 1.5598
# Epoch 111/252
# 13669/13669 [==============================] - 1s 49us/sample - loss: 1.5451
# Epoch 112/252
# 13669/13669 [==============================] - 1s 46us/sample - loss: 1.5787
# Epoch 113/252
# 13669/13669 [==============================] - 1s 46us/sample - loss: 1.5732
# Epoch 114/252
# 13669/13669 [==============================] - 1s 46us/sample - loss: 1.5705
# Epoch 115/252
# 13669/13669 [==============================] - 1s 46us/sample - loss: 1.5814
# Epoch 116/252
# 13669/13669 [==============================] - 1s 46us/sample - loss: 1.5762
# Epoch 117/252
# 13669/13669 [==============================] - 1s 46us/sample - loss: 1.5597
# Epoch 118/252
# 13669/13669 [==============================] - 1s 45us/sample - loss: 1.5509
# Epoch 119/252
# 13669/13669 [==============================] - 1s 45us/sample - loss: 1.5599
# Epoch 120/252
# 13669/13669 [==============================] - 1s 46us/sample - loss: 1.5613
# Epoch 121/252
# 13669/13669 [==============================] - 1s 45us/sample - loss: 1.5522
# Epoch 122/252
# 13669/13669 [==============================] - 1s 45us/sample - loss: 1.5636
# Epoch 123/252
# 13669/13669 [==============================] - 1s 46us/sample - loss: 1.5546
# Epoch 124/252
# 13669/13669 [==============================] - 1s 45us/sample - loss: 1.5668
# Epoch 125/252
# 13669/13669 [==============================] - 1s 46us/sample - loss: 1.5649
# Epoch 126/252
# 13669/13669 [==============================] - 1s 45us/sample - loss: 1.5492
# Epoch 127/252
# 13669/13669 [==============================] - 1s 44us/sample - loss: 1.5468
# Epoch 128/252
# 13669/13669 [==============================] - 1s 45us/sample - loss: 1.5777
# Epoch 129/252
# 13669/13669 [==============================] - 1s 45us/sample - loss: 1.5344
# Epoch 130/252
# 13669/13669 [==============================] - 1s 45us/sample - loss: 1.5752
# Epoch 131/252
# 13669/13669 [==============================] - 1s 45us/sample - loss: 1.5556
# Epoch 132/252
# 13669/13669 [==============================] - 1s 45us/sample - loss: 1.5935
# Epoch 133/252
# 13669/13669 [==============================] - 1s 44us/sample - loss: 1.5738
# Epoch 134/252
# 13669/13669 [==============================] - 1s 46us/sample - loss: 1.5943
# Epoch 135/252
# 13669/13669 [==============================] - 1s 45us/sample - loss: 1.5763
# Epoch 136/252
# 13669/13669 [==============================] - 1s 45us/sample - loss: 1.6030
# Epoch 137/252
# 13669/13669 [==============================] - 1s 45us/sample - loss: 1.5869
# Epoch 138/252
# 13669/13669 [==============================] - 1s 45us/sample - loss: 1.6145
# Epoch 139/252
# 13669/13669 [==============================] - 1s 45us/sample - loss: 1.5643
# Epoch 140/252
# 13669/13669 [==============================] - 1s 45us/sample - loss: 1.5946
# Epoch 141/252
# 13669/13669 [==============================] - 1s 45us/sample - loss: 1.6127
# Epoch 142/252
# 13669/13669 [==============================] - 1s 44us/sample - loss: 1.5922
# Epoch 143/252
# 13669/13669 [==============================] - 1s 45us/sample - loss: 1.5881
# Epoch 144/252
# 13669/13669 [==============================] - 1s 45us/sample - loss: 1.5862
# Epoch 145/252
# 13669/13669 [==============================] - 1s 45us/sample - loss: 1.5931
# Epoch 146/252
# 13669/13669 [==============================] - 1s 45us/sample - loss: 1.5908
# Epoch 147/252
# 13669/13669 [==============================] - 1s 45us/sample - loss: 1.5928
# Epoch 148/252
# 13669/13669 [==============================] - 1s 45us/sample - loss: 1.5937
# Epoch 149/252
# 13669/13669 [==============================] - 1s 55us/sample - loss: 1.5995
# Epoch 150/252
# 13669/13669 [==============================] - 1s 59us/sample - loss: 1.5981
# Epoch 151/252
# 13669/13669 [==============================] - 1s 44us/sample - loss: 1.5784
# Epoch 152/252
# 13669/13669 [==============================] - 1s 45us/sample - loss: 1.5784
# Epoch 153/252
# 13669/13669 [==============================] - 1s 44us/sample - loss: 1.6077
# Epoch 154/252
# 13669/13669 [==============================] - 1s 44us/sample - loss: 1.5652
# Epoch 155/252
# 13669/13669 [==============================] - 1s 46us/sample - loss: 1.5873
# Epoch 156/252
# 13669/13669 [==============================] - 1s 44us/sample - loss: 1.5828
# Epoch 157/252
# 13669/13669 [==============================] - 1s 44us/sample - loss: 1.6336
# Epoch 158/252
# 13669/13669 [==============================] - 1s 44us/sample - loss: 1.5853
# Epoch 159/252
# 13669/13669 [==============================] - 1s 45us/sample - loss: 1.6180
# Epoch 160/252
# 13669/13669 [==============================] - 1s 45us/sample - loss: 1.5934
# Epoch 161/252
# 13669/13669 [==============================] - 1s 45us/sample - loss: 1.5987
# Epoch 162/252
# 13669/13669 [==============================] - 1s 44us/sample - loss: 1.6057
# Epoch 163/252
# 13669/13669 [==============================] - 1s 45us/sample - loss: 1.5964
# Epoch 164/252
# 13669/13669 [==============================] - 1s 44us/sample - loss: 1.5677
# Epoch 165/252
# 13669/13669 [==============================] - 1s 44us/sample - loss: 1.5864
# Epoch 166/252
# 13669/13669 [==============================] - 1s 44us/sample - loss: 1.6071
# Epoch 167/252
# 13669/13669 [==============================] - 1s 44us/sample - loss: 1.5820
# Epoch 168/252
# 13669/13669 [==============================] - 1s 44us/sample - loss: 1.6110
# Epoch 169/252
# 13669/13669 [==============================] - 1s 45us/sample - loss: 1.5938
# Epoch 170/252
# 13669/13669 [==============================] - 1s 44us/sample - loss: 1.5947
# Epoch 171/252
# 13669/13669 [==============================] - 1s 45us/sample - loss: 1.5761
# Epoch 172/252
# 13669/13669 [==============================] - 1s 45us/sample - loss: 1.6106
# Epoch 173/252
# 13669/13669 [==============================] - 1s 45us/sample - loss: 1.5995
# Epoch 174/252
# 13669/13669 [==============================] - 1s 44us/sample - loss: 1.5833
# Epoch 175/252
# 13669/13669 [==============================] - 1s 45us/sample - loss: 1.6181
# Epoch 176/252
# 13669/13669 [==============================] - 1s 45us/sample - loss: 1.5918
# Epoch 177/252
# 13669/13669 [==============================] - 1s 44us/sample - loss: 1.6254
# Epoch 178/252
# 13669/13669 [==============================] - 1s 44us/sample - loss: 1.6278
# Epoch 179/252
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6026
# Epoch 180/252
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6229
# Epoch 181/252
# 13669/13669 [==============================] - 1s 43us/sample - loss: 1.5870
# Epoch 182/252
# 13669/13669 [==============================] - 1s 43us/sample - loss: 1.6020
# Epoch 183/252
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.5919
# Epoch 184/252
# 13669/13669 [==============================] - 1s 43us/sample - loss: 1.5906
# Epoch 185/252
# 13669/13669 [==============================] - 1s 43us/sample - loss: 1.6184
# Epoch 186/252
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.5857
# Epoch 187/252
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.5776
# Epoch 188/252
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6062
# Epoch 189/252
# 13669/13669 [==============================] - 1s 43us/sample - loss: 1.6234
# Epoch 190/252
# 13669/13669 [==============================] - 1s 43us/sample - loss: 1.6042
# Epoch 191/252
# 13669/13669 [==============================] - 1s 43us/sample - loss: 1.6056
# Epoch 192/252
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.5956
# Epoch 193/252
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.5846
# Epoch 194/252
# 13669/13669 [==============================] - 1s 43us/sample - loss: 1.6124
# Epoch 195/252
# 13669/13669 [==============================] - 1s 43us/sample - loss: 1.5833
# Epoch 196/252
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.5473
# Epoch 197/252
# 13669/13669 [==============================] - 1s 43us/sample - loss: 1.6202
# Epoch 198/252
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.5880
# Epoch 199/252
# 13669/13669 [==============================] - 1s 43us/sample - loss: 1.5750
# Epoch 200/252
# 13669/13669 [==============================] - 1s 45us/sample - loss: 1.6174
# Epoch 201/252
# 13669/13669 [==============================] - 1s 46us/sample - loss: 1.5652
# Epoch 202/252
# 13669/13669 [==============================] - 1s 44us/sample - loss: 1.5663
# Epoch 203/252
# 13669/13669 [==============================] - 1s 51us/sample - loss: 1.5871
# Epoch 204/252
# 13669/13669 [==============================] - 1s 58us/sample - loss: 1.5697
# Epoch 205/252
# 13669/13669 [==============================] - 1s 59us/sample - loss: 1.6022
# Epoch 206/252
# 13669/13669 [==============================] - 1s 61us/sample - loss: 1.5778
# Epoch 207/252
# 13669/13669 [==============================] - 1s 61us/sample - loss: 1.5939
# Epoch 208/252
# 13669/13669 [==============================] - 1s 58us/sample - loss: 1.5973
# Epoch 209/252
# 13669/13669 [==============================] - 1s 55us/sample - loss: 1.5809
# Epoch 210/252
# 13669/13669 [==============================] - 1s 60us/sample - loss: 1.5867
# Epoch 211/252
# 13669/13669 [==============================] - 1s 58us/sample - loss: 1.5863
# Epoch 212/252
# 13669/13669 [==============================] - 1s 57us/sample - loss: 1.5860
# Epoch 213/252
# 13669/13669 [==============================] - 1s 58us/sample - loss: 1.5546
# Epoch 214/252
# 13669/13669 [==============================] - 1s 61us/sample - loss: 1.5993
# Epoch 215/252
# 13669/13669 [==============================] - 1s 54us/sample - loss: 1.5801
# Epoch 216/252
# 13669/13669 [==============================] - 1s 60us/sample - loss: 1.5978
# Epoch 217/252
# 13669/13669 [==============================] - 1s 57us/sample - loss: 1.5606
# Epoch 218/252
# 13669/13669 [==============================] - 1s 55us/sample - loss: 1.6184
# Epoch 219/252
# 13669/13669 [==============================] - 1s 61us/sample - loss: 1.5710
# Epoch 220/252
# 13669/13669 [==============================] - 1s 66us/sample - loss: 1.6224
# Epoch 221/252
# 13669/13669 [==============================] - 1s 73us/sample - loss: 1.5987
# Epoch 222/252
# 13669/13669 [==============================] - 1s 75us/sample - loss: 1.5799
# Epoch 223/252
# 13669/13669 [==============================] - 1s 75us/sample - loss: 1.5937
# Epoch 224/252
# 13669/13669 [==============================] - 1s 79us/sample - loss: 1.6152
# Epoch 225/252
# 13669/13669 [==============================] - 1s 79us/sample - loss: 1.6278
# Epoch 226/252
# 13669/13669 [==============================] - 1s 77us/sample - loss: 1.6109
# Epoch 227/252
# 13669/13669 [==============================] - 1s 77us/sample - loss: 1.6086
# Epoch 228/252
# 13669/13669 [==============================] - 1s 78us/sample - loss: 1.6115
# Epoch 229/252
# 13669/13669 [==============================] - 1s 79us/sample - loss: 1.6138
# Epoch 230/252
# 13669/13669 [==============================] - 1s 75us/sample - loss: 1.5645
# Epoch 231/252
# 13669/13669 [==============================] - 1s 77us/sample - loss: 1.5846
# Epoch 232/252
# 13669/13669 [==============================] - 1s 77us/sample - loss: 1.6046
# Epoch 233/252
# 13669/13669 [==============================] - 1s 73us/sample - loss: 1.6300
# Epoch 234/252
# 13669/13669 [==============================] - 1s 62us/sample - loss: 1.6188
# Epoch 235/252
# 13669/13669 [==============================] - 1s 44us/sample - loss: 1.6124
# Epoch 236/252
# 13669/13669 [==============================] - 1s 44us/sample - loss: 1.6072
# Epoch 237/252
# 13669/13669 [==============================] - 1s 43us/sample - loss: 1.6156
# Epoch 238/252
# 13669/13669 [==============================] - 1s 44us/sample - loss: 1.6552
# Epoch 239/252
# 13669/13669 [==============================] - 1s 44us/sample - loss: 1.5899
# Epoch 240/252
# 13669/13669 [==============================] - 1s 43us/sample - loss: 1.6054
# Epoch 241/252
# 13669/13669 [==============================] - 1s 44us/sample - loss: 1.6160
# Epoch 242/252
# 13669/13669 [==============================] - 1s 44us/sample - loss: 1.6009
# Epoch 243/252
# 13669/13669 [==============================] - 1s 43us/sample - loss: 1.6573
# Epoch 244/252
# 13669/13669 [==============================] - 1s 49us/sample - loss: 1.6288
# Epoch 245/252
# 13669/13669 [==============================] - 1s 61us/sample - loss: 1.6449
# Epoch 246/252
# 13669/13669 [==============================] - 1s 53us/sample - loss: 1.6510
# Epoch 247/252
# 13669/13669 [==============================] - 1s 54us/sample - loss: 1.6547
# Epoch 248/252
# 13669/13669 [==============================] - 1s 54us/sample - loss: 1.6569
# Epoch 249/252
# 13669/13669 [==============================] - 1s 51us/sample - loss: 1.6377
# Epoch 250/252
# 13669/13669 [==============================] - 1s 51us/sample - loss: 1.6623
# Epoch 251/252
# 13669/13669 [==============================] - 1s 51us/sample - loss: 1.6654
# Epoch 252/252
# 13669/13669 [==============================] - 1s 51us/sample - loss: 1.7037
# Training time: 175.37369871139526
# /home/andressa.amaral/.local/lib/python3.7/site-packages/keras/engine/training_v1.py:2356: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# Testing time: 22.860393524169922

# %% [markdown]
# # Metrics

# %%
# Examinig the latent space generated by the encoder
X_encoded = encoder.predict(X_test)

pca = PCA(n_components=2)
X_analysis = pca.fit_transform(X_encoded)
# Out:
# /home/andressa.amaral/.local/lib/python3.7/site-packages/keras/engine/training_v1.py:2356: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,

# %%
plt.figure(figsize=(8, 8))
sns.scatterplot(x = X_analysis[:, 0], y = X_analysis[:, 1], s = 20, hue = Y_pred)
plt.grid()
plt.savefig("Results/PCA/S3_" + str(number_features))
plt.show()

# Orange ones are anomalies

# %%
plt.figure(figsize = (8, 8))
sns.scatterplot(x = X_analysis[:, 0], y = X_analysis[:, 1], s = 20, hue = Y_test)
plt.grid()
plt.savefig("Results/PCA Groundtruth/S3_" + str(number_features))
plt.show()

# Ground truth

# %%
conf_matrix = confusion_matrix(Y_test, Y_pred)

fig, ax = plt.subplots(figsize = (5, 5))
ax.matshow(conf_matrix, cmap = plt.cm.Blues, alpha = 0.3)
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        ax.text(x = j, y = i,s = conf_matrix[i, j], va = 'center', ha = 'center', size = 'large')
 
plt.xlabel('Predictions', fontsize=12)
plt.ylabel('Actuals', fontsize=12)
plt.title('Confusion Matrix', fontsize=14)
plt.savefig("Results/Confusion Matrix/S3_" + str(number_features))
plt.show()
