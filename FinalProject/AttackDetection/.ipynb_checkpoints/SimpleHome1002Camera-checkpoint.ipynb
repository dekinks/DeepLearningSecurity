# %%
# !pip3 install pandas
# !pip3 install seaborn
# !pip3 install --upgrade tensorflow-gpu
# !pip3 install import-ipynb
# !pip3 install cuda-python

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 

from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import math
import pickle
import time
import sys

import import_ipynb
import AttackDetectionModel

import tensorflow as tf
tf.compat.v1.disable_eager_execution()
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras import optimizers

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.metrics import f1_score, confusion_matrix

from bayes_opt import BayesianOptimization

# %matplotlib inline
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/andressa.amaral/.local/lib/python3.7/site-packages (1.3.5)
# Requirement already satisfied: numpy>=1.17.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from pandas) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from pandas) (2022.1)
# Requirement already satisfied: six>=1.5 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# WARNING: You are using pip version 22.0.4; however, version 22.3 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in /home/andressa.amaral/.local/lib/python3.7/site-packages (0.11.2)
# Requirement already satisfied: matplotlib>=2.2 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from seaborn) (3.5.1)
# Requirement already satisfied: scipy>=1.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from seaborn) (1.7.3)
# Requirement already satisfied: pandas>=0.23 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from seaborn) (1.3.5)
# Requirement already satisfied: numpy>=1.15 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from seaborn) (1.21.5)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (3.0.7)
# Requirement already satisfied: packaging>=20.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: cycler>=0.10 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (4.31.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (9.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (1.4.0)
# Requirement already satisfied: pytz>=2017.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from pandas>=0.23->seaborn) (2022.1)
# Requirement already satisfied: typing-extensions in /home/andressa.amaral/.local/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib>=2.2->seaborn) (4.1.1)
# Requirement already satisfied: six>=1.5 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# WARNING: You are using pip version 22.0.4; however, version 22.3 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow-gpu in /home/andressa.amaral/.local/lib/python3.7/site-packages (2.10.0)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (2.10.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (0.2.0)
# Requirement already satisfied: setuptools in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (60.10.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.1.0)
# Requirement already satisfied: h5py>=2.9.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (3.6.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (3.3.0)
# Requirement already satisfied: packaging in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (21.3)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (3.19.4)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.1.2)
# Requirement already satisfied: numpy>=1.20 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.21.5)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.44.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (13.0.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (0.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (4.1.1)
# Requirement already satisfied: six>=1.12.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.16.0)
# Requirement already satisfied: absl-py>=1.0.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.0.0)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (2.10.0)
# Requirement already satisfied: keras<2.11,>=2.10.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (2.10.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (0.24.0)
# Requirement already satisfied: flatbuffers>=2.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (2.0.7)
# Requirement already satisfied: wrapt>=1.11.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.14.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.6.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/lib/python3/dist-packages (from astunparse>=1.6.0->tensorflow-gpu) (0.30.0)
# Requirement already satisfied: cached-property in /home/andressa.amaral/.local/lib/python3.7/site-packages (from h5py>=2.9.0->tensorflow-gpu) (1.5.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (2.6.2)
# Requirement already satisfied: markdown>=2.6.8 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (3.3.6)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (0.4.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (2.27.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (2.0.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from packaging->tensorflow-gpu) (3.0.7)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow-gpu) (5.0.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow-gpu) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow-gpu) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow-gpu) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow-gpu) (4.11.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow-gpu) (2.6)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow-gpu) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow-gpu) (2018.1.18)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow-gpu) (2.0.12)
# Requirement already satisfied: zipp>=0.5 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow-gpu) (3.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow-gpu) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow-gpu) (3.2.0)
# WARNING: You are using pip version 22.0.4; however, version 22.3 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: import-ipynb in /home/andressa.amaral/.local/lib/python3.7/site-packages (0.1.3)
# WARNING: You are using pip version 22.0.4; however, version 22.3 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: cuda-python in /home/andressa.amaral/.local/lib/python3.7/site-packages (11.8.0)
# Requirement already satisfied: cython in /home/andressa.amaral/.local/lib/python3.7/site-packages (from cuda-python) (0.29.32)
# WARNING: You are using pip version 22.0.4; however, version 22.3 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# importing Jupyter notebook from AttackDetectionModel.ipynb
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/andressa.amaral/.local/lib/python3.7/site-packages (1.3.5)
# Requirement already satisfied: pytz>=2017.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from pandas) (2022.1)
# Requirement already satisfied: numpy>=1.17.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from pandas) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# WARNING: You are using pip version 22.0.4; however, version 22.3 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow-gpu in /home/andressa.amaral/.local/lib/python3.7/site-packages (2.10.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.14.0)
# Requirement already satisfied: packaging in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (21.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (0.4.0)
# Requirement already satisfied: numpy>=1.20 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.21.5)
# Requirement already satisfied: absl-py>=1.0.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.0.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.1.0)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (2.10.0)
# Requirement already satisfied: setuptools in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (60.10.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (4.1.1)
# Requirement already satisfied: keras<2.11,>=2.10.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (2.10.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.6.3)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.1.2)
# Requirement already satisfied: libclang>=13.0.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (13.0.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (0.24.0)
# Requirement already satisfied: h5py>=2.9.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (3.6.0)
# Requirement already satisfied: flatbuffers>=2.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (2.0.7)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (3.3.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.44.0)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (2.10.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (3.19.4)
# Requirement already satisfied: six>=1.12.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.16.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (0.2.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/lib/python3/dist-packages (from astunparse>=1.6.0->tensorflow-gpu) (0.30.0)
# Requirement already satisfied: cached-property in /home/andressa.amaral/.local/lib/python3.7/site-packages (from h5py>=2.9.0->tensorflow-gpu) (1.5.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (2.6.2)
# Requirement already satisfied: markdown>=2.6.8 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (3.3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (2.27.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (0.4.6)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (2.0.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from packaging->tensorflow-gpu) (3.0.7)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow-gpu) (4.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow-gpu) (5.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow-gpu) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow-gpu) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow-gpu) (4.11.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow-gpu) (1.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow-gpu) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow-gpu) (2.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow-gpu) (2018.1.18)
# Requirement already satisfied: zipp>=0.5 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow-gpu) (3.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow-gpu) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow-gpu) (3.2.0)
# WARNING: You are using pip version 22.0.4; however, version 22.3 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
gpu_options = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction = 0.333)
sess = tf.compat.v1.Session(config = tf.compat.v1.ConfigProto(gpu_options = gpu_options))

# %% [markdown]
# # Data Pre-Processing

# %%
#number_features = 115
#number_features = 92
#number_features = 69
#number_features = 46
number_features = 23

# %%
# Get benign traffic 
df_s2_benign = AttackDetectionModel.get_files('../../nbaiot/SimpleHome_XCS7_1002_WHT_Security_Camera', number_features)

# Get Bashlite traffic
df_s2_bashlite = AttackDetectionModel.get_files('../../nbaiot/SimpleHome_XCS7_1002_WHT_Security_Camera/gafgyt', number_features)

# Get Mirai traffic
df_s2_mirai = AttackDetectionModel.get_files('../../nbaiot/SimpleHome_XCS7_1002_WHT_Security_Camera/mirai', number_features)

# %%
# Normalize with the min-max scaler
scaler = MinMaxScaler()
df_s2_benign_norm = scaler.fit_transform(df_s2_benign)
df_s2_bashlite_norm = scaler.fit_transform(df_s2_bashlite)
df_s2_mirai_norm = scaler.fit_transform(df_s2_mirai)

# %% [markdown]
# # Sets

# %%
# Train set
len_benign_train = int(0.7 * len(df_s2_benign_norm))
X_train = df_s2_benign_norm[:len_benign_train]

# %%
# Test set
X_test_benign = df_s2_benign_norm[len_benign_train:]
X_test = np.concatenate([X_test_benign, df_s2_bashlite_norm, df_s2_mirai_norm])

Y_test = np.ones(len(X_test))
Y_test[:len(X_test_benign)] = 0

# %% [markdown]
# # Model

# %%
# Parameters
original_dim = X_train.shape[1]
input_shape = (original_dim,)
intermediate_dim = int(original_dim / 2)
latent_dim = int(original_dim / 3)

# Initial values
epochs = 5
learning_rate = 0.00005
batch_size = 23
anomaly_threshold = 0.056

# Dictionary
dict_params = { 'learning_rate': learning_rate, 'batch_size': round(batch_size), 'epochs': round(epochs)}
pbounds = { 'learning_rate': (0.000001, 0.001), 'batch_size': (10, 100), 'epochs': (50, 500)}

# %%
# KL Loss function
def vae_loss(x, x_decoded_mean):
    # Compute the average MSE error, then scale it up (sum on all axes)
    
    reconstruction_loss = K.sum(K.square(x - x_decoded_mean))
    
    # Compute the KL loss
    
    kl_loss = - 0.5 * K.sum(1 + z_var - K.square(z_mean) - K.square(K.exp(z_var)), axis=-1)
    
    # Return the average loss over all 
    
    total_loss = K.mean(reconstruction_loss + kl_loss) # Total_loss = reconstruction_loss + kl_loss 
    return total_loss

# (1) Reconstruction Loss - Forces the encoder to generate latent features that minimize the reconstruction error, or else is
# penalized
# (2) KL Loss - Forces the distribution generated by the encoder to be similar to the prior probability of the input vector, 
# pushing latent feature space to normality

# %%
# Encoder
inputs, encoder, z_var, z_mean = AttackDetectionModel.vae_encoder(input_shape, 
                                                                  intermediate_dim, 
                                                                  latent_dim, 
                                                                  AttackDetectionModel.reparametrization)
encoder.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  encoder_input (InputLayer)     [(None, 23)]         0           []
#
#  dense (Dense)                  (None, 11)           264         ['encoder_input[0][0]']
#
#  z_mean (Dense)                 (None, 7)            84          ['dense[0][0]']
#
#  z_var (Dense)                  (None, 7)            84          ['dense[0][0]']
#
#  z (Lambda)                     (None, 7)            0           ['z_mean[0][0]',
#                                                                   'z_var[0][0]']
#
# ==================================================================================================
# Total params: 432
# Trainable params: 432
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Decoder
decoder = AttackDetectionModel.vae_decoder(intermediate_dim, latent_dim, original_dim)
outputs = decoder(encoder(inputs))
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  z_sampling (InputLayer)     [(None, 7)]               0
#
#  dense_1 (Dense)             (None, 11)                88
#
#  dense_2 (Dense)             (None, 23)                276
#
# =================================================================
# Total params: 364
# Trainable params: 364
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Hyperparameter Optimization

# %%
def maximize_training(X_train = X_train, 
                      X_test = X_test, 
                      Y_test = Y_test, 
                      inputs = inputs, 
                      outputs = outputs, 
                      vae_loss = vae_loss,
                      learning_rate = learning_rate,
                      batch_size = batch_size,
                      epochs = epochs,
                      anomaly_threshold = anomaly_threshold):    
    
    # Create model
    opt_adam = optimizers.Adam(learning_rate = dict_params['learning_rate'], clipvalue = 0.5)
    model = Model(inputs, outputs, name = 'vae_mlp')
    model.compile(optimizer = opt_adam, loss = vae_loss)

    # Train
    history = model.fit(X_train, 
                        X_train, 
                        shuffle = True, 
                        verbose = 0,
                        epochs = dict_params['epochs'], 
                        batch_size = dict_params['batch_size'])
    
    # Maximize the f1-score
    X_pred_opt = model.predict(X_test)
    error_vector_opt = AttackDetectionModel.get_error_term(X_pred_opt, X_test, _rmse = False)
    Y_pred_opt = (error_vector_opt > anomaly_threshold)
    f1 = f1_score(Y_test, Y_pred_opt)
    
    return f1

# %%
'''
# Apply Bayesian optimization to choose the best hyperparameters

opt = BayesianOptimization(f = maximize_training,
                           pbounds = pbounds,
                           verbose = 2, 
                           random_state = 1)

opt_start = time.time()

opt.maximize(init_points = 5, n_iter = 5)

opt_end = time.time()
opt_time = opt_end - opt_start
print("Optimization time:", opt_time)

learning_rate = opt.max['params']['learning_rate']
epochs = round(opt.max['params']['epochs'])
batch_size = round(opt.max['params']['batch_size'])
'''
# Out:
# '\n# Apply Bayesian optimization to choose the best hyperparameters\n\nopt = BayesianOptimization(f = maximize_training,\n                           pbounds = pbounds,\n                           verbose = 2, \n                           random_state = 1)\n\nopt_start = time.time()\n\nopt.maximize(init_points = 5, n_iter = 5)\n\nopt_end = time.time()\nopt_time = opt_end - opt_start\nprint("Optimization time:", opt_time)\n\nlearning_rate = opt.max[\'params\'][\'learning_rate\']\nepochs = round(opt.max[\'params\'][\'epochs\'])\nbatch_size = round(opt.max[\'params\'][\'batch_size\'])\n'

# %% [markdown]
# # Predict Attacks

# %%
# Training step with the best hyperparameters
learning_rate = 0.0004682796608461357
epochs = 259
batch_size = 71
opt_time = 320.2365925312042
anomaly_threshold = 0.055

# %%
for i in range(1):
    print("Iteration " + str(i))
    
    # Train
    vae_model, train_time = AttackDetectionModel.train(X_train, inputs, outputs, vae_loss, learning_rate, epochs, batch_size)
    
    # Set the optimized anomaly threshold
    #anomaly_threshold = AttackDetectionModel.get_anomaly_threshold(X_train, vae_model)
    
    # Test
    X_pred, test_time = AttackDetectionModel.test(X_test, vae_model)
    Y_test, Y_pred = AttackDetectionModel.get_prediction(Y_test, X_pred, X_test, anomaly_threshold, vae_model)
    
    # Metrics
    acc, f1, pre, rec = AttackDetectionModel.get_scores(Y_test, Y_pred)
    
    # Print results
    AttackDetectionModel.print_results(number_features,
                                       learning_rate,
                                       epochs,
                                       batch_size,
                                       anomaly_threshold,
                                       X_train,
                                       X_test,
                                       opt_time,
                                       train_time,
                                       test_time,
                                       acc,
                                       f1,
                                       pre,
                                       rec,
                                       Y_test,
                                       Y_pred,
                                       "Results/S1002_camera.txt")
    
    vae_model = None
    
    print("")
# Out:
# Iteration 0
# Train on 32609 samples
# Epoch 1/259
# 32609/32609 [==============================] - 1s 32us/sample - loss: 171.5024
# Epoch 2/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 23.3409
# Epoch 3/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 12.7700
# Epoch 4/259
# 32609/32609 [==============================] - 1s 26us/sample - loss: 10.2851
# Epoch 5/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 9.3451
# Epoch 6/259
# 32609/32609 [==============================] - 1s 26us/sample - loss: 8.3540
# Epoch 7/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 7.0641
# Epoch 8/259
# 32609/32609 [==============================] - 1s 26us/sample - loss: 6.1138
# Epoch 9/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 5.4967
# Epoch 10/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 5.0797
# Epoch 11/259
# 32609/32609 [==============================] - 1s 26us/sample - loss: 4.8207
# Epoch 12/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 4.5740
# Epoch 13/259
# 32609/32609 [==============================] - 1s 26us/sample - loss: 4.3981
# Epoch 14/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 4.2793
# Epoch 15/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 4.1539
# Epoch 16/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 4.0621
# Epoch 17/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 3.9582
# Epoch 18/259
# 32609/32609 [==============================] - 1s 26us/sample - loss: 3.8775
# Epoch 19/259
# 32609/32609 [==============================] - 1s 26us/sample - loss: 3.8074
# Epoch 20/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 3.7683
# Epoch 21/259
# 32609/32609 [==============================] - 1s 26us/sample - loss: 3.7212
# Epoch 22/259
# 32609/32609 [==============================] - 1s 26us/sample - loss: 3.6725
# Epoch 23/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 3.6419
# Epoch 24/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 3.6109
# Epoch 25/259
# 32609/32609 [==============================] - 1s 26us/sample - loss: 3.5638
# Epoch 26/259
# 32609/32609 [==============================] - 1s 26us/sample - loss: 3.5374
# Epoch 27/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 3.5191
# Epoch 28/259
# 32609/32609 [==============================] - 1s 26us/sample - loss: 3.5227
# Epoch 29/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 3.4850
# Epoch 30/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 3.4680
# Epoch 31/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 3.4474
# Epoch 32/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 3.4589
# Epoch 33/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 3.4448
# Epoch 34/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 3.4161
# Epoch 35/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 3.4253
# Epoch 36/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 3.4050
# Epoch 37/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 3.3909
# Epoch 38/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 3.4177
# Epoch 39/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 3.3786
# Epoch 40/259
# 32609/32609 [==============================] - 1s 26us/sample - loss: 3.3802
# Epoch 41/259
# 32609/32609 [==============================] - 1s 26us/sample - loss: 3.3607
# Epoch 42/259
# 32609/32609 [==============================] - 1s 26us/sample - loss: 3.3611
# Epoch 43/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 3.3499
# Epoch 44/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 3.3483
# Epoch 45/259
# 32609/32609 [==============================] - 1s 26us/sample - loss: 3.3441
# Epoch 46/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 3.3300
# Epoch 47/259
# 32609/32609 [==============================] - 1s 26us/sample - loss: 3.3139
# Epoch 48/259
# 32609/32609 [==============================] - 1s 26us/sample - loss: 3.3203
# Epoch 49/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 3.3104
# Epoch 50/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 3.2845
# Epoch 51/259
# 32609/32609 [==============================] - 1s 26us/sample - loss: 3.2691
# Epoch 52/259
# 32609/32609 [==============================] - 1s 26us/sample - loss: 3.2511
# Epoch 53/259
# 32609/32609 [==============================] - 1s 26us/sample - loss: 3.1976
# Epoch 54/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 3.1805
# Epoch 55/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 3.1629
# Epoch 56/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 3.1494
# Epoch 57/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 3.1438
# Epoch 58/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 3.1557
# Epoch 59/259
# 32609/32609 [==============================] - 1s 26us/sample - loss: 3.1231
# Epoch 60/259
# 32609/32609 [==============================] - 1s 26us/sample - loss: 3.0974
# Epoch 61/259
# 32609/32609 [==============================] - 1s 26us/sample - loss: 3.0960
# Epoch 62/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 3.1136
# Epoch 63/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 3.0817
# Epoch 64/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 3.0836
# Epoch 65/259
# 32609/32609 [==============================] - 1s 26us/sample - loss: 3.0824
# Epoch 66/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 3.0656
# Epoch 67/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 3.0763
# Epoch 68/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 3.0704
# Epoch 69/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 3.0414
# Epoch 70/259
# 32609/32609 [==============================] - 1s 26us/sample - loss: 3.0492
# Epoch 71/259
# 32609/32609 [==============================] - 1s 26us/sample - loss: 3.0236
# Epoch 72/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 3.0237
# Epoch 73/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 3.0479
# Epoch 74/259
# 32609/32609 [==============================] - 1s 26us/sample - loss: 3.0530
# Epoch 75/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 3.0619
# Epoch 76/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 3.0445
# Epoch 77/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 3.0118
# Epoch 78/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 3.0278
# Epoch 79/259
# 32609/32609 [==============================] - 1s 26us/sample - loss: 3.0419
# Epoch 80/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 3.0067
# Epoch 81/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 2.9930
# Epoch 82/259
# 32609/32609 [==============================] - 1s 26us/sample - loss: 3.0117
# Epoch 83/259
# 32609/32609 [==============================] - 1s 26us/sample - loss: 3.0089
# Epoch 84/259
# 32609/32609 [==============================] - 1s 26us/sample - loss: 3.0006
# Epoch 85/259
# 32609/32609 [==============================] - 1s 26us/sample - loss: 3.0102
# Epoch 86/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 2.9730
# Epoch 87/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 2.9777
# Epoch 88/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 2.9709
# Epoch 89/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 2.9736
# Epoch 90/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 2.9769
# Epoch 91/259
# 32609/32609 [==============================] - 1s 26us/sample - loss: 2.9738
# Epoch 92/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 2.9667
# Epoch 93/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 2.9585
# Epoch 94/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 2.9595
# Epoch 95/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 2.9440
# Epoch 96/259
# 32609/32609 [==============================] - 1s 26us/sample - loss: 2.9451
# Epoch 97/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 2.9545
# Epoch 98/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 2.9484
# Epoch 99/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 2.9187
# Epoch 100/259
# 32609/32609 [==============================] - 1s 26us/sample - loss: 2.9338
# Epoch 101/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 2.9210
# Epoch 102/259
# 32609/32609 [==============================] - 1s 26us/sample - loss: 2.9311
# Epoch 103/259
# 32609/32609 [==============================] - 1s 26us/sample - loss: 2.8885
# Epoch 104/259
# 32609/32609 [==============================] - 1s 26us/sample - loss: 2.9086
# Epoch 105/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 2.9018
# Epoch 106/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 2.9349
# Epoch 107/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 2.8900
# Epoch 108/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 2.8974
# Epoch 109/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 2.9040
# Epoch 110/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 2.8917
# Epoch 111/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 2.8851
# Epoch 112/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 2.8795
# Epoch 113/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 2.8889
# Epoch 114/259
# 32609/32609 [==============================] - 1s 26us/sample - loss: 2.8564
# Epoch 115/259
# 32609/32609 [==============================] - 1s 26us/sample - loss: 2.8538
# Epoch 116/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 2.8412
# Epoch 117/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 2.8459
# Epoch 118/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 2.8574
# Epoch 119/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 2.8502
# Epoch 120/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 2.8300
# Epoch 121/259
# 32609/32609 [==============================] - 1s 24us/sample - loss: 2.8409
# Epoch 122/259
# 32609/32609 [==============================] - 1s 25us/sample - loss: 2.8352
# Epoch 123/259
# 32609/32609 [==============================] - 1s 24us/sample - loss: 2.8184
# Epoch 124/259
# 32609/32609 [==============================] - 1s 23us/sample - loss: 2.8395
# Epoch 125/259
# 32609/32609 [==============================] - 1s 23us/sample - loss: 2.8099
# Epoch 126/259
# 32609/32609 [==============================] - 1s 22us/sample - loss: 2.8276
# Epoch 127/259
# 32609/32609 [==============================] - 1s 23us/sample - loss: 2.8164
# Epoch 128/259
# 32609/32609 [==============================] - 1s 23us/sample - loss: 2.8266
# Epoch 129/259
# 32609/32609 [==============================] - 1s 21us/sample - loss: 2.8058
# Epoch 130/259
# 32609/32609 [==============================] - 1s 23us/sample - loss: 2.8276
# Epoch 131/259
# 32609/32609 [==============================] - 1s 23us/sample - loss: 2.8168
# Epoch 132/259
# 32609/32609 [==============================] - 1s 22us/sample - loss: 2.7923
# Epoch 133/259
# 32609/32609 [==============================] - 1s 21us/sample - loss: 2.7851
# Epoch 134/259
# 32609/32609 [==============================] - 1s 21us/sample - loss: 2.7884
# Epoch 135/259
# 32609/32609 [==============================] - 1s 20us/sample - loss: 2.7839
# Epoch 136/259
# 32609/32609 [==============================] - 1s 20us/sample - loss: 2.7749
# Epoch 137/259
# 32609/32609 [==============================] - 1s 20us/sample - loss: 2.7810
# Epoch 138/259
# 32609/32609 [==============================] - 1s 20us/sample - loss: 2.7790
# Epoch 139/259
# 32609/32609 [==============================] - 1s 21us/sample - loss: 2.7837
# Epoch 140/259
# 32609/32609 [==============================] - 1s 20us/sample - loss: 2.7485
# Epoch 141/259
# 32609/32609 [==============================] - 1s 20us/sample - loss: 2.7503
# Epoch 142/259
# 32609/32609 [==============================] - 1s 20us/sample - loss: 2.7706
# Epoch 143/259
# 32609/32609 [==============================] - 1s 20us/sample - loss: 2.7574
# Epoch 144/259
# 32609/32609 [==============================] - 1s 21us/sample - loss: 2.7477
# Epoch 145/259
# 32609/32609 [==============================] - 1s 20us/sample - loss: 2.7444
# Epoch 146/259
# 32609/32609 [==============================] - 1s 21us/sample - loss: 2.7436
# Epoch 147/259
# 32609/32609 [==============================] - 1s 20us/sample - loss: 2.7402
# Epoch 148/259
# 32609/32609 [==============================] - 1s 20us/sample - loss: 2.7393
# Epoch 149/259
# 32609/32609 [==============================] - 1s 21us/sample - loss: 2.7225
# Epoch 150/259
# 32609/32609 [==============================] - 1s 21us/sample - loss: 2.7366
# Epoch 151/259
# 32609/32609 [==============================] - 1s 20us/sample - loss: 2.7426
# Epoch 152/259
# 32609/32609 [==============================] - 1s 20us/sample - loss: 2.7348
# Epoch 153/259
# 32609/32609 [==============================] - 1s 20us/sample - loss: 2.7461
# Epoch 154/259
# 32609/32609 [==============================] - 1s 21us/sample - loss: 2.7441
# Epoch 155/259
# 32609/32609 [==============================] - 1s 21us/sample - loss: 2.7518
# Epoch 156/259
# 32609/32609 [==============================] - 1s 21us/sample - loss: 2.7310
# Epoch 157/259
# 32609/32609 [==============================] - 1s 17us/sample - loss: 2.7112
# Epoch 158/259
# 32609/32609 [==============================] - 0s 15us/sample - loss: 2.7237
# Epoch 159/259
# 32609/32609 [==============================] - 0s 14us/sample - loss: 2.7395
# Epoch 160/259
# 32609/32609 [==============================] - 0s 15us/sample - loss: 2.7315
# Epoch 161/259
# 32609/32609 [==============================] - 0s 15us/sample - loss: 2.7720
# Epoch 162/259
# 32609/32609 [==============================] - 0s 15us/sample - loss: 2.7440
# Epoch 163/259
# 32609/32609 [==============================] - 0s 15us/sample - loss: 2.7501
# Epoch 164/259
# 32609/32609 [==============================] - 0s 15us/sample - loss: 2.7051
# Epoch 165/259
# 32609/32609 [==============================] - 0s 15us/sample - loss: 2.7570
# Epoch 166/259
# 32609/32609 [==============================] - 0s 15us/sample - loss: 2.7437
# Epoch 167/259
# 32609/32609 [==============================] - 0s 15us/sample - loss: 2.7528
# Epoch 168/259
# 32609/32609 [==============================] - 0s 14us/sample - loss: 2.7289
# Epoch 169/259
# 32609/32609 [==============================] - 0s 15us/sample - loss: 2.7577
# Epoch 170/259
# 32609/32609 [==============================] - 0s 15us/sample - loss: 2.7627
# Epoch 171/259
# 32609/32609 [==============================] - 0s 15us/sample - loss: 2.7468
# Epoch 172/259
# 32609/32609 [==============================] - 0s 15us/sample - loss: 2.7371
# Epoch 173/259
# 32609/32609 [==============================] - 0s 15us/sample - loss: 2.7688
# Epoch 174/259
# 32609/32609 [==============================] - 0s 15us/sample - loss: 2.7468
# Epoch 175/259
# 32609/32609 [==============================] - 0s 15us/sample - loss: 2.7444
# Epoch 176/259
# 32609/32609 [==============================] - 0s 14us/sample - loss: 2.7689
# Epoch 177/259
# 32609/32609 [==============================] - 0s 15us/sample - loss: 2.7353
# Epoch 178/259
# 32609/32609 [==============================] - 1s 18us/sample - loss: 2.7644
# Epoch 179/259
# 32609/32609 [==============================] - 1s 17us/sample - loss: 2.7487
# Epoch 180/259
# 32609/32609 [==============================] - 1s 17us/sample - loss: 2.7505
# Epoch 181/259
# 32609/32609 [==============================] - 1s 17us/sample - loss: 2.7917
# Epoch 182/259
# 32609/32609 [==============================] - 1s 18us/sample - loss: 2.7599
# Epoch 183/259
# 32609/32609 [==============================] - 1s 16us/sample - loss: 2.7744
# Epoch 184/259
# 32609/32609 [==============================] - 1s 17us/sample - loss: 2.7586
# Epoch 185/259
# 32609/32609 [==============================] - 1s 20us/sample - loss: 2.7755
# Epoch 186/259
# 32609/32609 [==============================] - 1s 20us/sample - loss: 2.7524
# Epoch 187/259
# 32609/32609 [==============================] - 1s 19us/sample - loss: 2.7907
# Epoch 188/259
# 32609/32609 [==============================] - 1s 20us/sample - loss: 2.7684
# Epoch 189/259
# 32609/32609 [==============================] - 1s 20us/sample - loss: 2.7619
# Epoch 190/259
# 32609/32609 [==============================] - 1s 20us/sample - loss: 2.7855
# Epoch 191/259
# 32609/32609 [==============================] - 1s 20us/sample - loss: 2.7869
# Epoch 192/259
# 32609/32609 [==============================] - 1s 20us/sample - loss: 2.7892
# Epoch 193/259
# 32609/32609 [==============================] - 1s 20us/sample - loss: 2.7980
# Epoch 194/259
# 32609/32609 [==============================] - 1s 20us/sample - loss: 2.7930
# Epoch 195/259
# 32609/32609 [==============================] - 1s 19us/sample - loss: 2.7705
# Epoch 196/259
# 32609/32609 [==============================] - 1s 20us/sample - loss: 2.7959
# Epoch 197/259
# 32609/32609 [==============================] - 1s 20us/sample - loss: 2.7956
# Epoch 198/259
# 32609/32609 [==============================] - 1s 21us/sample - loss: 2.8309
# Epoch 199/259
# 32609/32609 [==============================] - 1s 19us/sample - loss: 2.8089
# Epoch 200/259
# 32609/32609 [==============================] - 1s 20us/sample - loss: 2.8425
# Epoch 201/259
# 32609/32609 [==============================] - 1s 21us/sample - loss: 2.8187
# Epoch 202/259
# 32609/32609 [==============================] - 1s 19us/sample - loss: 2.8122
# Epoch 203/259
# 32609/32609 [==============================] - 1s 19us/sample - loss: 2.8168
# Epoch 204/259
# 32609/32609 [==============================] - 1s 18us/sample - loss: 2.8182
# Epoch 205/259
# 32609/32609 [==============================] - 1s 18us/sample - loss: 2.8296
# Epoch 206/259
# 32609/32609 [==============================] - 1s 22us/sample - loss: 2.8304
# Epoch 207/259
# 32609/32609 [==============================] - 1s 21us/sample - loss: 2.8497
# Epoch 208/259
# 32609/32609 [==============================] - 1s 21us/sample - loss: 2.8813
# Epoch 209/259
# 32609/32609 [==============================] - 1s 20us/sample - loss: 2.8583
# Epoch 210/259
# 32609/32609 [==============================] - 1s 22us/sample - loss: 2.8682
# Epoch 211/259
# 32609/32609 [==============================] - 1s 22us/sample - loss: 2.8663
# Epoch 212/259
# 32609/32609 [==============================] - 1s 22us/sample - loss: 2.9149
# Epoch 213/259
# 32609/32609 [==============================] - 1s 21us/sample - loss: 2.8651
# Epoch 214/259
# 32609/32609 [==============================] - 1s 22us/sample - loss: 2.9133
# Epoch 215/259
# 32609/32609 [==============================] - 1s 20us/sample - loss: 2.8682
# Epoch 216/259
# 32609/32609 [==============================] - 1s 20us/sample - loss: 2.8822
# Epoch 217/259
# 32609/32609 [==============================] - 1s 19us/sample - loss: 2.9134
# Epoch 218/259
# 32609/32609 [==============================] - 1s 21us/sample - loss: 2.9203
# Epoch 219/259
# 32609/32609 [==============================] - 1s 21us/sample - loss: 2.8653
# Epoch 220/259
# 32609/32609 [==============================] - 1s 21us/sample - loss: 2.8835
# Epoch 221/259
# 32609/32609 [==============================] - 1s 21us/sample - loss: 2.9577
# Epoch 222/259
# 32609/32609 [==============================] - 1s 21us/sample - loss: 2.8979
# Epoch 223/259
# 32609/32609 [==============================] - 1s 21us/sample - loss: 2.9096
# Epoch 224/259
# 32609/32609 [==============================] - 1s 20us/sample - loss: 2.9122
# Epoch 225/259
# 32609/32609 [==============================] - 1s 22us/sample - loss: 2.9003
# Epoch 226/259
# 32609/32609 [==============================] - 1s 21us/sample - loss: 2.9106
# Epoch 227/259
# 32609/32609 [==============================] - 1s 21us/sample - loss: 2.9389
# Epoch 228/259
# 32609/32609 [==============================] - 1s 21us/sample - loss: 2.8944
# Epoch 229/259
# 32609/32609 [==============================] - 1s 21us/sample - loss: 2.8850
# Epoch 230/259
# 32609/32609 [==============================] - 1s 21us/sample - loss: 2.9330
# Epoch 231/259
# 32609/32609 [==============================] - 1s 21us/sample - loss: 2.9615
# Epoch 232/259
# 32609/32609 [==============================] - 1s 21us/sample - loss: 2.9376
# Epoch 233/259
# 32609/32609 [==============================] - 1s 20us/sample - loss: 2.9180
# Epoch 234/259
# 32609/32609 [==============================] - 1s 20us/sample - loss: 2.9439
# Epoch 235/259
# 32609/32609 [==============================] - 1s 21us/sample - loss: 2.9517
# Epoch 236/259
# 32609/32609 [==============================] - 1s 20us/sample - loss: 2.9499
# Epoch 237/259
# 32609/32609 [==============================] - 1s 21us/sample - loss: 3.0070
# Epoch 238/259
# 32609/32609 [==============================] - 1s 22us/sample - loss: 2.9997
# Epoch 239/259
# 32609/32609 [==============================] - 1s 20us/sample - loss: 3.0331
# Epoch 240/259
# 32609/32609 [==============================] - 1s 21us/sample - loss: 2.9855
# Epoch 241/259
# 32609/32609 [==============================] - 1s 20us/sample - loss: 3.0639
# Epoch 242/259
# 32609/32609 [==============================] - 1s 21us/sample - loss: 3.0517
# Epoch 243/259
# 32609/32609 [==============================] - 1s 21us/sample - loss: 3.0344
# Epoch 244/259
# 32609/32609 [==============================] - 1s 20us/sample - loss: 3.0040
# Epoch 245/259
# 32609/32609 [==============================] - 1s 21us/sample - loss: 3.0132
# Epoch 246/259
# 32609/32609 [==============================] - 1s 20us/sample - loss: 3.0436
# Epoch 247/259
# 32609/32609 [==============================] - 1s 21us/sample - loss: 3.1017
# Epoch 248/259
# 32609/32609 [==============================] - 1s 20us/sample - loss: 3.0933
# Epoch 249/259
# 32609/32609 [==============================] - 1s 21us/sample - loss: 3.0644
# Epoch 250/259
# 32609/32609 [==============================] - 1s 21us/sample - loss: 3.0824
# Epoch 251/259
# 32609/32609 [==============================] - 1s 21us/sample - loss: 3.1053
# Epoch 252/259
# 32609/32609 [==============================] - 1s 21us/sample - loss: 3.1413
# Epoch 253/259
# 32609/32609 [==============================] - 1s 20us/sample - loss: 3.1221
# Epoch 254/259
# 32609/32609 [==============================] - 1s 20us/sample - loss: 3.1758
# Epoch 255/259
# 32609/32609 [==============================] - 1s 19us/sample - loss: 3.1389
# Epoch 256/259
# 32609/32609 [==============================] - 1s 19us/sample - loss: 3.1172
# Epoch 257/259
# 32609/32609 [==============================] - 1s 21us/sample - loss: 3.1641
# Epoch 258/259
# 32609/32609 [==============================] - 1s 22us/sample - loss: 3.1634
# Epoch 259/259
# 32609/32609 [==============================] - 1s 22us/sample - loss: 3.1296
# Training time: 189.42020344734192
# /home/andressa.amaral/.local/lib/python3.7/site-packages/keras/engine/training_v1.py:2356: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# Testing time: 16.643980503082275

# %% [markdown]
# # Metrics

# %%
# Examinig the latent space generated by the encoder
X_encoded = encoder.predict(X_test)

pca = PCA(n_components=2)
X_analysis = pca.fit_transform(X_encoded)
# Out:
# /home/andressa.amaral/.local/lib/python3.7/site-packages/keras/engine/training_v1.py:2356: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x = X_analysis[:, 0], y = X_analysis[:, 1], s = 20, hue = Y_pred)
plt.grid()
plt.savefig("Results/PCA/S2_" + str(number_features))
plt.show()

# Orange ones are anomalies

# %%
plt.figure(figsize = (8, 6))
sns.scatterplot(x = X_analysis[:, 0], y = X_analysis[:, 1], s = 20, hue = Y_test)
plt.grid()
plt.savefig("Results/PCA Groundtruth/S2_" + str(number_features))
plt.show()

# Ground truth

# %%
conf_matrix = confusion_matrix(Y_test, Y_pred)

fig, ax = plt.subplots(figsize = (4, 4))
ax.matshow(conf_matrix, cmap = plt.cm.Blues, alpha = 0.3)
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        ax.text(x = j, y = i,s = conf_matrix[i, j], va = 'center', ha = 'center', size = 'large')
 
plt.xlabel('Predictions', fontsize=12)
plt.ylabel('Actuals', fontsize=12)
plt.title('Confusion Matrix', fontsize=14)
plt.savefig("Results/Confusion Matrix/S2_" + str(number_features))
plt.show()
