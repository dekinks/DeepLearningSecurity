# %%
# !pip3 install pandas
# !pip3 install seaborn
# !pip3 install --upgrade tensorflow-gpu
# !pip3 install import-ipynb

from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import math
import pickle
import time
import sys

import import_ipynb
import VariationalAutoencoderModel

import tensorflow as tf
tf.compat.v1.disable_eager_execution()
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Lambda, Input, Dense
from tensorflow.keras.losses import mse
from tensorflow.keras import optimizers
from tensorflow.keras import backend as K

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.metrics import classification_report, mean_squared_error, confusion_matrix, accuracy_score, f1_score, precision_score, recall_score

# %matplotlib inline
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/andressa.amaral/.local/lib/python3.7/site-packages (1.3.5)
# Requirement already satisfied: pytz>=2017.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from pandas) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from pandas) (1.21.5)
# Requirement already satisfied: six>=1.5 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in /home/andressa.amaral/.local/lib/python3.7/site-packages (0.11.2)
# Requirement already satisfied: numpy>=1.15 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from seaborn) (1.21.5)
# Requirement already satisfied: scipy>=1.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from seaborn) (1.7.3)
# Requirement already satisfied: matplotlib>=2.2 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from seaborn) (3.5.1)
# Requirement already satisfied: pandas>=0.23 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from seaborn) (1.3.5)
# Requirement already satisfied: fonttools>=4.22.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (4.31.1)
# Requirement already satisfied: packaging>=20.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: cycler>=0.10 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (1.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (3.0.7)
# Requirement already satisfied: pillow>=6.2.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (9.0.1)
# Requirement already satisfied: pytz>=2017.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from pandas>=0.23->seaborn) (2022.1)
# Requirement already satisfied: typing-extensions in /home/andressa.amaral/.local/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib>=2.2->seaborn) (4.1.1)
# Requirement already satisfied: six>=1.5 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow-gpu in /home/andressa.amaral/.local/lib/python3.7/site-packages (2.8.0)
# Requirement already satisfied: absl-py>=0.4.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.0.0)
# Requirement already satisfied: gast>=0.2.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (0.5.3)
# Requirement already satisfied: libclang>=9.0.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (13.0.0)
# Requirement already satisfied: flatbuffers>=1.12 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (2.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (0.24.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (2.8.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.14.0)
# Requirement already satisfied: setuptools in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (60.10.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.1.2)
# Requirement already satisfied: h5py>=2.9.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (3.6.0)
# Requirement already satisfied: six>=1.12.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.16.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (0.2.0)
# Requirement already satisfied: numpy>=1.20 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.21.5)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (2.8.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.6.3)
# Requirement already satisfied: tf-estimator-nightly==2.8.0.dev2021122109 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (2.8.0.dev2021122109)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (4.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (3.3.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.44.0)
# Requirement already satisfied: protobuf>=3.9.2 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (3.19.4)
# Requirement already satisfied: termcolor>=1.1.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.1.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/lib/python3/dist-packages (from astunparse>=1.6.0->tensorflow-gpu) (0.30.0)
# Requirement already satisfied: cached-property in /home/andressa.amaral/.local/lib/python3.7/site-packages (from h5py>=2.9.0->tensorflow-gpu) (1.5.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu) (2.6.2)
# Requirement already satisfied: werkzeug>=0.11.15 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu) (2.0.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu) (0.4.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu) (2.27.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu) (3.3.6)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow-gpu) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow-gpu) (4.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow-gpu) (5.0.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow-gpu) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow-gpu) (4.11.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow-gpu) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow-gpu) (2018.1.18)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow-gpu) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow-gpu) (2.6)
# Requirement already satisfied: zipp>=0.5 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow-gpu) (3.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow-gpu) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow-gpu) (3.2.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: import-ipynb in /home/andressa.amaral/.local/lib/python3.7/site-packages (0.1.3)
# importing Jupyter notebook from VariationalAutoencoderModel.ipynb
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/andressa.amaral/.local/lib/python3.7/site-packages (1.3.5)
# Requirement already satisfied: numpy>=1.17.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from pandas) (1.21.5)
# Requirement already satisfied: pytz>=2017.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from pandas) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in /home/andressa.amaral/.local/lib/python3.7/site-packages (0.11.2)
# Requirement already satisfied: pandas>=0.23 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from seaborn) (1.3.5)
# Requirement already satisfied: scipy>=1.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from seaborn) (1.7.3)
# Requirement already satisfied: matplotlib>=2.2 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from seaborn) (3.5.1)
# Requirement already satisfied: numpy>=1.15 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from seaborn) (1.21.5)
# Requirement already satisfied: fonttools>=4.22.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (4.31.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (9.0.1)
# Requirement already satisfied: packaging>=20.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (1.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (3.0.7)
# Requirement already satisfied: cycler>=0.10 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: pytz>=2017.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from pandas>=0.23->seaborn) (2022.1)
# Requirement already satisfied: typing-extensions in /home/andressa.amaral/.local/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib>=2.2->seaborn) (4.1.1)
# Requirement already satisfied: six>=1.5 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow-gpu in /home/andressa.amaral/.local/lib/python3.7/site-packages (2.8.0)
# Requirement already satisfied: flatbuffers>=1.12 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (2.0)
# Requirement already satisfied: libclang>=9.0.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (13.0.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (0.2.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (2.8.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (3.3.0)
# Requirement already satisfied: setuptools in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (60.10.0)
# Requirement already satisfied: tf-estimator-nightly==2.8.0.dev2021122109 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (2.8.0.dev2021122109)
# Requirement already satisfied: absl-py>=0.4.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.0.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.44.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.6.3)
# Requirement already satisfied: h5py>=2.9.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (4.1.1)
# Requirement already satisfied: termcolor>=1.1.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.1.0)
# Requirement already satisfied: six>=1.12.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.16.0)
# Requirement already satisfied: gast>=0.2.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (0.5.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (0.24.0)
# Requirement already satisfied: protobuf>=3.9.2 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (3.19.4)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.1.2)
# Requirement already satisfied: wrapt>=1.11.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.14.0)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (2.8.0)
# Requirement already satisfied: numpy>=1.20 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorflow-gpu) (1.21.5)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/lib/python3/dist-packages (from astunparse>=1.6.0->tensorflow-gpu) (0.30.0)
# Requirement already satisfied: cached-property in /home/andressa.amaral/.local/lib/python3.7/site-packages (from h5py>=2.9.0->tensorflow-gpu) (1.5.2)
# Requirement already satisfied: werkzeug>=0.11.15 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu) (2.0.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu) (3.3.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu) (2.6.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu) (2.27.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu) (0.4.6)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow-gpu) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow-gpu) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow-gpu) (5.0.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow-gpu) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow-gpu) (4.11.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow-gpu) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow-gpu) (2.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow-gpu) (2018.1.18)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow-gpu) (1.22)
# Requirement already satisfied: zipp>=0.5 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow-gpu) (3.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow-gpu) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/andressa.amaral/.local/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow-gpu) (3.2.0)
# 2022-04-27 09:16:05.691862: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-04-27 09:16:05.691883: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
gpu_options = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction = 0.333)
sess = tf.compat.v1.Session(config = tf.compat.v1.ConfigProto(gpu_options = gpu_options))
# Out:
# 2022-04-27 09:16:07.010762: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-04-27 09:16:07.046384: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-04-27 09:16:07.046726: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory
# 2022-04-27 09:16:07.046850: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory
# 2022-04-27 09:16:07.049309: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory
# 2022-04-27 09:16:07.049413: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory
# 2022-04-27 09:16:07.049511: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2022-04-27 09:16:07.049521: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %% [markdown]
# # Simple Home 1003 Camera Data Pre-Processing

# %%
# Benign traffic

s3_benign = pd.read_csv('../nbaiot/SimpleHome_XCS7_1003_WHT_Security_Camera/benign_traffic.csv', encoding = "utf-8", sep = ',' ) 
df_s3_benign = s3_benign.copy(deep=True)

columns = list(df_s3_benign.columns)
chosen_columns = []
for column in columns:
    if column.find('L5') != -1:
        chosen_columns.append(column)
        
df_s3_benign = pd.DataFrame(df_s3_benign, columns = chosen_columns)

# Mirai

s3_mirai_ack = pd.read_csv('../nbaiot/SimpleHome_XCS7_1003_WHT_Security_Camera/mirai/ack.csv', encoding = "utf-8", sep = ',' ) 
df_s3_mirai_ack = s3_mirai_ack.copy(deep=True)
df_s3_mirai_ack = pd.DataFrame(df_s3_mirai_ack, columns = chosen_columns)

s3_mirai_scan = pd.read_csv('../nbaiot/SimpleHome_XCS7_1003_WHT_Security_Camera/mirai/scan.csv', encoding = "utf-8", sep = ',' ) 
df_s3_mirai_scan = s3_mirai_scan.copy(deep=True)
df_s3_mirai_scan = pd.DataFrame(df_s3_mirai_scan, columns = chosen_columns)

s3_mirai_syn = pd.read_csv('../nbaiot/SimpleHome_XCS7_1003_WHT_Security_Camera/mirai/syn.csv', encoding = "utf-8", sep = ',' ) 
df_s3_mirai_syn = s3_mirai_syn.copy(deep=True)
df_s3_mirai_syn = pd.DataFrame(df_s3_mirai_syn, columns = chosen_columns)

s3_mirai_udp = pd.read_csv('../nbaiot/SimpleHome_XCS7_1003_WHT_Security_Camera/mirai/udp.csv', encoding = "utf-8", sep = ',' ) 
df_s3_mirai_udp = s3_mirai_udp.copy(deep=True)
df_s3_mirai_udp = pd.DataFrame(df_s3_mirai_udp, columns = chosen_columns)

s3_mirai_udpplain = pd.read_csv('../nbaiot/SimpleHome_XCS7_1003_WHT_Security_Camera/mirai/udpplain.csv', encoding = "utf-8", sep = ',' ) 
df_s3_mirai_udpplain = s3_mirai_udpplain.copy(deep=True)
df_s3_mirai_udpplain = pd.DataFrame(df_s3_mirai_udpplain, columns = chosen_columns)

# Bashlite

s3_bashlite_combo = pd.read_csv('../nbaiot/SimpleHome_XCS7_1003_WHT_Security_Camera/gafgyt/combo.csv', encoding = "utf-8", sep = ',' ) 
df_s3_bashlite_combo = s3_bashlite_combo.copy(deep=True)
df_s3_bashlite_combo = pd.DataFrame(df_s3_bashlite_combo, columns = chosen_columns)

s3_bashlite_junk = pd.read_csv('../nbaiot/SimpleHome_XCS7_1003_WHT_Security_Camera/gafgyt/junk.csv', encoding = "utf-8", sep = ',' ) 
df_s3_bashlite_junk = s3_bashlite_junk.copy(deep=True)
df_s3_bashlite_junk = pd.DataFrame(df_s3_bashlite_junk, columns = chosen_columns)

s3_bashlite_scan = pd.read_csv('../nbaiot/SimpleHome_XCS7_1003_WHT_Security_Camera/gafgyt/scan.csv', encoding = "utf-8", sep = ',' ) 
df_s3_bashlite_scan = s3_bashlite_scan.copy(deep=True)
df_s3_bashlite_scan = pd.DataFrame(df_s3_bashlite_scan, columns = chosen_columns)

s3_bashlite_udp = pd.read_csv('../nbaiot/SimpleHome_XCS7_1003_WHT_Security_Camera/gafgyt/udp.csv', encoding = "utf-8", sep = ',' ) 
df_s3_bashlite_udp = s3_bashlite_udp.copy(deep=True)
df_s3_bashlite_udp = pd.DataFrame(df_s3_bashlite_udp, columns = chosen_columns)

s3_bashlite_tcp = pd.read_csv('../nbaiot/SimpleHome_XCS7_1003_WHT_Security_Camera/gafgyt/tcp.csv', encoding = "utf-8", sep = ',' ) 
df_s3_bashlite_tcp = s3_bashlite_tcp.copy(deep=True)
df_s3_bashlite_tcp = pd.DataFrame(df_s3_bashlite_tcp, columns = chosen_columns)

# %%
scaler = MinMaxScaler()
df_s3_benign_norm = scaler.fit_transform(df_s3_benign)

df_s3_miraiack_norm = scaler.fit_transform(df_s3_mirai_ack)
df_s3_miraiscan_norm = scaler.fit_transform(df_s3_mirai_scan)
df_s3_miraisyn_norm = scaler.fit_transform(df_s3_mirai_syn)
df_s3_miraiudp_norm = scaler.fit_transform(df_s3_mirai_udp)
df_s3_miraiudpplain_norm = scaler.fit_transform(df_s3_mirai_udpplain)

df_s3_bashlitecombo_norm = scaler.fit_transform(df_s3_bashlite_combo)
df_s3_bashlitejunk_norm = scaler.fit_transform(df_s3_bashlite_junk)
df_s3_bashlitescan_norm = scaler.fit_transform(df_s3_bashlite_scan)
df_s3_bashliteudp_norm = scaler.fit_transform(df_s3_bashlite_udp)
df_s3_bashlitetcp_norm = scaler.fit_transform(df_s3_bashlite_tcp)

# %% [markdown]
# # Variational Autoencoder - Attack Detection

# %% [markdown]
# ## Model

# %%
# Train set

len_benign = len(df_s3_benign_norm)
len_benign_train = int(0.7 * len_benign)
X_train_VAE = df_s3_benign_norm[:len_benign_train]

# Test set - 30% benign and the rest is attack

X_test_benign = df_s3_benign_norm[len_benign_train:]

len_attack_test = len(X_test_benign)
X_test_mirai_ack = df_s3_miraiack_norm
X_test_mirai_scan = df_s3_miraiscan_norm
X_test_mirai_syn = df_s3_miraisyn_norm
X_test_mirai_udp = df_s3_miraiudp_norm
X_test_mirai_udpplain = df_s3_miraiudpplain_norm
X_test_bashlite_combo = df_s3_bashlitecombo_norm
X_test_bashlite_junk = df_s3_bashlitejunk_norm
X_test_bashlite_scan = df_s3_bashlitescan_norm
X_test_bashlite_tcp = df_s3_bashlitetcp_norm
X_test_bashlite_udp = df_s3_bashliteudp_norm

X_test_VAE = np.concatenate([X_test_benign, X_test_mirai_ack, X_test_mirai_scan, X_test_mirai_syn, X_test_mirai_udp,
                             X_test_mirai_udpplain, X_test_bashlite_combo, X_test_bashlite_junk, X_test_bashlite_scan,
                             X_test_bashlite_tcp, X_test_bashlite_udp])

Y_test_VAE = np.ones(len(X_test_VAE))
Y_test_VAE[:len(X_test_benign)] = 0

# %%
# KL Loss function

def vae_loss(x, x_decoded_mean):
    # Compute the average MSE error, then scale it up (sum on all axes)
    
    reconstruction_loss = K.sum(K.square(x - x_decoded_mean))
    
    # Compute the KL loss
    
    kl_loss = - 0.5 * K.sum(1 + z_var - K.square(z_mean) - K.square(K.exp(z_var)), axis=-1)
    
    # Return the average loss over all 
    
    total_loss = K.mean(reconstruction_loss + kl_loss) # Total_loss = reconstruction_loss + kl_loss 
    return total_loss

# (1) Reconstruction Loss - Forces the encoder to generate latent features that minimize the reconstruction error, or else is
# penalized
# (2) KL Loss - Forces the distribution generated by the encoder to be similar to the prior probability of the input vector, 
# pushing latent feature space to normality

# %%
# Parameters

original_dim = X_train_VAE.shape[1]
input_shape = (original_dim,)
intermediate_dim = int(original_dim / 2)
latent_dim = int(original_dim / 3)

epochs = 500
learning_rate = 0.00008
batch_size = 25
anomaly_threshold = 0.01
number_features = 23

# %%
# Encoder

inputs, encoder, z_var, z_mean = VariationalAutoencoderModel.vae_encoder(
    input_shape, 
    intermediate_dim, 
    latent_dim, 
    VariationalAutoencoderModel.sample)

encoder.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  encoder_input (InputLayer)     [(None, 23)]         0           []
#
#  dense (Dense)                  (None, 11)           264         ['encoder_input[0][0]']
#
#  z_mean (Dense)                 (None, 7)            84          ['dense[0][0]']
#
#  z_var (Dense)                  (None, 7)            84          ['dense[0][0]']
#
#  z (Lambda)                     (None, 7)            0           ['z_mean[0][0]',
#                                                                   'z_var[0][0]']
#
# ==================================================================================================
# Total params: 432
# Trainable params: 432
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Decoder

decoder = VariationalAutoencoderModel.vae_decoder(
    intermediate_dim,
    latent_dim,
    original_dim)

decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  z_sampling (InputLayer)     [(None, 7)]               0
#
#  dense_1 (Dense)             (None, 11)                88
#
#  dense_2 (Dense)             (None, 23)                276
#
# =================================================================
# Total params: 364
# Trainable params: 364
# Non-trainable params: 0
# _________________________________________________________________

# %%
# VAE model

outputs = decoder(encoder(inputs))

opt = optimizers.Adam(learning_rate = learning_rate, clipvalue = 0.5)

vae_model = Model(inputs, outputs, name = 'vae_mlp')
vae_model.compile(optimizer = opt, loss = vae_loss)
vae_model.summary()
# Out:
# Model: "vae_mlp"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder_input (InputLayer)  [(None, 23)]              0
#
#  encoder (Functional)        (None, 7)                 432
#
#  decoder (Functional)        (None, 23)                364
#
# =================================================================
# Total params: 796
# Trainable params: 796
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train

# %%
train_start = time.time()

results = vae_model.fit(X_train_VAE, X_train_VAE,
                        shuffle = True,
                        epochs = epochs,
                        batch_size = batch_size)

train_end = time.time()
train_time = train_end - train_start
print("Training time:", train_time)
# Out:
# Train on 13669 samples
# Epoch 1/500
# 2022-04-27 09:16:19.828488: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 13669/13669 [==============================] - 1s 63us/sample - loss: 85.9276
# Epoch 2/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 61.4281
# Epoch 3/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 39.0159
# Epoch 4/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 22.5975
# Epoch 5/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 14.4922
# Epoch 6/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 11.3620
# Epoch 7/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 9.9206
# Epoch 8/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 9.0963
# Epoch 9/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 8.4451
# Epoch 10/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 7.8932
# Epoch 11/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 7.3540
# Epoch 12/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 6.8270
# Epoch 13/500
# 13669/13669 [==============================] - 1s 43us/sample - loss: 6.3035
# Epoch 14/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 5.7312
# Epoch 15/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 5.2173
# Epoch 16/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 4.8248
# Epoch 17/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 4.5423
# Epoch 18/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 4.2451
# Epoch 19/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 4.0466
# Epoch 20/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 3.8525
# Epoch 21/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 3.6828
# Epoch 22/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 3.5993
# Epoch 23/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 3.4504
# Epoch 24/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 3.4043
# Epoch 25/500
# 13669/13669 [==============================] - 1s 43us/sample - loss: 3.3095
# Epoch 26/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 3.1840
# Epoch 27/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 3.1753
# Epoch 28/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 3.0424
# Epoch 29/500
# 13669/13669 [==============================] - 1s 39us/sample - loss: 3.0237
# Epoch 30/500
# 13669/13669 [==============================] - 1s 38us/sample - loss: 2.9758
# Epoch 31/500
# 13669/13669 [==============================] - 1s 39us/sample - loss: 2.9123
# Epoch 32/500
# 13669/13669 [==============================] - 1s 39us/sample - loss: 2.8735
# Epoch 33/500
# 13669/13669 [==============================] - 1s 39us/sample - loss: 2.8136
# Epoch 34/500
# 13669/13669 [==============================] - 1s 38us/sample - loss: 2.7857
# Epoch 35/500
# 13669/13669 [==============================] - 1s 38us/sample - loss: 2.7983
# Epoch 36/500
# 13669/13669 [==============================] - 1s 39us/sample - loss: 2.7063
# Epoch 37/500
# 13669/13669 [==============================] - 1s 38us/sample - loss: 2.6690
# Epoch 38/500
# 13669/13669 [==============================] - 1s 38us/sample - loss: 2.6498
# Epoch 39/500
# 13669/13669 [==============================] - 1s 38us/sample - loss: 2.5771
# Epoch 40/500
# 13669/13669 [==============================] - 1s 38us/sample - loss: 2.5604
# Epoch 41/500
# 13669/13669 [==============================] - 1s 38us/sample - loss: 2.5397
# Epoch 42/500
# 13669/13669 [==============================] - 1s 38us/sample - loss: 2.5027
# Epoch 43/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 2.4740
# Epoch 44/500
# 13669/13669 [==============================] - 1s 38us/sample - loss: 2.4439
# Epoch 45/500
# 13669/13669 [==============================] - 1s 38us/sample - loss: 2.4203
# Epoch 46/500
# 13669/13669 [==============================] - 1s 38us/sample - loss: 2.4357
# Epoch 47/500
# 13669/13669 [==============================] - 1s 38us/sample - loss: 2.3457
# Epoch 48/500
# 13669/13669 [==============================] - 1s 38us/sample - loss: 2.3443
# Epoch 49/500
# 13669/13669 [==============================] - 1s 38us/sample - loss: 2.3081
# Epoch 50/500
# 13669/13669 [==============================] - 1s 38us/sample - loss: 2.2759
# Epoch 51/500
# 13669/13669 [==============================] - 1s 39us/sample - loss: 2.2724
# Epoch 52/500
# 13669/13669 [==============================] - 1s 38us/sample - loss: 2.2683
# Epoch 53/500
# 13669/13669 [==============================] - 1s 39us/sample - loss: 2.2215
# Epoch 54/500
# 13669/13669 [==============================] - 1s 38us/sample - loss: 2.2010
# Epoch 55/500
# 13669/13669 [==============================] - 1s 39us/sample - loss: 2.1754
# Epoch 56/500
# 13669/13669 [==============================] - 1s 38us/sample - loss: 2.1777
# Epoch 57/500
# 13669/13669 [==============================] - 1s 39us/sample - loss: 2.1816
# Epoch 58/500
# 13669/13669 [==============================] - 1s 38us/sample - loss: 2.1410
# Epoch 59/500
# 13669/13669 [==============================] - 1s 39us/sample - loss: 2.1204
# Epoch 60/500
# 13669/13669 [==============================] - 1s 38us/sample - loss: 2.1075
# Epoch 61/500
# 13669/13669 [==============================] - 1s 39us/sample - loss: 2.0972
# Epoch 62/500
# 13669/13669 [==============================] - 1s 39us/sample - loss: 2.0785
# Epoch 63/500
# 13669/13669 [==============================] - 1s 39us/sample - loss: 2.0819
# Epoch 64/500
# 13669/13669 [==============================] - 1s 39us/sample - loss: 2.0477
# Epoch 65/500
# 13669/13669 [==============================] - 1s 39us/sample - loss: 2.0211
# Epoch 66/500
# 13669/13669 [==============================] - 1s 38us/sample - loss: 2.0345
# Epoch 67/500
# 13669/13669 [==============================] - 1s 38us/sample - loss: 2.0159
# Epoch 68/500
# 13669/13669 [==============================] - 1s 38us/sample - loss: 2.0194
# Epoch 69/500
# 13669/13669 [==============================] - 1s 39us/sample - loss: 2.0014
# Epoch 70/500
# 13669/13669 [==============================] - 1s 39us/sample - loss: 1.9886
# Epoch 71/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.9867
# Epoch 72/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.9743
# Epoch 73/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.9507
# Epoch 74/500
# 13669/13669 [==============================] - 1s 39us/sample - loss: 1.9535
# Epoch 75/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.9597
# Epoch 76/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.9099
# Epoch 77/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.9263
# Epoch 78/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.9061
# Epoch 79/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.8651
# Epoch 80/500
# 13669/13669 [==============================] - 1s 39us/sample - loss: 1.8919
# Epoch 81/500
# 13669/13669 [==============================] - 1s 39us/sample - loss: 1.8903
# Epoch 82/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.8730
# Epoch 83/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.8742
# Epoch 84/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.8677
# Epoch 85/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.8610
# Epoch 86/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.8190
# Epoch 87/500
# 13669/13669 [==============================] - 1s 39us/sample - loss: 1.8283
# Epoch 88/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.8366
# Epoch 89/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.8796
# Epoch 90/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.8181
# Epoch 91/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.8351
# Epoch 92/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.8321
# Epoch 93/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.8421
# Epoch 94/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.8099
# Epoch 95/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.7913
# Epoch 96/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.7927
# Epoch 97/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.8095
# Epoch 98/500
# 13669/13669 [==============================] - 1s 39us/sample - loss: 1.7603
# Epoch 99/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.7869
# Epoch 100/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.7645
# Epoch 101/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.7751
# Epoch 102/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.7451
# Epoch 103/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.7843
# Epoch 104/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.7435
# Epoch 105/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.7381
# Epoch 106/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.7717
# Epoch 107/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.7231
# Epoch 108/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.7291
# Epoch 109/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.7227
# Epoch 110/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.7205
# Epoch 111/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.7040
# Epoch 112/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.7359
# Epoch 113/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.7211
# Epoch 114/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.7142
# Epoch 115/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.7372
# Epoch 116/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.7085
# Epoch 117/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6942
# Epoch 118/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.7137
# Epoch 119/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6949
# Epoch 120/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.7149
# Epoch 121/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.7006
# Epoch 122/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6862
# Epoch 123/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.7250
# Epoch 124/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.7028
# Epoch 125/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.7006
# Epoch 126/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6773
# Epoch 127/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6990
# Epoch 128/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6941
# Epoch 129/500
# 13669/13669 [==============================] - 1s 43us/sample - loss: 1.6708
# Epoch 130/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6692
# Epoch 131/500
# 13669/13669 [==============================] - 1s 44us/sample - loss: 1.6863
# Epoch 132/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6596
# Epoch 133/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6954
# Epoch 134/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6700
# Epoch 135/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6338
# Epoch 136/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6617
# Epoch 137/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6711
# Epoch 138/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6785
# Epoch 139/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6667
# Epoch 140/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6475
# Epoch 141/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6447
# Epoch 142/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6559
# Epoch 143/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6498
# Epoch 144/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6444
# Epoch 145/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6354
# Epoch 146/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6158
# Epoch 147/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6460
# Epoch 148/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6452
# Epoch 149/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6252
# Epoch 150/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6549
# Epoch 151/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6479
# Epoch 152/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6544
# Epoch 153/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6236
# Epoch 154/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6138
# Epoch 155/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6012
# Epoch 156/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6188
# Epoch 157/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6309
# Epoch 158/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6114
# Epoch 159/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6224
# Epoch 160/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6453
# Epoch 161/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6284
# Epoch 162/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6152
# Epoch 163/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6394
# Epoch 164/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6282
# Epoch 165/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6334
# Epoch 166/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6315
# Epoch 167/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6090
# Epoch 168/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6506
# Epoch 169/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6093
# Epoch 170/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6107
# Epoch 171/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6186
# Epoch 172/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6128
# Epoch 173/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6237
# Epoch 174/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6119
# Epoch 175/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6396
# Epoch 176/500
# 13669/13669 [==============================] - 1s 43us/sample - loss: 1.6199
# Epoch 177/500
# 13669/13669 [==============================] - 1s 43us/sample - loss: 1.6037
# Epoch 178/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6160
# Epoch 179/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.5923
# Epoch 180/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6333
# Epoch 181/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6201
# Epoch 182/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6309
# Epoch 183/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.5908
# Epoch 184/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6225
# Epoch 185/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6356
# Epoch 186/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6222
# Epoch 187/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6240
# Epoch 188/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6254
# Epoch 189/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6126
# Epoch 190/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.5774
# Epoch 191/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6457
# Epoch 192/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6091
# Epoch 193/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6255
# Epoch 194/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.5805
# Epoch 195/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.5982
# Epoch 196/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6237
# Epoch 197/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.5973
# Epoch 198/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6280
# Epoch 199/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.5912
# Epoch 200/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6205
# Epoch 201/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6000
# Epoch 202/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6273
# Epoch 203/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.5600
# Epoch 204/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6120
# Epoch 205/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6197
# Epoch 206/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.5981
# Epoch 207/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6040
# Epoch 208/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6076
# Epoch 209/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6219
# Epoch 210/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.5979
# Epoch 211/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6101
# Epoch 212/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6273
# Epoch 213/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6083
# Epoch 214/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6204
# Epoch 215/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6133
# Epoch 216/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6031
# Epoch 217/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.5947
# Epoch 218/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.5652
# Epoch 219/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6033
# Epoch 220/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.5645
# Epoch 221/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6002
# Epoch 222/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6132
# Epoch 223/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.5988
# Epoch 224/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.5963
# Epoch 225/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6365
# Epoch 226/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6200
# Epoch 227/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6234
# Epoch 228/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6232
# Epoch 229/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6241
# Epoch 230/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.5835
# Epoch 231/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.5984
# Epoch 232/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.5835
# Epoch 233/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.5977
# Epoch 234/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6177
# Epoch 235/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6311
# Epoch 236/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6131
# Epoch 237/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.5930
# Epoch 238/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6194
# Epoch 239/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.5875
# Epoch 240/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6078
# Epoch 241/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6056
# Epoch 242/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.5944
# Epoch 243/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.5692
# Epoch 244/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6189
# Epoch 245/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.5911
# Epoch 246/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6297
# Epoch 247/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6235
# Epoch 248/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.5898
# Epoch 249/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.5794
# Epoch 250/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6136
# Epoch 251/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.5764
# Epoch 252/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.5837
# Epoch 253/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.5958
# Epoch 254/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.5940
# Epoch 255/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6336
# Epoch 256/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.5740
# Epoch 257/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6078
# Epoch 258/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.5748
# Epoch 259/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.5792
# Epoch 260/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6281
# Epoch 261/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6196
# Epoch 262/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6434
# Epoch 263/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.5939
# Epoch 264/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6012
# Epoch 265/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.5930
# Epoch 266/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6162
# Epoch 267/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.5986
# Epoch 268/500
# 13669/13669 [==============================] - 1s 43us/sample - loss: 1.5925
# Epoch 269/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6258
# Epoch 270/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.5992
# Epoch 271/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6356
# Epoch 272/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6041
# Epoch 273/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6187
# Epoch 274/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.5686
# Epoch 275/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6125
# Epoch 276/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.5848
# Epoch 277/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6463
# Epoch 278/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6206
# Epoch 279/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6089
# Epoch 280/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6347
# Epoch 281/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.5851
# Epoch 282/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6223
# Epoch 283/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6103
# Epoch 284/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6372
# Epoch 285/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6172
# Epoch 286/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6305
# Epoch 287/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6245
# Epoch 288/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6254
# Epoch 289/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6148
# Epoch 290/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.5924
# Epoch 291/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6347
# Epoch 292/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6216
# Epoch 293/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6268
# Epoch 294/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6304
# Epoch 295/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6388
# Epoch 296/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.5818
# Epoch 297/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6013
# Epoch 298/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6006
# Epoch 299/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6305
# Epoch 300/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6297
# Epoch 301/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6399
# Epoch 302/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6407
# Epoch 303/500
# 13669/13669 [==============================] - 1s 43us/sample - loss: 1.6320
# Epoch 304/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6530
# Epoch 305/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6148
# Epoch 306/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.5765
# Epoch 307/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6222
# Epoch 308/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6259
# Epoch 309/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.5994
# Epoch 310/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6638
# Epoch 311/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6316
# Epoch 312/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6259
# Epoch 313/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6184
# Epoch 314/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6548
# Epoch 315/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6016
# Epoch 316/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6235
# Epoch 317/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6257
# Epoch 318/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6294
# Epoch 319/500
# 13669/13669 [==============================] - 1s 43us/sample - loss: 1.6447
# Epoch 320/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6302
# Epoch 321/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6392
# Epoch 322/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6359
# Epoch 323/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6297
# Epoch 324/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6337
# Epoch 325/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6332
# Epoch 326/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6454
# Epoch 327/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6422
# Epoch 328/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6440
# Epoch 329/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6315
# Epoch 330/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6063
# Epoch 331/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6494
# Epoch 332/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6177
# Epoch 333/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6758
# Epoch 334/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6419
# Epoch 335/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6315
# Epoch 336/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6091
# Epoch 337/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6425
# Epoch 338/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6819
# Epoch 339/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6470
# Epoch 340/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6736
# Epoch 341/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6206
# Epoch 342/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6256
# Epoch 343/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6084
# Epoch 344/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6603
# Epoch 345/500
# 13669/13669 [==============================] - 1s 43us/sample - loss: 1.6222
# Epoch 346/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6406
# Epoch 347/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6609
# Epoch 348/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6251
# Epoch 349/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6466
# Epoch 350/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6571
# Epoch 351/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6241
# Epoch 352/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6252
# Epoch 353/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6214
# Epoch 354/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6187
# Epoch 355/500
# 13669/13669 [==============================] - 1s 43us/sample - loss: 1.6274
# Epoch 356/500
# 13669/13669 [==============================] - 1s 44us/sample - loss: 1.6413
# Epoch 357/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6562
# Epoch 358/500
# 13669/13669 [==============================] - 1s 43us/sample - loss: 1.6267
# Epoch 359/500
# 13669/13669 [==============================] - 1s 44us/sample - loss: 1.6197
# Epoch 360/500
# 13669/13669 [==============================] - 1s 44us/sample - loss: 1.6317
# Epoch 361/500
# 13669/13669 [==============================] - 1s 45us/sample - loss: 1.6559
# Epoch 362/500
# 13669/13669 [==============================] - 1s 45us/sample - loss: 1.6304
# Epoch 363/500
# 13669/13669 [==============================] - 1s 45us/sample - loss: 1.6663
# Epoch 364/500
# 13669/13669 [==============================] - 1s 45us/sample - loss: 1.6312
# Epoch 365/500
# 13669/13669 [==============================] - 1s 44us/sample - loss: 1.6457
# Epoch 366/500
# 13669/13669 [==============================] - 1s 45us/sample - loss: 1.6535
# Epoch 367/500
# 13669/13669 [==============================] - 1s 45us/sample - loss: 1.6339
# Epoch 368/500
# 13669/13669 [==============================] - 1s 44us/sample - loss: 1.6464
# Epoch 369/500
# 13669/13669 [==============================] - 1s 44us/sample - loss: 1.6086
# Epoch 370/500
# 13669/13669 [==============================] - 1s 44us/sample - loss: 1.6313
# Epoch 371/500
# 13669/13669 [==============================] - 1s 44us/sample - loss: 1.6644
# Epoch 372/500
# 13669/13669 [==============================] - 1s 45us/sample - loss: 1.6492
# Epoch 373/500
# 13669/13669 [==============================] - 1s 45us/sample - loss: 1.6195
# Epoch 374/500
# 13669/13669 [==============================] - 1s 44us/sample - loss: 1.6278
# Epoch 375/500
# 13669/13669 [==============================] - 1s 44us/sample - loss: 1.6428
# Epoch 376/500
# 13669/13669 [==============================] - 1s 45us/sample - loss: 1.6340
# Epoch 377/500
# 13669/13669 [==============================] - 1s 44us/sample - loss: 1.6121
# Epoch 378/500
# 13669/13669 [==============================] - 1s 44us/sample - loss: 1.6988
# Epoch 379/500
# 13669/13669 [==============================] - 1s 43us/sample - loss: 1.6778
# Epoch 380/500
# 13669/13669 [==============================] - 1s 44us/sample - loss: 1.6608
# Epoch 381/500
# 13669/13669 [==============================] - 1s 44us/sample - loss: 1.6344
# Epoch 382/500
# 13669/13669 [==============================] - 1s 47us/sample - loss: 1.6521
# Epoch 383/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6443
# Epoch 384/500
# 13669/13669 [==============================] - 1s 43us/sample - loss: 1.6474
# Epoch 385/500
# 13669/13669 [==============================] - 1s 43us/sample - loss: 1.6262
# Epoch 386/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6613
# Epoch 387/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6460
# Epoch 388/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6229
# Epoch 389/500
# 13669/13669 [==============================] - 1s 43us/sample - loss: 1.6316
# Epoch 390/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6366
# Epoch 391/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6619
# Epoch 392/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6503
# Epoch 393/500
# 13669/13669 [==============================] - 1s 42us/sample - loss: 1.6306
# Epoch 394/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.5928
# Epoch 395/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6256
# Epoch 396/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6390
# Epoch 397/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6209
# Epoch 398/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6367
# Epoch 399/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6171
# Epoch 400/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6692
# Epoch 401/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6271
# Epoch 402/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.5968
# Epoch 403/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6267
# Epoch 404/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6493
# Epoch 405/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6065
# Epoch 406/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6556
# Epoch 407/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6528
# Epoch 408/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6287
# Epoch 409/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6403
# Epoch 410/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6462
# Epoch 411/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6262
# Epoch 412/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6356
# Epoch 413/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6634
# Epoch 414/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6339
# Epoch 415/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6403
# Epoch 416/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6509
# Epoch 417/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6007
# Epoch 418/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6016
# Epoch 419/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6527
# Epoch 420/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6262
# Epoch 421/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6453
# Epoch 422/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6455
# Epoch 423/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6112
# Epoch 424/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.5915
# Epoch 425/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6344
# Epoch 426/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6114
# Epoch 427/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6337
# Epoch 428/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6670
# Epoch 429/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6138
# Epoch 430/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6204
# Epoch 431/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6525
# Epoch 432/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6534
# Epoch 433/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6261
# Epoch 434/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6179
# Epoch 435/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6130
# Epoch 436/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6310
# Epoch 437/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6127
# Epoch 438/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6217
# Epoch 439/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6261
# Epoch 440/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6352
# Epoch 441/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6594
# Epoch 442/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6272
# Epoch 443/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6580
# Epoch 444/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6499
# Epoch 445/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6433
# Epoch 446/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6258
# Epoch 447/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6363
# Epoch 448/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6348
# Epoch 449/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6652
# Epoch 450/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6432
# Epoch 451/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6612
# Epoch 452/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6212
# Epoch 453/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6441
# Epoch 454/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6243
# Epoch 455/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6486
# Epoch 456/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6208
# Epoch 457/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6320
# Epoch 458/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6545
# Epoch 459/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6421
# Epoch 460/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6467
# Epoch 461/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6291
# Epoch 462/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6405
# Epoch 463/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6728
# Epoch 464/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6482
# Epoch 465/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6517
# Epoch 466/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6192
# Epoch 467/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6432
# Epoch 468/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6973
# Epoch 469/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6651
# Epoch 470/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6439
# Epoch 471/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6349
# Epoch 472/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6650
# Epoch 473/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6288
# Epoch 474/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6220
# Epoch 475/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6607
# Epoch 476/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6057
# Epoch 477/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6555
# Epoch 478/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6420
# Epoch 479/500
# 13669/13669 [==============================] - 1s 41us/sample - loss: 1.6224
# Epoch 480/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6791
# Epoch 481/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6544
# Epoch 482/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6324
# Epoch 483/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6584
# Epoch 484/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6521
# Epoch 485/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6332
# Epoch 486/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6665
# Epoch 487/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6420
# Epoch 488/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6419
# Epoch 489/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.7061
# Epoch 490/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6412
# Epoch 491/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6987
# Epoch 492/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6642
# Epoch 493/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6742
# Epoch 494/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6234
# Epoch 495/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6589
# Epoch 496/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6590
# Epoch 497/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6634
# Epoch 498/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6409
# Epoch 499/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6666
# Epoch 500/500
# 13669/13669 [==============================] - 1s 40us/sample - loss: 1.6337
# Training time: 281.6807670593262

# %%
plt.plot(results.history['loss'])
plt.title('Loss Pattern')
plt.ylabel('Loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Test'], loc='upper right');
plt.show()

# %% [markdown]
# ## Test

# %%
X_train_pred = vae_model.predict(X_train_VAE)
error_vector = VariationalAutoencoderModel.get_error_term(X_train_pred, X_train_VAE, _rmse=False)
error_thresh = anomaly_threshold

# Measure the error between the train set and its output and generates an error vector representing the error of each term
# Find an extreme value on the vector to use as the error threshold
# Out:
# /home/andressa.amaral/.local/lib/python3.7/site-packages/keras/engine/training_v1.py:2079: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,

# %%
test_start = time.time()

X_pred_VAE = vae_model.predict(X_test_VAE)

test_end = time.time()
test_time = test_end - test_start
print("Testing time:", test_time)

# If the error of the vector is higher than the defined threshold it detects an attack

error_vector = VariationalAutoencoderModel.get_error_term(X_pred_VAE, X_test_VAE, _rmse=False)
attacks = (error_vector > error_thresh)
print(attacks)

np.count_nonzero(attacks) / len(attacks) # Percentage of attacks
# Out:
# Testing time: 11.831828832626343
# [False False False ...  True  True  True]
# 0.993842254200825

# %%
print(len(X_test_VAE))
# Out:
# 837157

# %% [markdown]
# ## Metrics

# %%
sys.stdout = open("../Results/S1003_camera.txt", "a")

print(" ==== Test " + str(number_features) + " Normal learning rate ====")
print("Training time:" + str(train_time))
print("Testing time:" + str(test_time))
print(classification_report(Y_test_VAE, attacks, digits = 5))

# %%
'''# Examinig the latent space generated by the encoder

X_encoded = encoder.predict(X_test_VAE)

pca = PCA(n_components=2)
X_analysis = pca.fit_transform(X_encoded)'''
# Out:
# '# Examinig the latent space generated by the encoder\n\nX_encoded = encoder.predict(X_test_VAE)\n\npca = PCA(n_components=2)\nX_analysis = pca.fit_transform(X_encoded)'

# %%
'''plt.figure(figsize = (12, 10))
sns.scatterplot(x = X_analysis[:, 0], y = X_analysis[:, 1], s = 20, hue = error_vector)
plt.grid()
plt.show()

# Darker clusters indicate that the error is higher'''
# Out:
# 'plt.figure(figsize = (12, 10))\nsns.scatterplot(x = X_analysis[:, 0], y = X_analysis[:, 1], s = 20, hue = error_vector)\nplt.grid()\nplt.show()\n\n# Darker clusters indicate that the error is higher'

# %%
'''plt.figure(figsize=(12, 10))
sns.scatterplot(x = X_analysis[:, 0], y = X_analysis[:, 1], s = 20, hue = attacks)
plt.grid()
plt.show()

# Orange ones are anomalies'''
# Out:
# 'plt.figure(figsize=(12, 10))\nsns.scatterplot(x = X_analysis[:, 0], y = X_analysis[:, 1], s = 20, hue = attacks)\nplt.grid()\nplt.show()\n\n# Orange ones are anomalies'

# %%
'''plt.figure(figsize = (12, 10))
sns.scatterplot(x = X_analysis[:, 0], y = X_analysis[:, 1], s = 20, hue = Y_test_VAE)
plt.grid()
plt.show()

# Ground truth'''
# Out:
# 'plt.figure(figsize = (12, 10))\nsns.scatterplot(x = X_analysis[:, 0], y = X_analysis[:, 1], s = 20, hue = Y_test_VAE)\nplt.grid()\nplt.show()\n\n# Ground truth'
