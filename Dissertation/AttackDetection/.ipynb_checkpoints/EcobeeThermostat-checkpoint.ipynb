# %%
# !pip3 install pandas
# !pip3 install seaborn
# !pip3 install --upgrade tensorflow-gpu
# !pip3 install import-ipynb
# !pip3 install cuda-python

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 

from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import math
import pickle
import time
import sys

import import_ipynb
import AttackDetectionModel

import tensorflow as tf
tf.compat.v1.disable_eager_execution()
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras import optimizers

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.metrics import f1_score, confusion_matrix

from bayes_opt import BayesianOptimization

# %matplotlib inline
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/andressa.amaral/.local/lib/python3.8/site-packages (1.5.1)
# Requirement already satisfied: numpy>=1.20.3 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from pandas) (1.23.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from pandas) (2022.6)
# Requirement already satisfied: six>=1.5 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in /home/andressa.amaral/.local/lib/python3.8/site-packages (0.12.1)
# Requirement already satisfied: numpy>=1.17 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from seaborn) (1.23.4)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from seaborn) (3.6.2)
# Requirement already satisfied: pandas>=0.25 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from seaborn) (1.5.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.6)
# Requirement already satisfied: pillow>=6.2.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.3.0)
# Requirement already satisfied: pytz>=2020.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from pandas>=0.25->seaborn) (2022.6)
# Requirement already satisfied: six>=1.5 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow-gpu in /home/andressa.amaral/.local/lib/python3.8/site-packages (2.11.0)
# Requirement already satisfied: numpy>=1.20 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (1.23.4)
# Requirement already satisfied: termcolor>=1.1.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (2.1.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (1.14.1)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (2.11.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (0.4.0)
# Requirement already satisfied: flatbuffers>=2.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (22.10.26)
# Requirement already satisfied: six>=1.12.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (1.50.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (4.4.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (2.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (14.0.6)
# Requirement already satisfied: h5py>=2.9.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (3.7.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (3.3.0)
# Requirement already satisfied: packaging in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (21.3)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (0.2.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (3.19.6)
# Requirement already satisfied: astunparse>=1.6.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (1.6.3)
# Requirement already satisfied: setuptools in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (65.5.1)
# Requirement already satisfied: absl-py>=1.0.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (1.3.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (0.27.0)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (2.11.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/lib/python3/dist-packages (from astunparse>=1.6.0->tensorflow-gpu) (0.30.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorboard<2.12,>=2.11->tensorflow-gpu) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorboard<2.12,>=2.11->tensorflow-gpu) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorboard<2.12,>=2.11->tensorflow-gpu) (2.14.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorboard<2.12,>=2.11->tensorflow-gpu) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorboard<2.12,>=2.11->tensorflow-gpu) (0.4.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorboard<2.12,>=2.11->tensorflow-gpu) (2.28.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorboard<2.12,>=2.11->tensorflow-gpu) (2.2.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from packaging->tensorflow-gpu) (3.0.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-gpu) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-gpu) (5.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-gpu) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-gpu) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-gpu) (5.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-gpu) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-gpu) (2018.1.18)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-gpu) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-gpu) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow-gpu) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-gpu) (3.10.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-gpu) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-gpu) (3.2.2)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: import-ipynb in /home/andressa.amaral/.local/lib/python3.8/site-packages (0.1.4)
# Requirement already satisfied: IPython in /home/andressa.amaral/.local/lib/python3.8/site-packages (from import-ipynb) (8.6.0)
# Requirement already satisfied: nbformat in /home/andressa.amaral/.local/lib/python3.8/site-packages (from import-ipynb) (5.7.0)
# Requirement already satisfied: traitlets>=5 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from IPython->import-ipynb) (5.5.0)
# Requirement already satisfied: stack-data in /home/andressa.amaral/.local/lib/python3.8/site-packages (from IPython->import-ipynb) (0.6.1)
# Requirement already satisfied: pickleshare in /home/andressa.amaral/.local/lib/python3.8/site-packages (from IPython->import-ipynb) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from IPython->import-ipynb) (0.18.1)
# Requirement already satisfied: pexpect>4.3 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from IPython->import-ipynb) (4.8.0)
# Requirement already satisfied: backcall in /home/andressa.amaral/.local/lib/python3.8/site-packages (from IPython->import-ipynb) (0.2.0)
# Requirement already satisfied: decorator in /usr/lib/python3/dist-packages (from IPython->import-ipynb) (4.1.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from IPython->import-ipynb) (3.0.32)
# Requirement already satisfied: pygments>=2.4.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from IPython->import-ipynb) (2.13.0)
# Requirement already satisfied: matplotlib-inline in /home/andressa.amaral/.local/lib/python3.8/site-packages (from IPython->import-ipynb) (0.1.6)
# Requirement already satisfied: fastjsonschema in /home/andressa.amaral/.local/lib/python3.8/site-packages (from nbformat->import-ipynb) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from nbformat->import-ipynb) (4.17.0)
# Requirement already satisfied: jupyter-core in /home/andressa.amaral/.local/lib/python3.8/site-packages (from nbformat->import-ipynb) (5.0.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from jedi>=0.16->IPython->import-ipynb) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (22.1.0)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (1.3.10)
# Requirement already satisfied: importlib-resources>=1.4.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (5.10.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (0.19.2)
# Requirement already satisfied: ptyprocess>=0.5 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from pexpect>4.3->IPython->import-ipynb) (0.7.0)
# Requirement already satisfied: wcwidth in /home/andressa.amaral/.local/lib/python3.8/site-packages (from prompt-toolkit<3.1.0,>3.0.1->IPython->import-ipynb) (0.2.5)
# Requirement already satisfied: platformdirs in /home/andressa.amaral/.local/lib/python3.8/site-packages (from jupyter-core->nbformat->import-ipynb) (2.5.4)
# Requirement already satisfied: pure-eval in /home/andressa.amaral/.local/lib/python3.8/site-packages (from stack-data->IPython->import-ipynb) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from stack-data->IPython->import-ipynb) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from stack-data->IPython->import-ipynb) (2.1.0)
# Requirement already satisfied: six in /home/andressa.amaral/.local/lib/python3.8/site-packages (from asttokens>=2.1.0->stack-data->IPython->import-ipynb) (1.16.0)
# Requirement already satisfied: zipp>=3.1.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat->import-ipynb) (3.10.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: cuda-python in /home/andressa.amaral/.local/lib/python3.8/site-packages (11.8.1)
# Requirement already satisfied: cython in /home/andressa.amaral/.local/lib/python3.8/site-packages (from cuda-python) (0.29.32)
# importing Jupyter notebook from AttackDetectionModel.ipynb

# %%
gpu_options = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction = 0.333)
sess = tf.compat.v1.Session(config = tf.compat.v1.ConfigProto(gpu_options = gpu_options))

# %% [markdown]
# # Data Pre-Processing

# %%
#number_features = 115
#number_features = 92
#number_features = 69
#number_features = 46
number_features = 23

# %%
# Get benign traffic 
df_et_benign = AttackDetectionModel.get_files('../../nbaiot/Ecobee_Thermostat', number_features)

# Get Bashlite traffic
df_et_bashlite = AttackDetectionModel.get_files('../../nbaiot/Ecobee_Thermostat/gafgyt', number_features)

# Get Mirai traffic
df_et_mirai = AttackDetectionModel.get_files('../../nbaiot/Ecobee_Thermostat/mirai', number_features)

# %%
# Normalize with the min-max scaler
scaler = MinMaxScaler()
df_et_benign_norm = scaler.fit_transform(df_et_benign)
df_et_bashlite_norm = scaler.fit_transform(df_et_bashlite)
df_et_mirai_norm = scaler.fit_transform(df_et_mirai)

# %% [markdown]
# # Sets

# %%
# Train set
len_benign_train = int(0.7 * len(df_et_benign_norm))
X_train = df_et_benign_norm[:len_benign_train]

# %%
# Test set
X_test_benign = df_et_benign_norm[len_benign_train:]
X_test = np.concatenate([X_test_benign, df_et_bashlite_norm, df_et_mirai_norm])

Y_test = np.ones(len(X_test))
Y_test[:len(X_test_benign)] = 0

# %% [markdown]
# # Model

# %%
# Parameters
original_dim = X_train.shape[1]
input_shape = (original_dim,)
intermediate_dim = int(original_dim / 2)
latent_dim = int(original_dim / 3)

# Initial values
epochs = 5
learning_rate = 0.0001
batch_size = 20
anomaly_threshold = 0.05

# Dictionary
dict_params = { 'learning_rate': learning_rate, 'batch_size': round(batch_size), 'epochs': round(epochs)}
pbounds = { 'learning_rate': (0.000001, 0.001), 'batch_size': (10, 100), 'epochs': (50, 500)}

# %%
# KL Loss function
def vae_loss(x, x_decoded_mean):
    # Compute the average MSE error, then scale it up (sum on all axes)
    
    reconstruction_loss = K.sum(K.square(x - x_decoded_mean))
    
    # Compute the KL loss
    
    kl_loss = - 0.5 * K.sum(1 + z_var - K.square(z_mean) - K.square(K.exp(z_var)), axis=-1)
    
    # Return the average loss over all 
    
    total_loss = K.mean(reconstruction_loss + kl_loss) # Total_loss = reconstruction_loss + kl_loss 
    return total_loss

# (1) Reconstruction Loss - Forces the encoder to generate latent features that minimize the reconstruction error, or else is
# penalized
# (2) KL Loss - Forces the distribution generated by the encoder to be similar to the prior probability of the input vector, 
# pushing latent feature space to normality

# %%
# Encoder
inputs, encoder, z_var, z_mean = AttackDetectionModel.vae_encoder(input_shape, 
                                                                  intermediate_dim, 
                                                                  latent_dim, 
                                                                  AttackDetectionModel.reparametrization)
encoder.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  encoder_input (InputLayer)     [(None, 23)]         0           []
#
#  dense (Dense)                  (None, 11)           264         ['encoder_input[0][0]']
#
#  z_mean (Dense)                 (None, 7)            84          ['dense[0][0]']
#
#  z_var (Dense)                  (None, 7)            84          ['dense[0][0]']
#
#  z (Lambda)                     (None, 7)            0           ['z_mean[0][0]',
#                                                                   'z_var[0][0]']
#
# ==================================================================================================
# Total params: 432
# Trainable params: 432
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Decoder
decoder = AttackDetectionModel.vae_decoder(intermediate_dim, latent_dim, original_dim)
outputs = decoder(encoder(inputs))
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  z_sampling (InputLayer)     [(None, 7)]               0
#
#  dense_1 (Dense)             (None, 11)                88
#
#  dense_2 (Dense)             (None, 23)                276
#
# =================================================================
# Total params: 364
# Trainable params: 364
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Hyperparameter Optimization

# %%
def maximize_training(X_train = X_train, 
                      X_test = X_test, 
                      Y_test = Y_test, 
                      inputs = inputs, 
                      outputs = outputs, 
                      vae_loss = vae_loss,
                      learning_rate = learning_rate,
                      batch_size = batch_size,
                      epochs = epochs,
                      anomaly_threshold = anomaly_threshold):    
    
    # Create model
    opt_adam = optimizers.Adam(learning_rate = dict_params['learning_rate'], clipvalue = 0.5)
    model = Model(inputs, outputs, name = 'vae_mlp')
    model.compile(optimizer = opt_adam, loss = vae_loss)

    # Train
    history = model.fit(X_train, 
                        X_train, 
                        shuffle = True, 
                        verbose = 0,
                        epochs = dict_params['epochs'], 
                        batch_size = dict_params['batch_size'])
    
    # Maximize the f1-score
    X_pred_opt = model.predict(X_test)
    error_vector_opt = AttackDetectionModel.get_error_term(X_pred_opt, X_test, _rmse = False)
    Y_pred_opt = (error_vector_opt > anomaly_threshold)
    f1 = f1_score(Y_test, Y_pred_opt)
    
    return f1

# %%
'''
# Apply Bayesian optimization to choose the best hyperparameters

opt = BayesianOptimization(f = maximize_training,
                           pbounds = pbounds,
                           verbose = 2, 
                           random_state = 1)

opt_start = time.time()

opt.maximize(init_points = 5, n_iter = 5)

opt_end = time.time()
opt_time = opt_end - opt_start
print("Optimization time:", opt_time)

learning_rate = opt.max['params']['learning_rate']
epochs = round(opt.max['params']['epochs'])
batch_size = round(opt.max['params']['batch_size'])
'''
# Out:
# '\n# Apply Bayesian optimization to choose the best hyperparameters\n\nopt = BayesianOptimization(f = maximize_training,\n                           pbounds = pbounds,\n                           verbose = 2, \n                           random_state = 1)\n\nopt_start = time.time()\n\nopt.maximize(init_points = 5, n_iter = 5)\n\nopt_end = time.time()\nopt_time = opt_end - opt_start\nprint("Optimization time:", opt_time)\n\nlearning_rate = opt.max[\'params\'][\'learning_rate\']\nepochs = round(opt.max[\'params\'][\'epochs\'])\nbatch_size = round(opt.max[\'params\'][\'batch_size\'])\n'

# %% [markdown]
# # Predict Attacks

# %%
# Training step with the best hyperparameters
learning_rate = 0.00012123446827562964
epochs = 422
batch_size = 74
opt_time = 262.7667851448059
anomaly_threshold = 0.04

# %%
for i in range(1):
    print("Iteration " + str(i))
    
    # Train
    vae_model, train_time = AttackDetectionModel.train(X_train, inputs, outputs, vae_loss, learning_rate, epochs, batch_size)
    
    # Set the optimized anomaly threshold
    #anomaly_threshold = AttackDetectionModel.get_anomaly_threshold(X_train, vae_model)
    
    # Test
    X_pred, test_time = AttackDetectionModel.test(X_test, vae_model)
    Y_test, Y_pred = AttackDetectionModel.get_prediction(Y_test, X_pred, X_test, anomaly_threshold, vae_model)
    
    # Metrics
    acc, f1, pre, rec = AttackDetectionModel.get_scores(Y_test, Y_pred)
    
    # Print results
    AttackDetectionModel.print_results(number_features,
                                       learning_rate,
                                       epochs,
                                       batch_size,
                                       anomaly_threshold,
                                       X_train,
                                       X_test,
                                       opt_time,
                                       train_time,
                                       test_time,
                                       acc,
                                       f1,
                                       pre,
                                       rec,
                                       Y_test,
                                       Y_pred,
                                       "Results/ecobee_thermostat.txt")
    
    print("")
# Out:
# Iteration 0
# Train on 9179 samples
# Epoch 1/422
# 9179/9179 [==============================] - 1s 59us/sample - loss: 274.0953
# Epoch 2/422
# 9179/9179 [==============================] - 0s 29us/sample - loss: 246.1367
# Epoch 3/422
# 9179/9179 [==============================] - 0s 29us/sample - loss: 217.3762
# Epoch 4/422
# 9179/9179 [==============================] - 0s 29us/sample - loss: 185.8289
# Epoch 5/422
# 9179/9179 [==============================] - 0s 29us/sample - loss: 153.1945
# Epoch 6/422
# 9179/9179 [==============================] - 0s 26us/sample - loss: 119.6318
# Epoch 7/422
# 9179/9179 [==============================] - 0s 28us/sample - loss: 88.0336
# Epoch 8/422
# 9179/9179 [==============================] - 0s 28us/sample - loss: 62.7173
# Epoch 9/422
# 9179/9179 [==============================] - 0s 27us/sample - loss: 43.9695
# Epoch 10/422
# 9179/9179 [==============================] - 0s 28us/sample - loss: 33.8796
# Epoch 11/422
# 9179/9179 [==============================] - 0s 27us/sample - loss: 29.2778
# Epoch 12/422
# 9179/9179 [==============================] - 0s 28us/sample - loss: 26.6930
# Epoch 13/422
# 9179/9179 [==============================] - 0s 29us/sample - loss: 25.1095
# Epoch 14/422
# 9179/9179 [==============================] - 0s 28us/sample - loss: 23.8404
# Epoch 15/422
# 9179/9179 [==============================] - 0s 29us/sample - loss: 22.7079
# Epoch 16/422
# 9179/9179 [==============================] - 0s 29us/sample - loss: 21.7177
# Epoch 17/422
# 9179/9179 [==============================] - 0s 28us/sample - loss: 21.0067
# Epoch 18/422
# 9179/9179 [==============================] - 0s 30us/sample - loss: 20.2720
# Epoch 19/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 19.6845
# Epoch 20/422
# 9179/9179 [==============================] - 0s 29us/sample - loss: 19.0807
# Epoch 21/422
# 9179/9179 [==============================] - 0s 24us/sample - loss: 18.5756
# Epoch 22/422
# 9179/9179 [==============================] - 0s 25us/sample - loss: 18.0558
# Epoch 23/422
# 9179/9179 [==============================] - 0s 29us/sample - loss: 17.8129
# Epoch 24/422
# 9179/9179 [==============================] - 0s 28us/sample - loss: 17.4735
# Epoch 25/422
# 9179/9179 [==============================] - 0s 29us/sample - loss: 17.0708
# Epoch 26/422
# 9179/9179 [==============================] - 0s 29us/sample - loss: 16.8720
# Epoch 27/422
# 9179/9179 [==============================] - 0s 29us/sample - loss: 16.5443
# Epoch 28/422
# 9179/9179 [==============================] - 0s 27us/sample - loss: 16.3580
# Epoch 29/422
# 9179/9179 [==============================] - 0s 28us/sample - loss: 16.0737
# Epoch 30/422
# 9179/9179 [==============================] - 0s 30us/sample - loss: 15.8754
# Epoch 31/422
# 9179/9179 [==============================] - 0s 29us/sample - loss: 15.5407
# Epoch 32/422
# 9179/9179 [==============================] - 0s 29us/sample - loss: 15.2991
# Epoch 33/422
# 9179/9179 [==============================] - 0s 29us/sample - loss: 15.0773
# Epoch 34/422
# 9179/9179 [==============================] - 0s 29us/sample - loss: 14.8291
# Epoch 35/422
# 9179/9179 [==============================] - 0s 29us/sample - loss: 14.3246
# Epoch 36/422
# 9179/9179 [==============================] - 0s 29us/sample - loss: 13.9530
# Epoch 37/422
# 9179/9179 [==============================] - 0s 30us/sample - loss: 13.4742
# Epoch 38/422
# 9179/9179 [==============================] - 0s 28us/sample - loss: 13.1550
# Epoch 39/422
# 9179/9179 [==============================] - 0s 29us/sample - loss: 12.6215
# Epoch 40/422
# 9179/9179 [==============================] - 0s 29us/sample - loss: 12.1313
# Epoch 41/422
# 9179/9179 [==============================] - 0s 29us/sample - loss: 11.6269
# Epoch 42/422
# 9179/9179 [==============================] - 0s 29us/sample - loss: 11.2976
# Epoch 43/422
# 9179/9179 [==============================] - 0s 28us/sample - loss: 10.9604
# Epoch 44/422
# 9179/9179 [==============================] - 0s 28us/sample - loss: 10.7025
# Epoch 45/422
# 9179/9179 [==============================] - 0s 29us/sample - loss: 10.4711
# Epoch 46/422
# 9179/9179 [==============================] - 0s 29us/sample - loss: 10.2504
# Epoch 47/422
# 9179/9179 [==============================] - 0s 29us/sample - loss: 10.0543
# Epoch 48/422
# 9179/9179 [==============================] - 0s 29us/sample - loss: 9.8783
# Epoch 49/422
# 9179/9179 [==============================] - 0s 27us/sample - loss: 9.7329
# Epoch 50/422
# 9179/9179 [==============================] - 0s 29us/sample - loss: 9.5818
# Epoch 51/422
# 9179/9179 [==============================] - 0s 29us/sample - loss: 9.4540
# Epoch 52/422
# 9179/9179 [==============================] - 0s 29us/sample - loss: 9.3467
# Epoch 53/422
# 9179/9179 [==============================] - 0s 27us/sample - loss: 9.2317
# Epoch 54/422
# 9179/9179 [==============================] - 0s 31us/sample - loss: 9.0450
# Epoch 55/422
# 9179/9179 [==============================] - 0s 31us/sample - loss: 8.9462
# Epoch 56/422
# 9179/9179 [==============================] - 0s 29us/sample - loss: 8.8503
# Epoch 57/422
# 9179/9179 [==============================] - 0s 27us/sample - loss: 8.7720
# Epoch 58/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 8.6035
# Epoch 59/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 8.5350
# Epoch 60/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 8.4295
# Epoch 61/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 8.3557
# Epoch 62/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 8.2373
# Epoch 63/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 8.1894
# Epoch 64/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 8.0941
# Epoch 65/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 7.9877
# Epoch 66/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 7.9430
# Epoch 67/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 7.8448
# Epoch 68/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 7.7791
# Epoch 69/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 7.6835
# Epoch 70/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 7.6516
# Epoch 71/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 7.5465
# Epoch 72/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 7.4905
# Epoch 73/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 7.4195
# Epoch 74/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 7.3550
# Epoch 75/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 7.2753
# Epoch 76/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 7.2427
# Epoch 77/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 7.1607
# Epoch 78/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 7.1056
# Epoch 79/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 7.0323
# Epoch 80/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 6.9557
# Epoch 81/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 6.9416
# Epoch 82/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 6.8830
# Epoch 83/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 6.8050
# Epoch 84/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 6.7776
# Epoch 85/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 6.6774
# Epoch 86/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 6.6498
# Epoch 87/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 6.6126
# Epoch 88/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 6.5246
# Epoch 89/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 6.5458
# Epoch 90/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 6.4801
# Epoch 91/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 6.4268
# Epoch 92/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 6.3483
# Epoch 93/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 6.3430
# Epoch 94/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 6.2978
# Epoch 95/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 6.2763
# Epoch 96/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 6.2328
# Epoch 97/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 6.1925
# Epoch 98/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 6.1255
# Epoch 99/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 6.1247
# Epoch 100/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 6.0690
# Epoch 101/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 6.0723
# Epoch 102/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 6.0084
# Epoch 103/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.9268
# Epoch 104/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.9388
# Epoch 105/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.8829
# Epoch 106/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.9209
# Epoch 107/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 5.8468
# Epoch 108/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.8624
# Epoch 109/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.8274
# Epoch 110/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.8271
# Epoch 111/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.7962
# Epoch 112/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 5.7219
# Epoch 113/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 5.7505
# Epoch 114/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.7355
# Epoch 115/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 5.6894
# Epoch 116/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 5.6694
# Epoch 117/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.6750
# Epoch 118/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.6431
# Epoch 119/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.6420
# Epoch 120/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 5.6155
# Epoch 121/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 5.5952
# Epoch 122/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 5.5765
# Epoch 123/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 5.5721
# Epoch 124/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.5406
# Epoch 125/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.5297
# Epoch 126/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.4914
# Epoch 127/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.5527
# Epoch 128/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.4831
# Epoch 129/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.4962
# Epoch 130/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.4763
# Epoch 131/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.4859
# Epoch 132/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.4862
# Epoch 133/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.4579
# Epoch 134/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.4496
# Epoch 135/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.4210
# Epoch 136/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.4358
# Epoch 137/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.4048
# Epoch 138/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 5.4001
# Epoch 139/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.4024
# Epoch 140/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 5.3745
# Epoch 141/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.3933
# Epoch 142/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.3667
# Epoch 143/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.3660
# Epoch 144/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.3633
# Epoch 145/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.3251
# Epoch 146/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.3419
# Epoch 147/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.3631
# Epoch 148/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.3474
# Epoch 149/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.3227
# Epoch 150/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.3390
# Epoch 151/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 5.3113
# Epoch 152/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 5.2882
# Epoch 153/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.2959
# Epoch 154/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.2785
# Epoch 155/422
# 9179/9179 [==============================] - 0s 16us/sample - loss: 5.2967
# Epoch 156/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.2816
# Epoch 157/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.2757
# Epoch 158/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.2780
# Epoch 159/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.2360
# Epoch 160/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.2555
# Epoch 161/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.2612
# Epoch 162/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.2390
# Epoch 163/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.2404
# Epoch 164/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.2563
# Epoch 165/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 5.2370
# Epoch 166/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.2564
# Epoch 167/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.2140
# Epoch 168/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.2069
# Epoch 169/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.2254
# Epoch 170/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.2071
# Epoch 171/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.1822
# Epoch 172/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.1548
# Epoch 173/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.1649
# Epoch 174/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.1878
# Epoch 175/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.1765
# Epoch 176/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.1605
# Epoch 177/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.1858
# Epoch 178/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.1781
# Epoch 179/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.1316
# Epoch 180/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.1219
# Epoch 181/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.1597
# Epoch 182/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.1499
# Epoch 183/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.1634
# Epoch 184/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.1411
# Epoch 185/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.1295
# Epoch 186/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.1500
# Epoch 187/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.1217
# Epoch 188/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.1143
# Epoch 189/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.1021
# Epoch 190/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.0981
# Epoch 191/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.0968
# Epoch 192/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.1145
# Epoch 193/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.1113
# Epoch 194/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.0824
# Epoch 195/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.1104
# Epoch 196/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.1043
# Epoch 197/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.0793
# Epoch 198/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.0704
# Epoch 199/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.0682
# Epoch 200/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.0830
# Epoch 201/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.0791
# Epoch 202/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.0776
# Epoch 203/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.0446
# Epoch 204/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.0714
# Epoch 205/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.0336
# Epoch 206/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.0513
# Epoch 207/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.0443
# Epoch 208/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.0476
# Epoch 209/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.0552
# Epoch 210/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.0277
# Epoch 211/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.0549
# Epoch 212/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.0575
# Epoch 213/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.0463
# Epoch 214/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.0121
# Epoch 215/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.0191
# Epoch 216/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 5.0475
# Epoch 217/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.0236
# Epoch 218/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 4.9758
# Epoch 219/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.0100
# Epoch 220/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 5.0080
# Epoch 221/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 4.9972
# Epoch 222/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 4.9701
# Epoch 223/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 4.9757
# Epoch 224/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 4.9891
# Epoch 225/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 4.9924
# Epoch 226/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 4.9813
# Epoch 227/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 4.9655
# Epoch 228/422
# 9179/9179 [==============================] - 0s 16us/sample - loss: 4.9812
# Epoch 229/422
# 9179/9179 [==============================] - 0s 16us/sample - loss: 5.0020
# Epoch 230/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.9545
# Epoch 231/422
# 9179/9179 [==============================] - 0s 25us/sample - loss: 4.9403
# Epoch 232/422
# 9179/9179 [==============================] - 0s 18us/sample - loss: 4.9854
# Epoch 233/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 4.9979
# Epoch 234/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.9485
# Epoch 235/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 4.9425
# Epoch 236/422
# 9179/9179 [==============================] - 0s 26us/sample - loss: 4.9365
# Epoch 237/422
# 9179/9179 [==============================] - 0s 25us/sample - loss: 4.9137
# Epoch 238/422
# 9179/9179 [==============================] - 0s 24us/sample - loss: 4.9435
# Epoch 239/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 4.9308
# Epoch 240/422
# 9179/9179 [==============================] - 0s 24us/sample - loss: 4.9467
# Epoch 241/422
# 9179/9179 [==============================] - 0s 21us/sample - loss: 4.9474
# Epoch 242/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 4.9375
# Epoch 243/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 4.9460
# Epoch 244/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 4.9268
# Epoch 245/422
# 9179/9179 [==============================] - 0s 24us/sample - loss: 4.8842
# Epoch 246/422
# 9179/9179 [==============================] - 0s 25us/sample - loss: 4.8833
# Epoch 247/422
# 9179/9179 [==============================] - 0s 25us/sample - loss: 4.8955
# Epoch 248/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 4.9085
# Epoch 249/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 4.8688
# Epoch 250/422
# 9179/9179 [==============================] - 0s 27us/sample - loss: 4.9018
# Epoch 251/422
# 9179/9179 [==============================] - 0s 24us/sample - loss: 4.8774
# Epoch 252/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 4.8415
# Epoch 253/422
# 9179/9179 [==============================] - 0s 25us/sample - loss: 4.8697
# Epoch 254/422
# 9179/9179 [==============================] - 0s 25us/sample - loss: 4.8737
# Epoch 255/422
# 9179/9179 [==============================] - 0s 25us/sample - loss: 4.8617
# Epoch 256/422
# 9179/9179 [==============================] - 0s 24us/sample - loss: 4.8624
# Epoch 257/422
# 9179/9179 [==============================] - 0s 25us/sample - loss: 4.8466
# Epoch 258/422
# 9179/9179 [==============================] - 0s 26us/sample - loss: 4.8449
# Epoch 259/422
# 9179/9179 [==============================] - 0s 25us/sample - loss: 4.8443
# Epoch 260/422
# 9179/9179 [==============================] - 0s 24us/sample - loss: 4.8268
# Epoch 261/422
# 9179/9179 [==============================] - 0s 26us/sample - loss: 4.8412
# Epoch 262/422
# 9179/9179 [==============================] - 0s 28us/sample - loss: 4.8466
# Epoch 263/422
# 9179/9179 [==============================] - 0s 24us/sample - loss: 4.8155
# Epoch 264/422
# 9179/9179 [==============================] - 0s 24us/sample - loss: 4.8258
# Epoch 265/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 4.8356
# Epoch 266/422
# 9179/9179 [==============================] - 0s 25us/sample - loss: 4.8287
# Epoch 267/422
# 9179/9179 [==============================] - 0s 25us/sample - loss: 4.8203
# Epoch 268/422
# 9179/9179 [==============================] - 0s 25us/sample - loss: 4.7721
# Epoch 269/422
# 9179/9179 [==============================] - 0s 24us/sample - loss: 4.8173
# Epoch 270/422
# 9179/9179 [==============================] - 0s 24us/sample - loss: 4.8038
# Epoch 271/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 4.8106
# Epoch 272/422
# 9179/9179 [==============================] - 0s 26us/sample - loss: 4.7864
# Epoch 273/422
# 9179/9179 [==============================] - 0s 25us/sample - loss: 4.8037
# Epoch 274/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.7799
# Epoch 275/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 4.8139
# Epoch 276/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 4.7727
# Epoch 277/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 4.8062
# Epoch 278/422
# 9179/9179 [==============================] - 0s 27us/sample - loss: 4.7721
# Epoch 279/422
# 9179/9179 [==============================] - 0s 26us/sample - loss: 4.7870
# Epoch 280/422
# 9179/9179 [==============================] - 0s 25us/sample - loss: 4.7671
# Epoch 281/422
# 9179/9179 [==============================] - 0s 24us/sample - loss: 4.7402
# Epoch 282/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 4.7718
# Epoch 283/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.7622
# Epoch 284/422
# 9179/9179 [==============================] - 0s 24us/sample - loss: 4.7491
# Epoch 285/422
# 9179/9179 [==============================] - 0s 25us/sample - loss: 4.7478
# Epoch 286/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 4.7440
# Epoch 287/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.7115
# Epoch 288/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 4.7597
# Epoch 289/422
# 9179/9179 [==============================] - 0s 25us/sample - loss: 4.7169
# Epoch 290/422
# 9179/9179 [==============================] - 0s 26us/sample - loss: 4.7468
# Epoch 291/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 4.7296
# Epoch 292/422
# 9179/9179 [==============================] - 0s 27us/sample - loss: 4.7135
# Epoch 293/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 4.7113
# Epoch 294/422
# 9179/9179 [==============================] - 0s 19us/sample - loss: 4.7133
# Epoch 295/422
# 9179/9179 [==============================] - 0s 24us/sample - loss: 4.7315
# Epoch 296/422
# 9179/9179 [==============================] - 0s 24us/sample - loss: 4.7117
# Epoch 297/422
# 9179/9179 [==============================] - 0s 28us/sample - loss: 4.6952
# Epoch 298/422
# 9179/9179 [==============================] - 0s 28us/sample - loss: 4.6924
# Epoch 299/422
# 9179/9179 [==============================] - 0s 27us/sample - loss: 4.7399
# Epoch 300/422
# 9179/9179 [==============================] - 0s 28us/sample - loss: 4.7036
# Epoch 301/422
# 9179/9179 [==============================] - 0s 26us/sample - loss: 4.7069
# Epoch 302/422
# 9179/9179 [==============================] - 0s 27us/sample - loss: 4.6763
# Epoch 303/422
# 9179/9179 [==============================] - 0s 27us/sample - loss: 4.6689
# Epoch 304/422
# 9179/9179 [==============================] - 0s 27us/sample - loss: 4.6784
# Epoch 305/422
# 9179/9179 [==============================] - 0s 27us/sample - loss: 4.6970
# Epoch 306/422
# 9179/9179 [==============================] - 0s 26us/sample - loss: 4.6895
# Epoch 307/422
# 9179/9179 [==============================] - 0s 27us/sample - loss: 4.6895
# Epoch 308/422
# 9179/9179 [==============================] - 0s 28us/sample - loss: 4.6658
# Epoch 309/422
# 9179/9179 [==============================] - 0s 27us/sample - loss: 4.6681
# Epoch 310/422
# 9179/9179 [==============================] - 0s 25us/sample - loss: 4.6486
# Epoch 311/422
# 9179/9179 [==============================] - 0s 28us/sample - loss: 4.6451
# Epoch 312/422
# 9179/9179 [==============================] - 0s 27us/sample - loss: 4.6523
# Epoch 313/422
# 9179/9179 [==============================] - 0s 26us/sample - loss: 4.6588
# Epoch 314/422
# 9179/9179 [==============================] - 0s 28us/sample - loss: 4.6732
# Epoch 315/422
# 9179/9179 [==============================] - 0s 28us/sample - loss: 4.6436
# Epoch 316/422
# 9179/9179 [==============================] - 0s 26us/sample - loss: 4.6365
# Epoch 317/422
# 9179/9179 [==============================] - 0s 27us/sample - loss: 4.6565
# Epoch 318/422
# 9179/9179 [==============================] - 0s 27us/sample - loss: 4.6330
# Epoch 319/422
# 9179/9179 [==============================] - 0s 27us/sample - loss: 4.6554
# Epoch 320/422
# 9179/9179 [==============================] - 0s 27us/sample - loss: 4.6268
# Epoch 321/422
# 9179/9179 [==============================] - 0s 24us/sample - loss: 4.6164
# Epoch 322/422
# 9179/9179 [==============================] - 0s 25us/sample - loss: 4.6289
# Epoch 323/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.6001
# Epoch 324/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 4.5766
# Epoch 325/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 4.6153
# Epoch 326/422
# 9179/9179 [==============================] - 0s 24us/sample - loss: 4.5957
# Epoch 327/422
# 9179/9179 [==============================] - 0s 25us/sample - loss: 4.5959
# Epoch 328/422
# 9179/9179 [==============================] - 0s 24us/sample - loss: 4.5878
# Epoch 329/422
# 9179/9179 [==============================] - 0s 24us/sample - loss: 4.5749
# Epoch 330/422
# 9179/9179 [==============================] - 0s 24us/sample - loss: 4.5848
# Epoch 331/422
# 9179/9179 [==============================] - 0s 25us/sample - loss: 4.5711
# Epoch 332/422
# 9179/9179 [==============================] - 0s 24us/sample - loss: 4.5735
# Epoch 333/422
# 9179/9179 [==============================] - 0s 24us/sample - loss: 4.5634
# Epoch 334/422
# 9179/9179 [==============================] - 0s 25us/sample - loss: 4.6001
# Epoch 335/422
# 9179/9179 [==============================] - 0s 24us/sample - loss: 4.5795
# Epoch 336/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.5646
# Epoch 337/422
# 9179/9179 [==============================] - 0s 25us/sample - loss: 4.5741
# Epoch 338/422
# 9179/9179 [==============================] - 0s 27us/sample - loss: 4.5710
# Epoch 339/422
# 9179/9179 [==============================] - 0s 24us/sample - loss: 4.5703
# Epoch 340/422
# 9179/9179 [==============================] - 0s 24us/sample - loss: 4.5555
# Epoch 341/422
# 9179/9179 [==============================] - 0s 24us/sample - loss: 4.5277
# Epoch 342/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 4.5545
# Epoch 343/422
# 9179/9179 [==============================] - 0s 24us/sample - loss: 4.5191
# Epoch 344/422
# 9179/9179 [==============================] - 0s 24us/sample - loss: 4.5256
# Epoch 345/422
# 9179/9179 [==============================] - 0s 27us/sample - loss: 4.5357
# Epoch 346/422
# 9179/9179 [==============================] - 0s 27us/sample - loss: 4.5137
# Epoch 347/422
# 9179/9179 [==============================] - 0s 27us/sample - loss: 4.5565
# Epoch 348/422
# 9179/9179 [==============================] - 0s 26us/sample - loss: 4.5191
# Epoch 349/422
# 9179/9179 [==============================] - 0s 27us/sample - loss: 4.5060
# Epoch 350/422
# 9179/9179 [==============================] - 0s 27us/sample - loss: 4.5116
# Epoch 351/422
# 9179/9179 [==============================] - 0s 28us/sample - loss: 4.4916
# Epoch 352/422
# 9179/9179 [==============================] - 0s 27us/sample - loss: 4.5275
# Epoch 353/422
# 9179/9179 [==============================] - 0s 27us/sample - loss: 4.4992
# Epoch 354/422
# 9179/9179 [==============================] - 0s 28us/sample - loss: 4.5047
# Epoch 355/422
# 9179/9179 [==============================] - 0s 27us/sample - loss: 4.5047
# Epoch 356/422
# 9179/9179 [==============================] - 0s 26us/sample - loss: 4.4890
# Epoch 357/422
# 9179/9179 [==============================] - 0s 23us/sample - loss: 4.4885
# Epoch 358/422
# 9179/9179 [==============================] - 0s 22us/sample - loss: 4.4802
# Epoch 359/422
# 9179/9179 [==============================] - 0s 28us/sample - loss: 4.5034
# Epoch 360/422
# 9179/9179 [==============================] - 0s 20us/sample - loss: 4.5040
# Epoch 361/422
# 9179/9179 [==============================] - 0s 26us/sample - loss: 4.4748
# Epoch 362/422
# 9179/9179 [==============================] - 0s 24us/sample - loss: 4.4593
# Epoch 363/422
# 9179/9179 [==============================] - 0s 17us/sample - loss: 4.4799
# Epoch 364/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 4.4528
# Epoch 365/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 4.4198
# Epoch 366/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 4.5011
# Epoch 367/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 4.4614
# Epoch 368/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 4.4464
# Epoch 369/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 4.4573
# Epoch 370/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 4.4185
# Epoch 371/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 4.4467
# Epoch 372/422
# 9179/9179 [==============================] - 0s 16us/sample - loss: 4.4674
# Epoch 373/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 4.4315
# Epoch 374/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 4.4440
# Epoch 375/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 4.4336
# Epoch 376/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 4.4120
# Epoch 377/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 4.3893
# Epoch 378/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 4.3910
# Epoch 379/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 4.4257
# Epoch 380/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 4.4349
# Epoch 381/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 4.4292
# Epoch 382/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 4.3790
# Epoch 383/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 4.4170
# Epoch 384/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 4.4067
# Epoch 385/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 4.3904
# Epoch 386/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 4.4112
# Epoch 387/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 4.3868
# Epoch 388/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 4.3474
# Epoch 389/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 4.3956
# Epoch 390/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 4.3762
# Epoch 391/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 4.3841
# Epoch 392/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 4.3743
# Epoch 393/422
# 9179/9179 [==============================] - 0s 16us/sample - loss: 4.3551
# Epoch 394/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 4.3718
# Epoch 395/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 4.3824
# Epoch 396/422
# 9179/9179 [==============================] - 0s 16us/sample - loss: 4.3722
# Epoch 397/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 4.3483
# Epoch 398/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 4.3509
# Epoch 399/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 4.3643
# Epoch 400/422
# 9179/9179 [==============================] - 0s 16us/sample - loss: 4.3369
# Epoch 401/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 4.3678
# Epoch 402/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 4.3492
# Epoch 403/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 4.3689
# Epoch 404/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 4.3332
# Epoch 405/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 4.3613
# Epoch 406/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 4.3438
# Epoch 407/422
# 9179/9179 [==============================] - 0s 16us/sample - loss: 4.3546
# Epoch 408/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 4.3109
# Epoch 409/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 4.2994
# Epoch 410/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 4.3547
# Epoch 411/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 4.3299
# Epoch 412/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 4.3247
# Epoch 413/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 4.2844
# Epoch 414/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 4.3249
# Epoch 415/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 4.3190
# Epoch 416/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 4.3159
# Epoch 417/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 4.3327
# Epoch 418/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 4.3407
# Epoch 419/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 4.2995
# Epoch 420/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 4.2854
# Epoch 421/422
# 9179/9179 [==============================] - 0s 14us/sample - loss: 4.3291
# Epoch 422/422
# 9179/9179 [==============================] - 0s 15us/sample - loss: 4.2837
# Training time: 76.5439453125
# /home/andressa.amaral/.local/lib/python3.8/site-packages/keras/engine/training_v1.py:2357: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# Testing time: 11.263602256774902

# %% [markdown]
# # Metrics

# %%
# Examinig the latent space generated by the encoder
X_encoded = encoder.predict(X_test)

pca = PCA(n_components=2)
X_analysis = pca.fit_transform(X_encoded)
# Out:
# /home/andressa.amaral/.local/lib/python3.8/site-packages/keras/engine/training_v1.py:2357: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,

# %%
plt.figure(figsize=(8, 8))
sns.scatterplot(x = X_analysis[:, 0], y = X_analysis[:, 1], s = 20, hue = Y_pred)
plt.grid()
plt.savefig("Results/PCA/ET_" + str(number_features))
plt.show()

# Orange ones are anomalies

# %%
plt.figure(figsize = (8, 8))
sns.scatterplot(x = X_analysis[:, 0], y = X_analysis[:, 1], s = 20, hue = Y_test)
plt.grid()
plt.savefig("Results/PCA Groundtruth/ET_" + str(number_features))
plt.show()

# Ground truth

# %%
conf_matrix = confusion_matrix(Y_test, Y_pred)

fig, ax = plt.subplots(figsize = (5, 5))
ax.matshow(conf_matrix, cmap = plt.cm.Blues, alpha = 0.3)
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        ax.text(x = j, y = i,s = conf_matrix[i, j], va = 'center', ha = 'center', fontsize = 18)
 
plt.xlabel('Predictions', fontsize = 16)
plt.ylabel('Actuals', fontsize = 16)
plt.savefig("Results/Confusion Matrix/ET_" + str(number_features))
plt.show()
