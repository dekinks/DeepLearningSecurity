# %%
# !pip3 install pandas
# !pip3 install seaborn
# !pip3 install --upgrade tensorflow-gpu
# !pip3 install import-ipynb
# !pip3 install cuda-python

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 

from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import math
import pickle
import time
import sys

import import_ipynb
import AttackDetectionModel

import tensorflow as tf
tf.compat.v1.disable_eager_execution()
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras import optimizers

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.metrics import f1_score, confusion_matrix

from bayes_opt import BayesianOptimization

# %matplotlib inline
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/andressa.amaral/.local/lib/python3.8/site-packages (1.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from pandas) (2022.6)
# Requirement already satisfied: numpy>=1.20.3 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from pandas) (1.23.4)
# Requirement already satisfied: six>=1.5 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in /home/andressa.amaral/.local/lib/python3.8/site-packages (0.12.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from seaborn) (3.6.2)
# Requirement already satisfied: pandas>=0.25 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from seaborn) (1.5.1)
# Requirement already satisfied: numpy>=1.17 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from seaborn) (1.23.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (21.3)
# Requirement already satisfied: cycler>=0.10 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.3.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.6)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from pandas>=0.25->seaborn) (2022.6)
# Requirement already satisfied: six>=1.5 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow-gpu in /home/andressa.amaral/.local/lib/python3.8/site-packages (2.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (14.0.6)
# Requirement already satisfied: astunparse>=1.6.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (1.6.3)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (3.19.6)
# Requirement already satisfied: six>=1.12.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (1.16.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (2.11.0)
# Requirement already satisfied: packaging in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (21.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (3.3.0)
# Requirement already satisfied: absl-py>=1.0.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (1.3.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (0.4.0)
# Requirement already satisfied: flatbuffers>=2.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (22.10.26)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (0.27.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (2.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (1.14.1)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (2.11.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (2.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (4.4.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (1.50.0)
# Requirement already satisfied: numpy>=1.20 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (1.23.4)
# Requirement already satisfied: setuptools in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (65.5.1)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorflow-gpu) (3.7.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/lib/python3/dist-packages (from astunparse>=1.6.0->tensorflow-gpu) (0.30.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorboard<2.12,>=2.11->tensorflow-gpu) (2.14.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorboard<2.12,>=2.11->tensorflow-gpu) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorboard<2.12,>=2.11->tensorflow-gpu) (3.4.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorboard<2.12,>=2.11->tensorflow-gpu) (2.2.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorboard<2.12,>=2.11->tensorflow-gpu) (2.28.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorboard<2.12,>=2.11->tensorflow-gpu) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from tensorboard<2.12,>=2.11->tensorflow-gpu) (0.4.6)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from packaging->tensorflow-gpu) (3.0.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-gpu) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-gpu) (5.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-gpu) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-gpu) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-gpu) (5.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-gpu) (2018.1.18)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-gpu) (1.22)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-gpu) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-gpu) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow-gpu) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-gpu) (3.10.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-gpu) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-gpu) (3.2.2)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: import-ipynb in /home/andressa.amaral/.local/lib/python3.8/site-packages (0.1.4)
# Requirement already satisfied: nbformat in /home/andressa.amaral/.local/lib/python3.8/site-packages (from import-ipynb) (5.7.0)
# Requirement already satisfied: IPython in /home/andressa.amaral/.local/lib/python3.8/site-packages (from import-ipynb) (8.6.0)
# Requirement already satisfied: jedi>=0.16 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from IPython->import-ipynb) (0.18.1)
# Requirement already satisfied: backcall in /home/andressa.amaral/.local/lib/python3.8/site-packages (from IPython->import-ipynb) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from IPython->import-ipynb) (4.8.0)
# Requirement already satisfied: decorator in /usr/lib/python3/dist-packages (from IPython->import-ipynb) (4.1.2)
# Requirement already satisfied: stack-data in /home/andressa.amaral/.local/lib/python3.8/site-packages (from IPython->import-ipynb) (0.6.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from IPython->import-ipynb) (3.0.32)
# Requirement already satisfied: traitlets>=5 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from IPython->import-ipynb) (5.5.0)
# Requirement already satisfied: matplotlib-inline in /home/andressa.amaral/.local/lib/python3.8/site-packages (from IPython->import-ipynb) (0.1.6)
# Requirement already satisfied: pygments>=2.4.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from IPython->import-ipynb) (2.13.0)
# Requirement already satisfied: pickleshare in /home/andressa.amaral/.local/lib/python3.8/site-packages (from IPython->import-ipynb) (0.7.5)
# Requirement already satisfied: jupyter-core in /home/andressa.amaral/.local/lib/python3.8/site-packages (from nbformat->import-ipynb) (5.0.0)
# Requirement already satisfied: jsonschema>=2.6 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from nbformat->import-ipynb) (4.17.0)
# Requirement already satisfied: fastjsonschema in /home/andressa.amaral/.local/lib/python3.8/site-packages (from nbformat->import-ipynb) (2.16.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from jedi>=0.16->IPython->import-ipynb) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (0.19.2)
# Requirement already satisfied: importlib-resources>=1.4.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (5.10.0)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (1.3.10)
# Requirement already satisfied: ptyprocess>=0.5 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from pexpect>4.3->IPython->import-ipynb) (0.7.0)
# Requirement already satisfied: wcwidth in /home/andressa.amaral/.local/lib/python3.8/site-packages (from prompt-toolkit<3.1.0,>3.0.1->IPython->import-ipynb) (0.2.5)
# Requirement already satisfied: platformdirs in /home/andressa.amaral/.local/lib/python3.8/site-packages (from jupyter-core->nbformat->import-ipynb) (2.5.4)
# Requirement already satisfied: pure-eval in /home/andressa.amaral/.local/lib/python3.8/site-packages (from stack-data->IPython->import-ipynb) (0.2.2)
# Requirement already satisfied: asttokens>=2.1.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from stack-data->IPython->import-ipynb) (2.1.0)
# Requirement already satisfied: executing>=1.2.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from stack-data->IPython->import-ipynb) (1.2.0)
# Requirement already satisfied: six in /home/andressa.amaral/.local/lib/python3.8/site-packages (from asttokens>=2.1.0->stack-data->IPython->import-ipynb) (1.16.0)
# Requirement already satisfied: zipp>=3.1.0 in /home/andressa.amaral/.local/lib/python3.8/site-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat->import-ipynb) (3.10.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: cuda-python in /home/andressa.amaral/.local/lib/python3.8/site-packages (11.8.1)
# Requirement already satisfied: cython in /home/andressa.amaral/.local/lib/python3.8/site-packages (from cuda-python) (0.29.32)
# importing Jupyter notebook from AttackDetectionModel.ipynb

# %%
gpu_options = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction = 0.333)
sess = tf.compat.v1.Session(config = tf.compat.v1.ConfigProto(gpu_options = gpu_options))

# %% [markdown]
# # Data Pre-Processing

# %%
number_features = 115
#number_features = 92
#number_features = 69
#number_features = 46
#number_features = 23

# %%
# Get benign traffic 
df_p7_benign = AttackDetectionModel.get_files('../../nbaiot/Provision_PT_737E_Security_Camera', number_features)

# Get Bashlite traffic
df_p7_bashlite = AttackDetectionModel.get_files('../../nbaiot/Provision_PT_737E_Security_Camera/gafgyt', number_features)

# Get Mirai traffic
df_p7_mirai = AttackDetectionModel.get_files('../../nbaiot/Provision_PT_737E_Security_Camera/mirai', number_features)

# %%
# Normalize with the min-max scaler
scaler = MinMaxScaler()
df_p7_benign_norm = scaler.fit_transform(df_p7_benign)
df_p7_bashlite_norm = scaler.fit_transform(df_p7_bashlite)
df_p7_mirai_norm = scaler.fit_transform(df_p7_mirai)

# %% [markdown]
# # Sets

# %%
# Train set
len_benign_train = int(0.7 * len(df_p7_benign_norm))
X_train = df_p7_benign_norm[:len_benign_train]

# %%
# Test set
X_test_benign = df_p7_benign_norm[len_benign_train:]
X_test = np.concatenate([X_test_benign, df_p7_bashlite_norm, df_p7_mirai_norm])

Y_test = np.ones(len(X_test))
Y_test[:len(X_test_benign)] = 0

# %% [markdown]
# # Model

# %%
# Parameters
original_dim = X_train.shape[1]
input_shape = (original_dim,)
intermediate_dim = int(original_dim / 2)
latent_dim = int(original_dim / 3)

# Initial values
epochs = 5
learning_rate = 0.0001
batch_size = 32
anomaly_threshold = 0.035

# Dictionary
dict_params = { 'learning_rate': learning_rate, 'batch_size': round(batch_size), 'epochs': round(epochs)}
pbounds = { 'learning_rate': (0.000001, 0.001), 'batch_size': (10, 100), 'epochs': (50, 500)}

# %%
# KL Loss function
def vae_loss(x, x_decoded_mean):
    # Compute the average MSE error, then scale it up (sum on all axes)
    
    reconstruction_loss = K.sum(K.square(x - x_decoded_mean))
    
    # Compute the KL loss
    
    kl_loss = - 0.5 * K.sum(1 + z_var - K.square(z_mean) - K.square(K.exp(z_var)), axis=-1)
    
    # Return the average loss over all 
    
    total_loss = K.mean(reconstruction_loss + kl_loss) # Total_loss = reconstruction_loss + kl_loss 
    return total_loss

# (1) Reconstruction Loss - Forces the encoder to generate latent features that minimize the reconstruction error, or else is
# penalized
# (2) KL Loss - Forces the distribution generated by the encoder to be similar to the prior probability of the input vector, 
# pushing latent feature space to normality

# %%
# Encoder
inputs, encoder, z_var, z_mean = AttackDetectionModel.vae_encoder(input_shape, 
                                                                  intermediate_dim, 
                                                                  latent_dim, 
                                                                  AttackDetectionModel.reparametrization)
encoder.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  encoder_input (InputLayer)     [(None, 115)]        0           []
#
#  dense (Dense)                  (None, 57)           6612        ['encoder_input[0][0]']
#
#  z_mean (Dense)                 (None, 38)           2204        ['dense[0][0]']
#
#  z_var (Dense)                  (None, 38)           2204        ['dense[0][0]']
#
#  z (Lambda)                     (None, 38)           0           ['z_mean[0][0]',
#                                                                   'z_var[0][0]']
#
# ==================================================================================================
# Total params: 11,020
# Trainable params: 11,020
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Decoder
decoder = AttackDetectionModel.vae_decoder(intermediate_dim, latent_dim, original_dim)
outputs = decoder(encoder(inputs))
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  z_sampling (InputLayer)     [(None, 38)]              0
#
#  dense_1 (Dense)             (None, 57)                2223
#
#  dense_2 (Dense)             (None, 115)               6670
#
# =================================================================
# Total params: 8,893
# Trainable params: 8,893
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Hyperparemet Optimization

# %%
def maximize_training(X_train = X_train, 
                      X_test = X_test, 
                      Y_test = Y_test, 
                      inputs = inputs, 
                      outputs = outputs, 
                      vae_loss = vae_loss,
                      learning_rate = learning_rate,
                      batch_size = batch_size,
                      epochs = epochs,
                      anomaly_threshold = anomaly_threshold):    
    
    # Create model
    opt_adam = optimizers.Adam(learning_rate = dict_params['learning_rate'], clipvalue = 0.5)
    model = Model(inputs, outputs, name = 'vae_mlp')
    model.compile(optimizer = opt_adam, loss = vae_loss)

    # Train
    history = model.fit(X_train, 
                        X_train, 
                        shuffle = True, 
                        verbose = 0,
                        epochs = dict_params['epochs'], 
                        batch_size = dict_params['batch_size'])
    
    # Maximize the f1-score
    X_pred_opt = model.predict(X_test)
    error_vector_opt = AttackDetectionModel.get_error_term(X_pred_opt, X_test, _rmse = False)
    Y_pred_opt = (error_vector_opt > anomaly_threshold)
    f1 = f1_score(Y_test, Y_pred_opt)
    
    return f1

# %%
'''
# Apply Bayesian optimization to choose the best hyperparameters

opt = BayesianOptimization(f = maximize_training,
                           pbounds = pbounds,
                           verbose = 2, 
                           random_state = 1)

opt_start = time.time()

opt.maximize(init_points = 5, n_iter = 5)

opt_end = time.time()
opt_time = opt_end - opt_start
print("Optimization time:", opt_time)

learning_rate = opt.max['params']['learning_rate']
epochs = round(opt.max['params']['epochs'])
batch_size = round(opt.max['params']['batch_size'])
'''
# Out:
# '\n# Apply Bayesian optimization to choose the best hyperparameters\n\nopt = BayesianOptimization(f = maximize_training,\n                           pbounds = pbounds,\n                           verbose = 2, \n                           random_state = 1)\n\nopt_start = time.time()\n\nopt.maximize(init_points = 5, n_iter = 5)\n\nopt_end = time.time()\nopt_time = opt_end - opt_start\nprint("Optimization time:", opt_time)\n\nlearning_rate = opt.max[\'params\'][\'learning_rate\']\nepochs = round(opt.max[\'params\'][\'epochs\'])\nbatch_size = round(opt.max[\'params\'][\'batch_size\'])\n'

# %% [markdown]
# # Predict Attacks

# %%
# Training step with the best hyperparameters
learning_rate = 0.0002573457473330052
epochs = 464
batch_size = 78
opt_time = 543.0240316390991
anomaly_threshold = 0.05

# %%
for i in range(1):
    print("Iteration " + str(i))
    
    # Train
    vae_model, train_time = AttackDetectionModel.train(X_train, inputs, outputs, vae_loss, learning_rate, epochs, batch_size)
    
    # Set the optimized anomaly threshold
    #anomaly_threshold = AttackDetectionModel.get_anomaly_threshold(X_train, vae_model)
    
    # Test
    X_pred, test_time = AttackDetectionModel.test(X_test, vae_model)
    Y_test, Y_pred = AttackDetectionModel.get_prediction(Y_test, X_pred, X_test, anomaly_threshold, vae_model)
    
    # Metrics
    acc, f1, pre, rec = AttackDetectionModel.get_scores(Y_test, Y_pred)
    
    # Print results
    AttackDetectionModel.print_results(number_features,
                                       learning_rate,
                                       epochs,
                                       batch_size,
                                       anomaly_threshold,
                                       X_train,
                                       X_test,
                                       opt_time,
                                       train_time,
                                       test_time,
                                       acc,
                                       f1,
                                       pre,
                                       rec,
                                       Y_test,
                                       Y_pred,
                                       "Results/P737_camera.txt")
    
    print("")
# Out:
# Iteration 0
# Train on 43507 samples
# Epoch 1/464
# 43507/43507 [==============================] - 1s 26us/sample - loss: 333.7245
# Epoch 2/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 47.7723
# Epoch 3/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 33.2685
# Epoch 4/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 27.5633
# Epoch 5/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 24.5889
# Epoch 6/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 22.5691
# Epoch 7/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 20.7438
# Epoch 8/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 19.0852
# Epoch 9/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 17.5231
# Epoch 10/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 16.0676
# Epoch 11/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 15.0423
# Epoch 12/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 14.1981
# Epoch 13/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 13.4929
# Epoch 14/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 13.0067
# Epoch 15/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 12.4262
# Epoch 16/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 11.9489
# Epoch 17/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 11.6302
# Epoch 18/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 11.2025
# Epoch 19/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 10.9108
# Epoch 20/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 10.6200
# Epoch 21/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 10.3146
# Epoch 22/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 10.1111
# Epoch 23/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 9.9057
# Epoch 24/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 9.7021
# Epoch 25/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 9.5015
# Epoch 26/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 9.3957
# Epoch 27/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 9.2038
# Epoch 28/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 9.1205
# Epoch 29/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 8.9491
# Epoch 30/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 8.8620
# Epoch 31/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 8.7325
# Epoch 32/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 8.6721
# Epoch 33/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 8.5830
# Epoch 34/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 8.5144
# Epoch 35/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 8.4636
# Epoch 36/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 8.3889
# Epoch 37/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 8.3220
# Epoch 38/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 8.2907
# Epoch 39/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 8.2276
# Epoch 40/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 8.1721
# Epoch 41/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 8.0991
# Epoch 42/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 8.0701
# Epoch 43/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 8.0313
# Epoch 44/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 7.9382
# Epoch 45/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 7.9160
# Epoch 46/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 7.8923
# Epoch 47/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 7.8571
# Epoch 48/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 7.8321
# Epoch 49/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 7.7531
# Epoch 50/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 7.7512
# Epoch 51/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 7.7391
# Epoch 52/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 7.7108
# Epoch 53/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 7.6426
# Epoch 54/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 7.6469
# Epoch 55/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 7.5727
# Epoch 56/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 7.6146
# Epoch 57/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 7.5822
# Epoch 58/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 7.5054
# Epoch 59/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 7.5057
# Epoch 60/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 7.4909
# Epoch 61/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 7.4839
# Epoch 62/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 7.4575
# Epoch 63/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 7.4055
# Epoch 64/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 7.3702
# Epoch 65/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 7.3724
# Epoch 66/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 7.3239
# Epoch 67/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 7.3454
# Epoch 68/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 7.3171
# Epoch 69/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 7.2852
# Epoch 70/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 7.2808
# Epoch 71/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 7.2400
# Epoch 72/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 7.2476
# Epoch 73/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 7.2156
# Epoch 74/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 7.2096
# Epoch 75/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 7.2002
# Epoch 76/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 7.1710
# Epoch 77/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 7.1026
# Epoch 78/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 7.1555
# Epoch 79/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 7.1487
# Epoch 80/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 7.1283
# Epoch 81/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 7.1091
# Epoch 82/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 7.1323
# Epoch 83/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 7.0982
# Epoch 84/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 7.0845
# Epoch 85/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 7.0446
# Epoch 86/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 7.0693
# Epoch 87/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 7.0525
# Epoch 88/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 7.0362
# Epoch 89/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 7.0337
# Epoch 90/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 7.0219
# Epoch 91/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 6.9731
# Epoch 92/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 6.9841
# Epoch 93/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 7.0040
# Epoch 94/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 6.9811
# Epoch 95/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 6.9663
# Epoch 96/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 6.9491
# Epoch 97/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 6.9751
# Epoch 98/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 6.9236
# Epoch 99/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 6.9336
# Epoch 100/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 6.8936
# Epoch 101/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 6.8831
# Epoch 102/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 6.8802
# Epoch 103/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 6.9077
# Epoch 104/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 6.8905
# Epoch 105/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 6.8864
# Epoch 106/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 6.9045
# Epoch 107/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 6.8494
# Epoch 108/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 6.8656
# Epoch 109/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 6.8462
# Epoch 110/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 6.8497
# Epoch 111/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 6.8160
# Epoch 112/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 6.8257
# Epoch 113/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 6.8192
# Epoch 114/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 6.7997
# Epoch 115/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 6.8212
# Epoch 116/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 6.7617
# Epoch 117/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 6.7420
# Epoch 118/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 6.8050
# Epoch 119/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 6.7819
# Epoch 120/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 6.7717
# Epoch 121/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 6.7971
# Epoch 122/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 6.7473
# Epoch 123/464
# 43507/43507 [==============================] - 1s 19us/sample - loss: 6.7795
# Epoch 124/464
# 43507/43507 [==============================] - 1s 25us/sample - loss: 6.7813
# Epoch 125/464
# 43507/43507 [==============================] - 1s 27us/sample - loss: 6.7253
# Epoch 126/464
# 43507/43507 [==============================] - 1s 27us/sample - loss: 6.7607
# Epoch 127/464
# 43507/43507 [==============================] - 1s 27us/sample - loss: 6.7246
# Epoch 128/464
# 43507/43507 [==============================] - 1s 27us/sample - loss: 6.7357
# Epoch 129/464
# 43507/43507 [==============================] - 1s 28us/sample - loss: 6.7198
# Epoch 130/464
# 43507/43507 [==============================] - 1s 28us/sample - loss: 6.7027
# Epoch 131/464
# 43507/43507 [==============================] - 1s 27us/sample - loss: 6.7484
# Epoch 132/464
# 43507/43507 [==============================] - 1s 29us/sample - loss: 6.7163
# Epoch 133/464
# 43507/43507 [==============================] - 1s 21us/sample - loss: 6.7182
# Epoch 134/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 6.7322
# Epoch 135/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 6.7168
# Epoch 136/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 6.7185
# Epoch 137/464
# 43507/43507 [==============================] - 1s 26us/sample - loss: 6.6806
# Epoch 138/464
# 43507/43507 [==============================] - 1s 25us/sample - loss: 6.7001
# Epoch 139/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 6.7145
# Epoch 140/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 6.6560
# Epoch 141/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 6.7037
# Epoch 142/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 6.7039
# Epoch 143/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 6.6358
# Epoch 144/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 6.7105
# Epoch 145/464
# 43507/43507 [==============================] - 1s 18us/sample - loss: 6.6767
# Epoch 146/464
# 43507/43507 [==============================] - 1s 26us/sample - loss: 6.6763
# Epoch 147/464
# 43507/43507 [==============================] - 2s 41us/sample - loss: 6.6720
# Epoch 148/464
# 43507/43507 [==============================] - 2s 40us/sample - loss: 6.6626
# Epoch 149/464
# 43507/43507 [==============================] - 2s 40us/sample - loss: 6.6754
# Epoch 150/464
# 43507/43507 [==============================] - 2s 40us/sample - loss: 6.6421
# Epoch 151/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.6506
# Epoch 152/464
# 43507/43507 [==============================] - 2s 36us/sample - loss: 6.6390
# Epoch 153/464
# 43507/43507 [==============================] - 2s 36us/sample - loss: 6.5973
# Epoch 154/464
# 43507/43507 [==============================] - 2s 36us/sample - loss: 6.6136
# Epoch 155/464
# 43507/43507 [==============================] - 2s 36us/sample - loss: 6.6207
# Epoch 156/464
# 43507/43507 [==============================] - 2s 36us/sample - loss: 6.6290
# Epoch 157/464
# 43507/43507 [==============================] - 2s 36us/sample - loss: 6.6107
# Epoch 158/464
# 43507/43507 [==============================] - 2s 36us/sample - loss: 6.5943
# Epoch 159/464
# 43507/43507 [==============================] - 2s 36us/sample - loss: 6.6172
# Epoch 160/464
# 43507/43507 [==============================] - 2s 36us/sample - loss: 6.6068
# Epoch 161/464
# 43507/43507 [==============================] - 2s 36us/sample - loss: 6.6080
# Epoch 162/464
# 43507/43507 [==============================] - 2s 36us/sample - loss: 6.5602
# Epoch 163/464
# 43507/43507 [==============================] - 2s 35us/sample - loss: 6.5998
# Epoch 164/464
# 43507/43507 [==============================] - 2s 36us/sample - loss: 6.5674
# Epoch 165/464
# 43507/43507 [==============================] - 2s 36us/sample - loss: 6.5720
# Epoch 166/464
# 43507/43507 [==============================] - 2s 36us/sample - loss: 6.5556
# Epoch 167/464
# 43507/43507 [==============================] - 2s 36us/sample - loss: 6.5959
# Epoch 168/464
# 43507/43507 [==============================] - 2s 36us/sample - loss: 6.5833
# Epoch 169/464
# 43507/43507 [==============================] - 2s 36us/sample - loss: 6.5352
# Epoch 170/464
# 43507/43507 [==============================] - 2s 35us/sample - loss: 6.5545
# Epoch 171/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 6.5864
# Epoch 172/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.5216
# Epoch 173/464
# 43507/43507 [==============================] - 1s 34us/sample - loss: 6.5511
# Epoch 174/464
# 43507/43507 [==============================] - 1s 34us/sample - loss: 6.5553
# Epoch 175/464
# 43507/43507 [==============================] - 1s 34us/sample - loss: 6.5586
# Epoch 176/464
# 43507/43507 [==============================] - 1s 34us/sample - loss: 6.5358
# Epoch 177/464
# 43507/43507 [==============================] - 1s 34us/sample - loss: 6.5063
# Epoch 178/464
# 43507/43507 [==============================] - 1s 34us/sample - loss: 6.5240
# Epoch 179/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.4992
# Epoch 180/464
# 43507/43507 [==============================] - 1s 34us/sample - loss: 6.5152
# Epoch 181/464
# 43507/43507 [==============================] - 1s 34us/sample - loss: 6.4917
# Epoch 182/464
# 43507/43507 [==============================] - 1s 34us/sample - loss: 6.4892
# Epoch 183/464
# 43507/43507 [==============================] - 1s 34us/sample - loss: 6.4730
# Epoch 184/464
# 43507/43507 [==============================] - 1s 34us/sample - loss: 6.4920
# Epoch 185/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.4912
# Epoch 186/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.4905
# Epoch 187/464
# 43507/43507 [==============================] - 1s 34us/sample - loss: 6.5434
# Epoch 188/464
# 43507/43507 [==============================] - 1s 34us/sample - loss: 6.4987
# Epoch 189/464
# 43507/43507 [==============================] - 1s 34us/sample - loss: 6.4946
# Epoch 190/464
# 43507/43507 [==============================] - 1s 34us/sample - loss: 6.4897
# Epoch 191/464
# 43507/43507 [==============================] - 1s 34us/sample - loss: 6.4571
# Epoch 192/464
# 43507/43507 [==============================] - 1s 34us/sample - loss: 6.4973
# Epoch 193/464
# 43507/43507 [==============================] - 1s 34us/sample - loss: 6.4894
# Epoch 194/464
# 43507/43507 [==============================] - 1s 34us/sample - loss: 6.4828
# Epoch 195/464
# 43507/43507 [==============================] - 1s 34us/sample - loss: 6.4831
# Epoch 196/464
# 43507/43507 [==============================] - 1s 34us/sample - loss: 6.5228
# Epoch 197/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.4831
# Epoch 198/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.4603
# Epoch 199/464
# 43507/43507 [==============================] - 1s 34us/sample - loss: 6.4592
# Epoch 200/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.5108
# Epoch 201/464
# 43507/43507 [==============================] - 1s 28us/sample - loss: 6.5307
# Epoch 202/464
# 43507/43507 [==============================] - 1s 27us/sample - loss: 6.4743
# Epoch 203/464
# 43507/43507 [==============================] - 1s 30us/sample - loss: 6.4585
# Epoch 204/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 6.4964
# Epoch 205/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 6.4641
# Epoch 206/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 6.4693
# Epoch 207/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.4930
# Epoch 208/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.4736
# Epoch 209/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 6.5386
# Epoch 210/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.4419
# Epoch 211/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.4548
# Epoch 212/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.4451
# Epoch 213/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.4717
# Epoch 214/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.4477
# Epoch 215/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.4523
# Epoch 216/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 6.4086
# Epoch 217/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 6.4170
# Epoch 218/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.3913
# Epoch 219/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.4247
# Epoch 220/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.4390
# Epoch 221/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.4220
# Epoch 222/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.4297
# Epoch 223/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.4240
# Epoch 224/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.4090
# Epoch 225/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.4120
# Epoch 226/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.3939
# Epoch 227/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.4799
# Epoch 228/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.4205
# Epoch 229/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.4068
# Epoch 230/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.4307
# Epoch 231/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.3986
# Epoch 232/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.4340
# Epoch 233/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.4225
# Epoch 234/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.4582
# Epoch 235/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.4199
# Epoch 236/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.4332
# Epoch 237/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.4716
# Epoch 238/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.4215
# Epoch 239/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.4176
# Epoch 240/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.4209
# Epoch 241/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.4590
# Epoch 242/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.4483
# Epoch 243/464
# 43507/43507 [==============================] - 1s 34us/sample - loss: 6.4418
# Epoch 244/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.4437
# Epoch 245/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.4615
# Epoch 246/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.4770
# Epoch 247/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.4620
# Epoch 248/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 6.4620
# Epoch 249/464
# 43507/43507 [==============================] - 1s 30us/sample - loss: 6.4437
# Epoch 250/464
# 43507/43507 [==============================] - 1s 31us/sample - loss: 6.4980
# Epoch 251/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 6.4691
# Epoch 252/464
# 43507/43507 [==============================] - 1s 31us/sample - loss: 6.5153
# Epoch 253/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 6.5212
# Epoch 254/464
# 43507/43507 [==============================] - 1s 31us/sample - loss: 6.5022
# Epoch 255/464
# 43507/43507 [==============================] - 1s 34us/sample - loss: 6.5343
# Epoch 256/464
# 43507/43507 [==============================] - 1s 28us/sample - loss: 6.5364
# Epoch 257/464
# 43507/43507 [==============================] - 1s 29us/sample - loss: 6.5392
# Epoch 258/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.5578
# Epoch 259/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.5398
# Epoch 260/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 6.4712
# Epoch 261/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.4912
# Epoch 262/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.5053
# Epoch 263/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.5317
# Epoch 264/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.5341
# Epoch 265/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.5150
# Epoch 266/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.5566
# Epoch 267/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 6.5108
# Epoch 268/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.5005
# Epoch 269/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 6.5590
# Epoch 270/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 6.5845
# Epoch 271/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 6.5534
# Epoch 272/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.5338
# Epoch 273/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.5025
# Epoch 274/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 6.5297
# Epoch 275/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.5576
# Epoch 276/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.5648
# Epoch 277/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.5208
# Epoch 278/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.5382
# Epoch 279/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.5350
# Epoch 280/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 6.5961
# Epoch 281/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.5771
# Epoch 282/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 6.5366
# Epoch 283/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.5377
# Epoch 284/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.5438
# Epoch 285/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 6.5030
# Epoch 286/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 6.5224
# Epoch 287/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.4997
# Epoch 288/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.5063
# Epoch 289/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 6.5506
# Epoch 290/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.5118
# Epoch 291/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.5258
# Epoch 292/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 6.5277
# Epoch 293/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.4744
# Epoch 294/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.4333
# Epoch 295/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 6.5235
# Epoch 296/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.4788
# Epoch 297/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.5222
# Epoch 298/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.4848
# Epoch 299/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.5626
# Epoch 300/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.4744
# Epoch 301/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.5166
# Epoch 302/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.5151
# Epoch 303/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 6.5217
# Epoch 304/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 6.5179
# Epoch 305/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 6.5436
# Epoch 306/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 6.5287
# Epoch 307/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.5370
# Epoch 308/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.5080
# Epoch 309/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.4943
# Epoch 310/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.4750
# Epoch 311/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.5084
# Epoch 312/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.5035
# Epoch 313/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 6.5085
# Epoch 314/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.5229
# Epoch 315/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.5078
# Epoch 316/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.5287
# Epoch 317/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.4967
# Epoch 318/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.4850
# Epoch 319/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 6.5354
# Epoch 320/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.5449
# Epoch 321/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.5262
# Epoch 322/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.5432
# Epoch 323/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.5084
# Epoch 324/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.5134
# Epoch 325/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.5555
# Epoch 326/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.5582
# Epoch 327/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.5511
# Epoch 328/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.5228
# Epoch 329/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 6.6105
# Epoch 330/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.5787
# Epoch 331/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 6.5538
# Epoch 332/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 6.6027
# Epoch 333/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.5498
# Epoch 334/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.5470
# Epoch 335/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.5665
# Epoch 336/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 6.5575
# Epoch 337/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.5630
# Epoch 338/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 6.5648
# Epoch 339/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.6276
# Epoch 340/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 6.5876
# Epoch 341/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.6654
# Epoch 342/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.6509
# Epoch 343/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.6220
# Epoch 344/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 6.6192
# Epoch 345/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.6141
# Epoch 346/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.6710
# Epoch 347/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.6352
# Epoch 348/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.6032
# Epoch 349/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.7012
# Epoch 350/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 6.6349
# Epoch 351/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.7077
# Epoch 352/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.6634
# Epoch 353/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.6950
# Epoch 354/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.6628
# Epoch 355/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.6910
# Epoch 356/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 6.6803
# Epoch 357/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.6534
# Epoch 358/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.7523
# Epoch 359/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.6864
# Epoch 360/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 6.7345
# Epoch 361/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.7995
# Epoch 362/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.7376
# Epoch 363/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.7134
# Epoch 364/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 6.7573
# Epoch 365/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.7417
# Epoch 366/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.7783
# Epoch 367/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.7723
# Epoch 368/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 6.7891
# Epoch 369/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.8192
# Epoch 370/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 6.7655
# Epoch 371/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.8080
# Epoch 372/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.8004
# Epoch 373/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 6.7867
# Epoch 374/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.8353
# Epoch 375/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 6.7795
# Epoch 376/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 6.8395
# Epoch 377/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.8311
# Epoch 378/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 6.7925
# Epoch 379/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.7999
# Epoch 380/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.8593
# Epoch 381/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.8532
# Epoch 382/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.8499
# Epoch 383/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.8266
# Epoch 384/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.9202
# Epoch 385/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.8356
# Epoch 386/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.9118
# Epoch 387/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.9339
# Epoch 388/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.8921
# Epoch 389/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.8598
# Epoch 390/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.8481
# Epoch 391/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.8741
# Epoch 392/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.9317
# Epoch 393/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.9365
# Epoch 394/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.8948
# Epoch 395/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.8936
# Epoch 396/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.8984
# Epoch 397/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.8980
# Epoch 398/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.8708
# Epoch 399/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.8555
# Epoch 400/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 6.9602
# Epoch 401/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.9400
# Epoch 402/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.9405
# Epoch 403/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.9027
# Epoch 404/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.9628
# Epoch 405/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.9472
# Epoch 406/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.9550
# Epoch 407/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.9224
# Epoch 408/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.9299
# Epoch 409/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.9219
# Epoch 410/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 6.8962
# Epoch 411/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.9578
# Epoch 412/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 6.9650
# Epoch 413/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 7.0228
# Epoch 414/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.9718
# Epoch 415/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.9976
# Epoch 416/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.9254
# Epoch 417/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 7.0682
# Epoch 418/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 7.0561
# Epoch 419/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 7.0133
# Epoch 420/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 7.0798
# Epoch 421/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 7.0532
# Epoch 422/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 6.9809
# Epoch 423/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 6.9970
# Epoch 424/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 7.0548
# Epoch 425/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 7.0357
# Epoch 426/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 7.0358
# Epoch 427/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 7.0582
# Epoch 428/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 7.0401
# Epoch 429/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 7.0911
# Epoch 430/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 7.0722
# Epoch 431/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 7.0192
# Epoch 432/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 7.0509
# Epoch 433/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 7.0309
# Epoch 434/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 7.0385
# Epoch 435/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 7.0561
# Epoch 436/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 7.0248
# Epoch 437/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 7.0333
# Epoch 438/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 7.0845
# Epoch 439/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 7.0722
# Epoch 440/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 7.0125
# Epoch 441/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 7.0767
# Epoch 442/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 7.0713
# Epoch 443/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 7.0221
# Epoch 444/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 7.1201
# Epoch 445/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 7.0955
# Epoch 446/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 7.0360
# Epoch 447/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 7.0482
# Epoch 448/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 7.0389
# Epoch 449/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 7.0705
# Epoch 450/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 7.1058
# Epoch 451/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 7.0834
# Epoch 452/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 7.0301
# Epoch 453/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 7.0658
# Epoch 454/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 7.0929
# Epoch 455/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 7.1448
# Epoch 456/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 7.0569
# Epoch 457/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 7.0114
# Epoch 458/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 7.1094
# Epoch 459/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 7.0412
# Epoch 460/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 7.1193
# Epoch 461/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 7.1744
# Epoch 462/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 7.1719
# Epoch 463/464
# 43507/43507 [==============================] - 1s 33us/sample - loss: 7.0962
# Epoch 464/464
# 43507/43507 [==============================] - 1s 32us/sample - loss: 7.1484
# Training time: 577.9516406059265
# /home/andressa.amaral/.local/lib/python3.8/site-packages/keras/engine/training_v1.py:2357: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# Testing time: 18.17971396446228

# %% [markdown]
# # Metrics

# %%
# Examinig the latent space generated by the encoder
X_encoded = encoder.predict(X_test)

pca = PCA(n_components=2)
X_analysis = pca.fit_transform(X_encoded)
# Out:
# /home/andressa.amaral/.local/lib/python3.8/site-packages/keras/engine/training_v1.py:2357: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,

# %%
plt.figure(figsize=(8, 8))
sns.scatterplot(x = X_analysis[:, 0], y = X_analysis[:, 1], s = 20, hue = Y_pred)
plt.grid()
plt.savefig("Results/PCA/P7_" + str(number_features))
plt.show()

# Orange ones are anomalies

# %%
plt.figure(figsize = (8, 8))
sns.scatterplot(x = X_analysis[:, 0], y = X_analysis[:, 1], s = 20, hue = Y_test)
plt.grid()
plt.savefig("Results/PCA Groundtruth/P7_" + str(number_features))
plt.show()

# Ground truth

# %%
conf_matrix = confusion_matrix(Y_test, Y_pred)

fig, ax = plt.subplots(figsize = (5, 5))
ax.matshow(conf_matrix, cmap = plt.cm.Blues, alpha = 0.3)
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        ax.text(x = j, y = i,s = conf_matrix[i, j], va = 'center', ha = 'center', fontsize = 18)
 
plt.xlabel('Predictions', fontsize = 16)
plt.ylabel('Actuals', fontsize = 16)
plt.savefig("Results/Confusion Matrix/P7_" + str(number_features))
plt.show()
